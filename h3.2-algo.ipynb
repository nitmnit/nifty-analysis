# %%
import base as b
import pandas as pd
import datetime as dt
from typing import Dict
import talib as ta
import utils as ut
from constants import *
from scipy.stats import linregress
from logger_settings import logger

settings = {
    "vwch_thresh": 3,
    "quantity": 50 * 1, # 1 lot
    "stagnation_cooldown": 5, # cooldown period after stagnation to resume, in ticks
    "svs_mx_thresh": 8000, # stagnation_volume_std_min_threshold
    "svs_mn_thresh": 15000, # stagnation_volume_std_max_threshold
}

instrument = b.Instrument(name="NIFTY 22650 CALL 7 Mar 2024")

SYMBOL = "NIFTY"
expiry = dt.datetime.strptime("2024-03-21", "%Y-%m-%d").date()
otype = "CE"
strike = 22000
date = dt.datetime.strptime("2024-03-15", "%Y-%m-%d").date()

tdf = ut.get_ticks(symbol=SYMBOL, expiry=expiry, strike=strike, otype=otype, date=date)

# %%
REASON_REVERSE_SIGNIFICANCE = "reverse significance found"
REASON_STAGNATING = "trend stagnating"
REASON_CONFIRM = "confirmed"

class Phase(b.BasePhase):
    def __init__(self, initiated_at, strategy):
        super().__init__(initiated_at, strategy)
        self.volume_confirmed = False
        self.parent_volume_confirmed = False
        self.last_slope = None
        self.stagnated_at = None
        self.stagnate_reason = None
        logger.info(f"created new phase{self.id} at: {initiated_at}")
        if initiated_at < strategy.ticks.iloc[-1].name:
            self.rerun()

    def __repr__(self):
        return (f"==Phase {self.id}:{self.direction}, {self.status} I:{self.initiated_at}, C:{self.confirmed_at} R:{self.retraced_at}, "
               f"T:{self.term_at}, RJ:{self.rejected_at}, cr:{self.created_at} tr: {self.term_reason}, rr:{self.retrace_reason}, "
               f"end:{self.ended_at}, vc: {self.volume_confirmed}, pc: {self.parent_volume_confirmed}, st: {self.stagnated_at}==")

    def rerun(self):
        self.next()

    def has_breached_start(self):
        up_breach = self.direction == UP and (self.strategy.ticks.iloc[-1].last_price <= self.strategy.ticks.loc[self.initiated_at].last_price).all()
        if up_breach:
            return up_breach
        down_breach = self.direction == DOWN and (self.strategy.ticks.iloc[-1].last_price >= self.strategy.ticks.loc[self.initiated_at].last_price).all()
        return down_breach

    def get_new_phase_start(self):
        """
        Return new phase start when current phase is breached
        """
        if self.direction == UP:
            return self.strategy.ticks.loc[self.strategy.ticks.index > self.initiated_at].last_price.idxmax()
        else:
            return self.strategy.ticks.loc[self.strategy.ticks.index > self.initiated_at].last_price.idxmin()

    def is_tick_significant(self):
        """
        If a tick has a very high vwch, that could mean that its a very significant tick.
        If opposite direction tick has a very high vwch, its a good sign of reversal.
        Returns -1 if its opposite direction significant
        Returns 1 if same direction significant
        Returns 0 if not significant
        """
        thresh = self.strategy.vwch_thresh
        is_volume_significant = self.pticks.iloc[-1].volume >= (thresh * self.pticks.volume.mean())
        if not is_volume_significant:
            return 0
        if self.direction == UP and self.pticks.iloc[-1].ch <= 0:
            return -1
        if self.direction == DOWN and self.pticks.iloc[-1].ch >= 0:
            return -1
        return 1

    def terminate(self, reason):
        self.status = self.STATUS_TERM
        self.term_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_termination(self, reason)
        self.term_reason = reason
        if self.retraced_at is None:
            self.retraced_at = self.strategy.ticks.iloc[-1].name
            self.retrace_reason = "on phase termination"

    def retracing(self, reason):
        self.status = self.STATUS_RETRACING
        self.retraced_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_retracel(self, reason)
        self.retrace_reason = reason

    def stagnating(self, reason):
        if self.status == self.STATUS_STAGNATING:
            return
        self.status = self.STATUS_STAGNATING
        self.stagnated_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_stagnation(self, reason)
        self.stagnate_reason = reason

    def confirm(self):
        self.status = self.STATUS_CONFIRMED
        self.strategy.on_confirmed(self, REASON_CONFIRM)

    def calculate_pdata(self):
        self.pticks["ch"] = self.pticks.last_price.diff()
        self.pticks["vwch"] = self.pticks.ch * self.pticks.volume  # Volume weighted change
        self.pticks["std_vwch"] = self.pticks.vwch.rolling(window=5).std()  # Volume weighted change
        # self.pticks["cum_vwch"] = self.pticks.vwch.cumsum()
        # self.last_slope = self.get_slope(self.ended_at)

    def get_slope(self, eidx):
        if self.direction == UP:
            last_idx = self.pticks.last_price.idxmax()
        else:
            last_idx = self.pticks.last_price.idxmin()
        if eidx - last_idx < 6:
            return
        df = self.pticks.loc[last_idx: eidx+1]
        try:
            lr = linregress(df.id, df.cum_vwch)
        except ValueError:
            raise Exception("asd")
        logger.info(f"slope: {last_idx} to {eidx}: {lr.slope}, {self}")
        return lr.slope

    def is_stagnating(self):
        if self.direction == UP and (self.last_slope is not None) and self.last_slope < -300:
            if self.status != Phase.STATUS_STAGNATING:
                return True
            else:
                return self.last_slope > 300
        elif self.direction == DOWN and (self.last_slope is not None) and self.last_slope > 300:
            if self.status != Phase.STATUS_STAGNATING:
                return True
            else:
                return self.last_slope < - 300
        return False

    def next(self):
        super().next()
        self.calculate_pdata()
        if self.status == self.STATUS_TERM:
            raise Exception(f"phase {self} already terminated")
        if self.status == self.STATUS_INITIATED:
            if self.pticks.iloc[-1].ch > 0:
                self.direction = UP
            else:
                self.direction = DOWN
            self.confirm()
            return
        if self.has_breached_start():
            self.terminate("breached start")
            return
        if self.status == self.STATUS_RETRACING:
            return
        is_stagnating = self.is_stagnating()
        if self.status == self.STATUS_STAGNATING and self.ended_at - self.stagnated_at >= self.strategy.stagnation_cooldown:
            if not is_stagnating:
                self.confirm()
                return
        if is_stagnating:
            self.stagnating(REASON_STAGNATING)
            return
        significance = self.is_tick_significant()
        if significance == -1:
            self.retracing(REASON_REVERSE_SIGNIFICANCE)
            return
        elif significance == 1:
            self.volume_confirmed = True

class PhaseStrategy(b.BasePhaseStrategy):
    def __init__(self, instrument: "Instrument", settings: Dict):
        super().__init__(instrument, settings)
        self.om = b.OrderManager()

    def calculate_data(self):
        pass

    def next(self, tick: Dict):
        super().next(tick)
        self.calculate_data()
        if self.current_phase is None:
            self.current_phase = Phase(initiated_at=self.ticks.iloc[-1].name, strategy=self)
        else:
            self.current_phase.next()
        for phase in self.active_ph:
            phase.next()

    def _terminate_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_TERM:
            raise Exception("expected terminated status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            self.current_phase.status = Phase.STATUS_CONFIRMED
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
        self.inactive_ph.append(last_phase)

    def _retrace_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_RETRACING:
            raise Exception(f"expected {Phase.STATUS_RETRACING} status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            self.current_phase.status = Phase.STATUS_CONFIRMED
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
            if reason == REASON_REVERSE_SIGNIFICANCE:
                self.current_phase.volume_confirmed = True
        self.active_ph.append(last_phase)

    def _stagnate_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_STAGNATING:
            raise Exception(f"expected {Phase.STATUS_STAGNATING} status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            self.current_phase.status = Phase.STATUS_CONFIRMED
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
        self.active_ph.append(last_phase)
    
    def set_new_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status == Phase.STATUS_TERM:
            self._terminate_last_phase(reason)
        elif last_phase.status == Phase.STATUS_RETRACING:
            self._retrace_last_phase(reason)
        elif last_phase.status == Phase.STATUS_STAGNATING:
            self._stagnate_last_phase(reason)
        else:
            raise Exception("status not handled")
        # if last_phase.status == Phase.STATUS_TERM and self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction and self.active_ph[-1].status == Phase.STATUS_RETRACING:
        #     self.current_phase = self.active_ph[-1]
        #     self.current_phase.status = Phase.STATUS_CONFIRMED
        #     del self.active_ph[-1]
        #     self.inactive_ph.append(last_phase)
        # else:
        #     new_start = last_phase.get_new_phase_start()
        #     if last_phase.status == Phase.STATUS_RETRACING and self.active_ph is not None and len(self.active_ph) > 0:
        #         if self.active_ph[-1].direction != last_phase.direction and self.active_ph[-1].status == Phase.STATUS_RETRACING:
        #             self.current_phase = self.active_ph[-1]
        #             del self.active_ph[-1]
        #             self.current_phase.status = Phase.STATUS_CONFIRMED
        #             self.active_ph.append(last_phase)
        #         else:
        #             print(f"ad: {self.active_ph[-1].direction}, cd: {last_phase.direction}, st: {self.active_ph[-1].status}, {self.active_ph[-1]}")
        #             raise NotImplementedError
        #     else:
        #         self.current_phase = Phase(initiated_at=new_start, strategy=self)
        #         if last_phase.status == Phase.STATUS_TERM:
        #             self.inactive_ph.append(last_phase)
        #         elif last_phase.status == Phase.STATUS_RETRACING:
        #             self.active_ph.append(last_phase)
        #             if reason == REASON_REVERSE_SIGNIFICANCE:
        #                 self.current_phase.volume_confirmed = True
        #         if self.active_ph is not None and self.active_ph:
        #             self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed

    def on_termination(self, phase, reason):
        logger.info(f"phase terminated: {phase}")
        if self.om.has_intrade_orders(phase):
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=phase)
        if phase.id != self.current_phase.id:
            idx = [i for i, cphase in enumerate(self.active_ph) if cphase.id == phase.id][0]
            self.inactive_ph.append(self.active_ph[idx])
            del self.active_ph[idx]
            return
        self.set_new_phase(reason)
        if self.current_phase.direction == UP and self.current_phase.status == Phase.STATUS_CONFIRMED and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed:
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_retracel(self, phase, reason):
        logger.info(f"phase retracing {phase}")
        if phase.id != self.current_phase.id:
            return
        if self.om.has_intrade_orders():
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=self.current_phase)
        self.set_new_phase(reason)
        if self.current_phase.direction == UP and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed:
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_confirmed(self, phase, reason):
        logger.info(f"phase on confirmed {phase}")
        if phase.id != self.current_phase.id:
            return
        if self.current_phase.direction == UP and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed:
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_stagnation(self, phase, reason):
        logger.info(f"phase stagnating {phase}, slope: {phase.last_slope}")
        if phase.id != self.current_phase.id:
            return
        if self.om.has_intrade_orders():
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=self.current_phase)
        # self.set_new_phase(reason)

ps = PhaseStrategy(instrument=instrument, settings=settings)
# for i in range(tdf.shape[0]):
# for i in range(1000, 3000):
for i in range(100):
    ps.next(tdf.iloc[i].to_dict())

print(ps.current_phase)
print(ps.inactive_ph)
print(ps.active_ph)
# Out:
# 2024-03-19 15:46:38,096 - INFO - 667869005.py:13 - [126938945619200] -
# created new phase0 at: 0
# 2024-03-19 15:46:38,101 - INFO - 667869005.py:284 - [126938945619200] -
# phase on confirmed ==Phase 0:DOWN, CONFIRMED I:0, C:None R:None, T:None, RJ:None, cr:0 tr: None, rr:None, end:1, vc: False, pc: False, st: None==
# 2024-03-19 15:46:38,114 - INFO - 667869005.py:255 - [126938945619200] -
# phase terminated: ==Phase 0:DOWN, TERMINATED I:0, C:None R:None, T:3, RJ:None, cr:0 tr: None, rr:None, end:3, vc: False, pc: False, st: None==
# 2024-03-19 15:46:38,116 - INFO - base.py:145 - [126938945619200] -
# has_intrade_orders called
# 2024-03-19 15:46:38,120 - INFO - 667869005.py:13 - [126938945619200] -
# created new phase1 at: 1
# 2024-03-19 15:46:38,127 - INFO - 667869005.py:284 - [126938945619200] -
# phase on confirmed ==Phase 1:UP, CONFIRMED I:1, C:None R:None, T:None, RJ:None, cr:3 tr: None, rr:None, end:3, vc: False, pc: False, st: None==
# 2024-03-19 15:46:38,151 - INFO - 667869005.py:255 - [126938945619200] -
# phase terminated: ==Phase 1:UP, TERMINATED I:1, C:None R:None, T:4, RJ:None, cr:3 tr: None, rr:None, end:4, vc: False, pc: False, st: None==
# 2024-03-19 15:46:38,152 - INFO - base.py:145 - [126938945619200] -
# has_intrade_orders called
# 2024-03-19 15:46:38,154 - INFO - 667869005.py:13 - [126938945619200] -
# created new phase2 at: 3
# 2024-03-19 15:46:38,161 - INFO - 667869005.py:284 - [126938945619200] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:4, vc: False, pc: False, st: None==
# 2024-03-19 15:46:38,394 - INFO - 667869005.py:271 - [126938945619200] -
# phase retracing ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:None, end:22, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,396 - INFO - base.py:145 - [126938945619200] -
# has_intrade_orders called
# 2024-03-19 15:46:38,399 - INFO - 667869005.py:13 - [126938945619200] -
# created new phase3 at: 19
# 2024-03-19 15:46:38,404 - INFO - 667869005.py:284 - [126938945619200] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:22, vc: False, pc: False, st: None==
# 2024-03-19 15:46:38,406 - INFO - base.py:140 - [126938945619200] -
# place_order called
# 2024-03-19 15:46:38,407 - INFO - 667869005.py:281 - [126938945619200] -
# placed order for phase start: ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:22, vc: True, pc: True, st: None==, order: buy, b:214.2, s:None, pnl:NA
# 2024-03-19 15:46:38,468 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 25: 19117.916666666548, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:25, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,479 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 26: 20973.951612903125, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:26, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,491 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 27: 17876.324999999895, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:27, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,506 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 28: 14421.504559270426, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:28, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,519 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 29: 11862.43396226408, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:29, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,530 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 30: 10906.983584131263, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:30, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,542 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 31: 9933.357699805008, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:31, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,553 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 32: 8786.97222222217, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:32, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,563 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 33: 8194.927184465978, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:33, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,573 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 34: 7282.217391304309, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:34, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,584 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 35: 6364.096385542138, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:35, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,595 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 36: 5518.749999999972, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:36, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,609 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 37: 5000.676691729299, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:37, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,629 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 38: 4611.393377059648, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:38, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,637 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 33 to 39: -429.1927083333393, ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:39, vc: True, pc: True, st: None==
# 2024-03-19 15:46:38,639 - INFO - 667869005.py:294 - [126938945619200] -
# phase stagnating ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:39, vc: True, pc: True, st: 39==, slope: -429.1927083333393
# 2024-03-19 15:46:38,641 - INFO - base.py:145 - [126938945619200] -
# has_intrade_orders called
# 2024-03-19 15:46:38,643 - INFO - base.py:158 - [126938945619200] -
# squared off buy, b:214.2, s:220.4, pnl:310.0
# 2024-03-19 15:46:38,648 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 39: 4372.281484962385, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:39, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,656 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 33 to 40: -117.56410256410993, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:40, vc: True, pc: True, st: 39==
# 2024-03-19 15:46:38,661 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 40: 4072.099753694561, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:40, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,669 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 33 to 41: 632.8942307692237, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:41, vc: True, pc: True, st: 39==
# 2024-03-19 15:46:38,675 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 41: 3861.3947050064958, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:41, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,683 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 33 to 42: 954.5192307692234, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:42, vc: True, pc: True, st: 39==
# 2024-03-19 15:46:38,694 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 42: 3711.552547770682, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:42, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,702 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 33 to 43: 973.655660377351, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:43, vc: True, pc: True, st: 39==
# 2024-03-19 15:46:38,706 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 43: 3510.326271186423, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:43, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,714 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 33 to 44: 1234.8908857509564, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:44, vc: True, pc: True, st: 39==
# 2024-03-19 15:46:38,716 - INFO - 667869005.py:284 - [126938945619200] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:44, vc: True, pc: True, st: 39==
# 2024-03-19 15:46:38,718 - INFO - base.py:140 - [126938945619200] -
# place_order called
# 2024-03-19 15:46:38,720 - INFO - 667869005.py:291 - [126938945619200] -
# placed order for phase start: ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:44, vc: True, pc: True, st: 39==, order: buy, b:220.5, s:None, pnl:NA
# 2024-03-19 15:46:38,724 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 44: 3367.3144255686566, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:44, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,734 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 45: 3229.365833985123, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:45, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,745 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 46: 3141.7313245848586, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:46, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,762 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 47: 2983.2609135747816, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:47, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,773 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 48: 3163.511760581326, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:48, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,783 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 49: 3258.3067899530693, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:49, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,794 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 50: 3330.702098140389, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:50, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,804 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 51: 3365.8357093855793, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:51, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,816 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 52: 3393.4833741955226, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:52, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,828 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 53: 3402.6756798305537, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:53, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,835 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 48 to 54: -230.76923076922574, ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:54, vc: True, pc: True, st: 39==
# 2024-03-19 15:46:38,843 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 54: 3407.7063810110967, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:54, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,853 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 55: 3448.4414723841246, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:55, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,864 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 19 to 56: 3524.2140736305, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:56, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,866 - INFO - 667869005.py:255 - [126938945619200] -
# phase terminated: ==Phase 2:DOWN, TERMINATED I:3, C:None R:22, T:56, RJ:None, cr:4 tr: None, rr:reverse significance found, end:56, vc: True, pc: False, st: None==
# 2024-03-19 15:46:38,868 - INFO - base.py:145 - [126938945619200] -
# has_intrade_orders called
# 2024-03-19 15:46:38,924 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 61 to 67: -1494.5220588235456, ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:67, vc: True, pc: True, st: 39==
# 2024-03-19 15:46:38,926 - INFO - 667869005.py:294 - [126938945619200] -
# phase stagnating ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:67, vc: True, pc: True, st: 67==, slope: -1494.5220588235456
# 2024-03-19 15:46:38,928 - INFO - base.py:145 - [126938945619200] -
# has_intrade_orders called
# 2024-03-19 15:46:38,930 - INFO - base.py:158 - [126938945619200] -
# squared off buy, b:220.5, s:223.45, pnl:147.5
# 2024-03-19 15:46:38,936 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 61 to 68: -1082.3387096774347, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:68, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:38,943 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 61 to 69: -900.3750000000151, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:69, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:38,952 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 61 to 70: -851.9572953736846, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:70, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:38,959 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 61 to 71: -511.8441704036062, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:71, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:38,966 - INFO - 667869005.py:284 - [126938945619200] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:72, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:38,968 - INFO - base.py:140 - [126938945619200] -
# place_order called
# 2024-03-19 15:46:38,970 - INFO - 667869005.py:291 - [126938945619200] -
# placed order for phase start: ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:72, vc: True, pc: True, st: 67==, order: buy, b:225.0, s:None, pnl:NA
# 2024-03-19 15:46:39,047 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 80 to 86: 55.220588235320655, ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:86, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:39,056 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 80 to 87: -145.31746031743236, ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:87, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:39,064 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 80 to 88: -170.63084112147135, ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:88, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:39,071 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 80 to 89: -432.48164464019953, ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:89, vc: True, pc: True, st: 67==
# 2024-03-19 15:46:39,073 - INFO - 667869005.py:294 - [126938945619200] -
# phase stagnating ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:89, vc: True, pc: True, st: 89==, slope: -432.48164464019953
# 2024-03-19 15:46:39,074 - INFO - base.py:145 - [126938945619200] -
# has_intrade_orders called
# 2024-03-19 15:46:39,076 - INFO - base.py:158 - [126938945619200] -
# squared off buy, b:225.0, s:225.75, pnl:37.5
# 2024-03-19 15:46:39,083 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 80 to 90: -552.4732334046704, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:90, vc: True, pc: True, st: 89==
# 2024-03-19 15:46:39,091 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 80 to 91: -710.4088785046343, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:91, vc: True, pc: True, st: 89==
# 2024-03-19 15:46:39,099 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 80 to 92: -800.6854345164862, ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:92, vc: True, pc: True, st: 89==
# 2024-03-19 15:46:39,109 - INFO - 667869005.py:284 - [126938945619200] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:94, vc: True, pc: True, st: 89==
# 2024-03-19 15:46:39,111 - INFO - base.py:140 - [126938945619200] -
# place_order called
# 2024-03-19 15:46:39,112 - INFO - 667869005.py:291 - [126938945619200] -
# placed order for phase start: ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:94, vc: True, pc: True, st: 89==, order: buy, b:226.15, s:None, pnl:NA
# 2024-03-19 15:46:39,134 - INFO - 667869005.py:104 - [126938945619200] -
# slope: 93 to 99: -5975.427631578949, ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:99, vc: True, pc: True, st: 89==
# 2024-03-19 15:46:39,136 - INFO - 667869005.py:294 - [126938945619200] -
# phase stagnating ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:99, vc: True, pc: True, st: 99==, slope: -5975.427631578949
# 2024-03-19 15:46:39,137 - INFO - base.py:145 - [126938945619200] -
# has_intrade_orders called
# 2024-03-19 15:46:39,139 - INFO - base.py:158 - [126938945619200] -
# squared off buy, b:226.15, s:223.3, pnl:-142.5
# ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:99, vc: True, pc: True, st: 99==
# [==Phase 0:DOWN, TERMINATED I:0, C:None R:3, T:3, RJ:None, cr:0 tr: breached start, rr:on phase termination, end:3, vc: False, pc: False, st: None==, ==Phase 1:UP, TERMINATED I:1, C:None R:4, T:4, RJ:None, cr:3 tr: breached start, rr:on phase termination, end:4, vc: False, pc: False, st: None==, ==Phase 2:DOWN, TERMINATED I:3, C:None R:22, T:56, RJ:None, cr:4 tr: breached start, rr:reverse significance found, end:56, vc: True, pc: False, st: None==]
# []

# %%
print(f"Total orders: {len(ps.om.closed_orders)}")
print(f"Total PNL %: {sum([po.order.pnl for po in ps.om.closed_orders]) * 100 / sum([po.order.limit_price * po.order.quantity for po in ps.om.closed_orders])}")
# Out:
# Total orders: 4
# Total PNL %: 0.7958457978213016

# %%
from bokeh.models import ColumnDataSource
all_phases = ps.inactive_ph + [phase for phase in ps.active_ph if phase.retraced_at is not None]
up_ini_idx = [ps.ticks.loc[phase.initiated_at].id for phase in all_phases if phase.direction == UP]
up_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == UP]

up_end_idx = [ps.ticks.loc[phase.retraced_at].id for phase in all_phases if phase.direction == UP]
up_end = [ps.ticks.loc[phase.retraced_at].last_price for phase in all_phases if phase.direction == UP]

down_ini_idx = [ps.ticks.loc[phase.initiated_at].id for phase in all_phases if phase.direction == DOWN]
down_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == DOWN]
down_end_idx = [ps.ticks.loc[phase.retraced_at].id for phase in all_phases if phase.direction == DOWN]
down_end = [ps.ticks.loc[phase.retraced_at].last_price for phase in all_phases if phase.direction == DOWN]

up_ini_plot = ColumnDataSource({'x': up_ini_idx, 'y': up_initiate})
up_end_plot = ColumnDataSource({'x': up_end_idx, 'y': up_end})

down_ini_plot = ColumnDataSource({'x': down_ini_idx, 'y': down_initiate})
down_end_plot = ColumnDataSource({'x': down_end_idx, 'y': down_end})

order_created_at = [ps.ticks.loc[po.order.created_at].id for po in ps.om.closed_orders]
order_created_at_price = [ps.ticks.loc[po.order.created_at].last_price for po in ps.om.closed_orders]

order_sqo_at = [ps.ticks.loc[po.order.square_off_at].id for po in ps.om.closed_orders]
order_sqo_at_price = [ps.ticks.loc[po.order.square_off_at].last_price for po in ps.om.closed_orders]
order_at_cds = ColumnDataSource({'x': order_created_at, 'y': order_created_at_price})
order_sqo_at_cds = ColumnDataSource({'x': order_sqo_at, 'y': order_sqo_at_price})

down_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == DOWN]

ticks_cdf = ColumnDataSource(ps.ticks)
# ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end'])
# ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end'])
ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot, order_at_cds, order_sqo_at_cds], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end', 'Order At', 'Order SQO'])
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ad0788a8-d9d5-492c-8324-0ccb99b47d8e">Loading BokehJS ...</span>
#     </div>
#   <div id="decb1e20-4dba-4e33-b228-5f341c955ec8" data-root-id="p1022" style="display: contents;"></div>

# %%
# for i, row in ps.ticks.iterrows():

# ps.ticks['vwch_rolling'] = ps.ticks.vwch.rolling(window=5).sum()
# ps.ticks['vwch_cum'] = ps.ticks.vwch.cumsum()
ps.ticks.head(100)
# Out:
#     last_price  last_traded_quantity  total_buy_quantity  total_sell_quantity  \
# 0       220.35                    50               43000                45600
# 1       218.10                   250               56350                42950
# 2       218.30                   200               73600                47500
# 3       223.15                    50               89500                58800
# 4       218.10                    50               95500                67350
# ..         ...                   ...                 ...                  ...
# 76      224.95                    50              168600                82900
# 77      224.90                   100              157450                72000
# 78      224.40                    50              166000                88700
# 79      226.80                   300              174850                82250
# 80      227.10                    50              182150                84750
#
#        last_trade_time       oi  volume  id
# 0  2024-03-15 09:15:02  1879800     0.0   0
# 1  2024-03-15 09:15:03  1879800  7550.0   1
# 2  2024-03-15 09:15:03  1879800  1900.0   1
# 3  2024-03-15 09:15:04  1879800  2400.0   2
# 4  2024-03-15 09:15:05  1879800  6600.0   3
# ..                 ...      ...     ...  ..
# 76 2024-03-15 09:15:52  1906300  3800.0  50
# 77 2024-03-15 09:15:53  1906300  3500.0  51
# 78 2024-03-15 09:15:53  1906300  3100.0  51
# 79 2024-03-15 09:15:54  1906300  1400.0  52
# 80 2024-03-15 09:15:54  1906300  2900.0  52
#
# [81 rows x 8 columns]

# %% [markdown]
# # Per Quantity Movement Chart

# %%
# from matplotlib import pyplot as plt

# plt.ion()
# plt.figure(figsize=(30, 12))  # Adjust the width and height as needed

# plt.plot(ps.ticks.loc[ps.ticks.pqch.notna()].pqch)

# ut.bokeh_series_plot(ps.ticks, 'vwch_cum', 'id')
# ps.inactive_ph[5]
# ps.inactive_ph[2].id
ut.bokeh_series_plot(ps.inactive_ph[2].pticks, 'cum_vwch', 'id')
# ut.bokeh_series_plot(ps.current_phase.pticks, 'cum_vwch', 'id')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b1136ddf-f9d9-4844-a8c3-efb364051881">Loading BokehJS ...</span>
#     </div>
#   <div id="e987517b-c7fa-435e-bf20-180320e530e4" data-root-id="p1139" style="display: contents;"></div>

# %%
# print(ps.inactive_ph[5].pticks.to_json())
ps.inactive_ph[2].pticks['rolling_std'] = ps.inactive_ph[2].pticks.vwch.rolling(window=7).std()
ps.inactive_ph[2].pticks
# Out:
#     last_price  last_traded_quantity  total_buy_quantity  total_sell_quantity  \
# 3       223.15                    50               89500                58800
# 4       218.10                    50               95500                67350
# 5       222.70                    50              104800                61750
# 6       219.60                    50               99900                76650
# 7       218.30                   100              108000                80000
# 8       216.55                   250              108800                82850
# 9       215.30                    50              106600                77100
# 10      217.95                   200              114050                67850
# 11      216.30                    50              106450                66550
# 12      215.95                    50              116000                73650
# 13      215.20                    50              111700                78350
# 14      216.05                   100              114200                79200
# 15      216.00                    50              123150                85050
# 16      215.50                    50              120050                71350
# 17      214.00                    50              116700                79900
# 18      212.80                    50              115050                74900
# 19      212.35                    50              122000                93250
# 20      212.75                    50              118000                81550
# 21      212.80                    50              118000                81550
# 22      214.20                    50              119450                77800
# 23      214.30                    50              121350                80500
# 24      214.00                   550              119850                86250
# 25      217.40                    50              128750                82600
# 26      218.25                   100              128750                82600
# 27      217.20                    50              135850                82400
# 28      217.00                   200              136000                84100
# 29      218.10                    50              141150                84750
# 30      219.10                   400              142400                91450
# 31      220.00                    50              144150                85500
# 32      219.40                    50              143200                90100
# 33      221.10                    50              146100                87900
# 34      219.10                    50              147900                89700
# 35      218.80                    50              146650                92450
# 36      218.60                    50              150400                81050
# 37      219.00                    50              150800                82550
# 38      219.85                    50              154900                89700
# 39      220.40                   100              155550                82200
# 40      219.50                   100              153550                83950
# 41      220.00                    50              152000                81600
# 42      220.00                   100              146450                89550
# 43      219.10                    50              155000                90050
# 44      220.50                    50              152500                88300
# 45      221.25                    50              163550                83400
# 46      222.40                    50              162000                85200
# 47      220.95                    50              162050                86850
# 48      222.50                    50              163300                87450
# 49      222.00                   100              166050                86350
# 50      222.00                    50              162100                86950
# 51      222.00                   200              166100                83050
# 52      222.00                    50              168100                89250
# 53      222.40                    50              163100                89800
# 54      222.00                    50              169250                84950
# 55      223.00                   200              172800                83550
# 56      224.10                   400              172050                85450
#
#        last_trade_time       oi   volume  id    ch     vwch  cum_vwch  \
# 3  2024-03-15 09:15:04  1879800   2400.0   2   NaN      NaN       NaN
# 4  2024-03-15 09:15:05  1879800   6600.0   3 -5.05 -33330.0  -33330.0
# 5  2024-03-15 09:15:05  1879800   1850.0   3  4.60   8510.0  -24820.0
# 6  2024-03-15 09:15:06  1879800   6950.0   4 -3.10 -21545.0  -46365.0
# 7  2024-03-15 09:15:07  1879800   3350.0   5 -1.30  -4355.0  -50720.0
# 8  2024-03-15 09:15:08  1879800   1250.0   6 -1.75  -2187.5  -52907.5
# 9  2024-03-15 09:15:08  1879800    400.0   6 -1.25   -500.0  -53407.5
# 10 2024-03-15 09:15:09  1879800   3150.0   7  2.65   8347.5  -45060.0
# 11 2024-03-15 09:15:10  1879800   6750.0   8 -1.65 -11137.5  -56197.5
# 12 2024-03-15 09:15:10  1879800    600.0   8 -0.35   -210.0  -56407.5
# 13 2024-03-15 09:15:11  1879800   1650.0   9 -0.75  -1237.5  -57645.0
# 14 2024-03-15 09:15:11  1879800   1200.0   9  0.85   1020.0  -56625.0
# 15 2024-03-15 09:15:12  1879800   4850.0  10 -0.05   -242.5  -56867.5
# 16 2024-03-15 09:15:13  1879800   2950.0  11 -0.50  -1475.0  -58342.5
# 17 2024-03-15 09:15:13  1879800   1450.0  11 -1.50  -2175.0  -60517.5
# 18 2024-03-15 09:15:14  1879800  21500.0  12 -1.20 -25800.0  -86317.5
# 19 2024-03-15 09:15:14  1879800   1400.0  12 -0.45   -630.0  -86947.5
# 20 2024-03-15 09:15:15  1879800   7500.0  13  0.40   3000.0  -83947.5
# 21 2024-03-15 09:15:15  1879800      0.0  13  0.05      0.0  -83947.5
# 22 2024-03-15 09:15:16  1879800  22900.0  14  1.40  32060.0  -51887.5
# 23 2024-03-15 09:15:17  1879800   5850.0  15  0.10    585.0  -51302.5
# 24 2024-03-15 09:15:17  1879800   2250.0  15 -0.30   -675.0  -51977.5
# 25 2024-03-15 09:15:18  1879800  13950.0  16  3.40  47430.0   -4547.5
# 26 2024-03-15 09:15:18  1879800      0.0  16  0.85      0.0   -4547.5
# 27 2024-03-15 09:15:19  1906300  17450.0  17 -1.05 -18322.5  -22870.0
# 28 2024-03-15 09:15:20  1906300   6650.0  18 -0.20  -1330.0  -24200.0
# 29 2024-03-15 09:15:21  1906300   3300.0  19  1.10   3630.0  -20570.0
# 30 2024-03-15 09:15:21  1906300   3500.0  19  1.00   3500.0  -17070.0
# 31 2024-03-15 09:15:22  1906300   4900.0  20  0.90   4410.0  -12660.0
# 32 2024-03-15 09:15:23  1906300   2750.0  21 -0.60  -1650.0  -14310.0
# 33 2024-03-15 09:15:23  1906300    700.0  21  1.70   1190.0  -13120.0
# 34 2024-03-15 09:15:24  1906300   3050.0  22 -2.00  -6100.0  -19220.0
# 35 2024-03-15 09:15:25  1906300   5600.0  23 -0.30  -1680.0  -20900.0
# 36 2024-03-15 09:15:26  1906300   6050.0  24 -0.20  -1210.0  -22110.0
# 37 2024-03-15 09:15:26  1906300   1050.0  24  0.40    420.0  -21690.0
# 38 2024-03-15 09:15:27  1906300   6300.0  25  0.85   5355.0  -16335.0
# 39 2024-03-15 09:15:27  1906300   2550.0  25  0.55   1402.5  -14932.5
# 40 2024-03-15 09:15:28  1906300   2000.0  26 -0.90  -1800.0  -16732.5
# 41 2024-03-15 09:15:29  1906300  11450.0  27  0.50   5725.0  -11007.5
# 42 2024-03-15 09:15:29  1906300   1550.0  27  0.00      0.0  -11007.5
# 43 2024-03-15 09:15:30  1906300   2200.0  28 -0.90  -1980.0  -12987.5
# 44 2024-03-15 09:15:31  1906300   3650.0  29  1.40   5110.0   -7877.5
# 45 2024-03-15 09:15:32  1906300   2000.0  30  0.75   1500.0   -6377.5
# 46 2024-03-15 09:15:32  1906300   1150.0  30  1.15   1322.5   -5055.0
# 47 2024-03-15 09:15:33  1906300   3550.0  31 -1.45  -5147.5  -10202.5
# 48 2024-03-15 09:15:34  1906300  22400.0  32  1.55  34720.0   24517.5
# 49 2024-03-15 09:15:35  1906300   5150.0  33 -0.50  -2575.0   21942.5
# 50 2024-03-15 09:15:35  1906300   3450.0  33  0.00      0.0   21942.5
# 51 2024-03-15 09:15:36  1906300   4400.0  34  0.00      0.0   21942.5
# 52 2024-03-15 09:15:36  1906300   3350.0  34  0.00      0.0   21942.5
# 53 2024-03-15 09:15:37  1906300   3100.0  35  0.40   1240.0   23182.5
# 54 2024-03-15 09:15:37  1906300    950.0  35 -0.40   -380.0   22802.5
# 55 2024-03-15 09:15:38  1906300   9350.0  36  1.00   9350.0   32152.5
# 56 2024-03-15 09:15:39  1906300   9250.0  37  1.10  10175.0   42327.5
#
#      rolling_std
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10  15551.636063
# 11  10642.914282
# 12   9481.722549
# 13   5789.709776
# 14   5721.224166
# 15   5692.233692
# 16   5702.277688
# 17   4072.087843
# 18   9536.062302
# 19   9507.296368
# 20   9867.545393
# 21   9792.483375
# 22  16863.391492
# 23  16836.830271
# 24  16799.104887
# 25  19716.544811
# 26  19652.313841
# 27  22660.675760
# 28  22751.421221
# 29  20252.367344
# 30  20188.945739
# 31  20046.299883
# 32   7868.345923
# 33   7916.209692
# 34   3787.903680
# 35   3818.601090
# 36   3582.233940
# 37   3220.000000
# 38   3477.502696
# 39   3504.203980
# 40   3504.559488
# 41   3201.211592
# 42   3008.846233
# 43   3132.275103
# 44   3401.865516
# 45   3057.792981
# 46   3058.029682
# 47   3812.530445
# 48  13451.872779
# 49  13647.569566
# 50  13505.654294
# 51  13635.563718
# 52  13697.811011
# 53  13700.579813
# 54  13280.138365
# 55   3816.794498
# 56   4712.944813
