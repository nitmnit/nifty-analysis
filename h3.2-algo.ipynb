# %%
import base as b
import pandas as pd
import datetime as dt
from typing import Dict
import talib as ta
import utils as ut

settings = {
    "small_sma": 3,
    "big_sma": 10,
}

instrument = b.Instrument(name="NIFTY 22650 CALL 7 Mar 2024")

SYMBOL = "NIFTY"
expiry = dt.datetime.strptime("2024-03-21", "%Y-%m-%d").date()
otype = "CE"
strike = 22000
date = dt.datetime.strptime("2024-03-15", "%Y-%m-%d").date()

tdf = ut.get_ticks(symbol=SYMBOL, expiry=expiry, strike=strike, otype=otype, date=date)

# %%
class Phase(b.BasePhase):
    def __init__(self, initiated_at, strategy):
        super().__init__(initiated_at, strategy)

    def next(self, tick):
        if self.status == self.STATUS_INITIATED:
            pass
        else:
            pass

class PhaseStrategy(b.BasePhaseStrategy):
    def __init__(self, instrument: "Instrument", settings: Dict):
        super().__init__(instrument, settings)

    def next(self, tick: Dict):
        super().next(tick)
        self.ticks["small_sma"] = ta.SMA(self.ticks.volume, self.small_sma)
        self.ticks["big_sma"] = ta.SMA(self.ticks.volume, self.big_sma)

        if self.current_phase is None:
            self.current_phase = Phase(initiated_at=tick, strategy=self)
        else:
            self.current_phase.next(tick=tick)


pm = MyPhaseManager(instrument=instrument, settings=settings)
# for i in range(10):
for i in range(tdf.shape[0]):
    pm.next(tdf.iloc[i].to_dict())

print(pm.ticks)
# Out:
#       last_price  last_traded_quantity  total_buy_quantity  \
# 0           8.60                    50             1056650
# 1           8.65                   200             1055250
# 2           8.55                   150             1055650
# 3           8.60                   200             1055650
# 4           8.55                   100             1051800
# ...          ...                   ...                 ...
# 5913       12.80                   450              481450
# 5914       13.40                    50              466550
# 5915       13.35                    50              460900
# 5916       13.75                    50              460900
# 5917       13.45                    50              458800
#
#       total_sell_quantity     last_trade_time  volume
# 0                  464950 2024-03-06 14:16:31       0
# 1                  466300 2024-03-06 14:16:33    5400
# 2                  468200 2024-03-06 14:16:33    2300
# 3                  468200 2024-03-06 14:16:33       0
# 4                  471300 2024-03-06 14:16:34   16800
# ...                   ...                 ...     ...
# 5913               255700 2024-03-06 15:29:57       0
# 5914               244850 2024-03-06 15:29:58   39650
# 5915               244400 2024-03-06 15:29:59    1350
# 5916               244400 2024-03-06 15:29:59       0
# 5917               243400 2024-03-06 15:29:59    3850
#
# [5918 rows x 6 columns]

# %%
class ContinuationPhase(ph.Phase):
    def __init__(self, ticks, pm):
        self.phase_type = ph.Phase.TYPE_CONT
        self.t_start = ticks[0]
        self.t_end = ticks[-1]
        self.status = self.STATUS_INITIATED
        # self.min_pc = None
        self.direction = None
        self.pm = pm
        self.last_processed_tid = ticks[-1].id
        self.started_at = None
        self.terminated_at = None
        self.hard_retraced_at = None
        self.soft_retraced_at = None
        self.second_last_5sec = ph.Candle(ticks, confirm_ticks=self.pm.settings.CONFIRM_TICKS)
        self.last_5sec = ph.Candle([], confirm_ticks=self.pm.settings.CONFIRM_TICKS)
        self.up_sum, self.down_sum = self.get_sums(ticks)
        self.confidence_at_confirmation = None
        self.svac = 0 # Second last candle volume at confirmation
        self.lvac = 0 # last candle volume at confirmation

    def get_sums(self, ticks):
        if len(ticks) == 1:
            return 0, 0
        cur_price = ticks[0].last_price
        up_sum = down_sum = 0
        for i in range(1, len(ticks)):
            ch = ticks[i].last_price - cur_price
            if ch >= 0:
                up_sum += ch
            else:
                down_sum += ch
            cur_price = ticks[i].last_price
        return up_sum, down_sum

    @property
    def confidence(self):
        total = (self.up_sum + abs(self.down_sum))
        if total == 0:
            logger.info(f"u: {self.up_sum}, d: {self.down_sum}")
            return 0
        if self.direction == ph.Direction.UP:
            return self.up_sum * 100 / total
        return self.down_sum * 100 / total

    def start_phase(self):
        if len(self.last_5sec) < 1:
            return False
        is_red_breach = self.second_last_5sec.IS_RED and self.last_5sec.CLOSE >= self.second_last_5sec.OPEN
        is_green_breach = (not self.second_last_5sec.IS_RED) and self.last_5sec.CLOSE <= self.second_last_5sec.OPEN
        if is_red_breach or is_green_breach:
            raise ph.PhaseStartFailed(f'failed to start phase at: {self.last_5sec.end_id}')
        # if self.second_last_5sec.volume > self.last_5sec.volume:
        #     return False
        price_change = self.last_5sec.CLOSE - self.second_last_5sec.OPEN
        self.direction = ph.Direction.UP if price_change >= 0 else ph.Direction.DOWN
        # self.min_pc = Settings.MIN_UP_PC_CHG if price_change >= 0 else Settings.MIN_DOWN_PC_CHG
        self.status = self.STATUS_STARTED
        self.started_at = self.last_5sec[-1]
        self.confidence_at_confirmation = self.confidence
        self.svac = self.second_last_5sec.volume
        self.lvac = self.last_5sec.volume
        return True

    def update_sum(self):
        if self.t_start.id == 51463:
            print(f"before u: {self.up_sum}, d: {self.down_sum}")
        ch = self.pm.ticks[-1].last_price - self.pm.ticks[-2].last_price
        if ch >= 0:
            self.up_sum += ch
        else:
            self.down_sum += ch
        if self.t_start.id == 51463:
            print(f"after u: {self.up_sum}, d: {self.down_sum}, ch: {ch}, -1 id: {self.pm.ticks[-1].id}, -2 id: {self.pm.ticks[-2].id}")

    def process(self, tick):
        """
        if it breaks previous open or previous nth tick
        """
        self.last_processed_tid = tick.id
        self.update_last_nsec(tick)
        self.update_sum()
        self.t_end = tick
        if self.status == self.STATUS_INITIATED:
            has_started = self.start_phase()
            if not has_started:
                return
            self.pm.on_phase_start(self, tick)
            return
        elif self.status == self.STATUS_TERM or self.status == self.STATUS_HARD_RETR:
            return
        change = self.last_5sec.CLOSE - self.second_last_5sec.OPEN
        open_change = self.last_5sec.CLOSE - self.t_start.last_price
        last_5sec_breach = (self.direction == ph.Direction.UP and change < 0) or (self.direction == ph.Direction.DOWN and change > 0)
        open_breach = (self.direction == ph.Direction.UP and open_change < 0) or (self.direction == ph.Direction.DOWN and open_change > 0)
        if last_5sec_breach or open_breach:
            self.status = self.STATUS_HARD_RETR
            self.hard_retraced_at = tick
            raise ph.PhaseHardRetraceException(f"Continuation Phase {self} hard retracing at: {tick}")
        self.status = self.STATUS_ONG

# %%
class MyPhaseManager(ph.PhaseManager):
    def __init__(self, instrument, settings):
        super().__init__(instrument, settings)

    def process(self, tick):
        if self.current_phase is None:
            # First call
            self.current_phase = ContinuationPhase(ticks=[tick], pm=self)
            return
        # Has existing phase
        try:
            self.current_phase.process(tick)
            self.on_ongoing(self.current_phase, tick)
        except ph.PhaseSoftRetraceException:
            self.on_soft_retracel(self.current_phase, tick)
        except ph.PhaseHardRetraceException:
            self.on_hard_retracel(self.current_phase, tick)
            self.ps.append(self.current_phase)
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        except ph.PhaseTerminatedException:
            self.on_hard_retracel(self.current_phase, tick)
            self.on_termination(self.current_phase, tick)
            self.aps.append(self.current_phase)
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        except ph.PhaseStartFailed:
            # logger.info(f"phase start failed at: {tick}, phase: {self.current_phase}")
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        # self.process_ps(tick)

    def process_ps(self, tick):
        # Process for process stack
        mark_for_removal = []
        for i in range(len(self.ps)):
            phase = self.ps[i]
            try:
                phase.process(tick)
            except ph.PhaseSoftRetraceException:
                # logger.info(f"soft retracel of {phase}")
                pass
            except ph.PhaseHardRetraceException:
                pass
            except ph.PhaseTerminatedException:
                mark_for_removal.append(i)
                self.aps.append(phase)
        mark_for_removal.reverse()
        for mark in mark_for_removal:
            del self.ps[mark]

    def on_phase_start(self, phase, tick):
        self.current_order = ph.Order(type=ph.Order.TYPE_BUY, limit_price=tick.last_price, quantity=Settings.QUANTITY)

    def on_hard_retracel(self, phase, tick):
        if phase.direction == ph.Direction.UP:
            if self.current_order is not None:
                self.current_order.square_off(tick.last_price)
                self.closed_orders.append(ph.PhaseOrder(phase, self.current_order))
                self.current_order = None
            logger.info(f"Retracel {phase}, Up change %: {phase.hard_retraced_at.last_price - phase.started_at.last_price}")
        else:
            logger.info(f"Retracel {phase}, Down change %: {phase.started_at.last_price - phase.hard_retraced_at.last_price}")

instrument = ph.Instrument(name="NIFTY 22650 CALL 7 Mar 2024")
pm = MyPhaseManager(instrument=instrument, settings=Settings)
# for i in range(100):
for i in range(tdf.shape[0]):
    pm.next(tdf.iloc[i].to_dict())

print(pm.current_phase)
# print(pm.ps)
# print(pm.aps)
# Out:
# 2024-03-14 04:38:44,705 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51391 8.6, v: 0.0 to Tick: 51410 8.45, v: 5600.0, confirmation:Tick: 51397 8.5, v: 4100.0 terminated at: None, hard retracel: Tick: 51410 8.45, v: 5600.0, soft: None, conf: -62.50000000000006, Down change %: 0.05000000000000071
# 2024-03-14 04:38:44,710 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51405 8.4, v: 17850.0 to Tick: 51428 8.65, v: 8600.0, confirmation:Tick: 51410 8.45, v: 0.0 terminated at: None, hard retracel: Tick: 51428 8.65, v: 8600.0, soft: None, conf: 59.99999999999986, Up change %: 0.20000000000000107
# 2024-03-14 04:38:44,716 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51423 8.85, v: 2550.0 to Tick: 51467 7.9, v: 2600.0, confirmation:Tick: 51429 8.65, v: 18100.0 terminated at: None, hard retracel: Tick: 51467 7.9, v: 2600.0, soft: None, conf: -83.33333333333313, Down change %: 0.75
# 2024-03-14 04:38:44,718 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51463 7.6, v: 11650.0 to Tick: 51475 7.5, v: 4850.0, confirmation:Tick: 51469 7.75, v: 0.0 terminated at: None, hard retracel: Tick: 51475 7.5, v: 4850.0, soft: None, conf: 63.636363636363654, Up change %: -0.25
# 2024-03-14 04:38:44,720 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51470 7.7, v: 1100.0 to Tick: 51484 7.85, v: 0.0, confirmation:Tick: 51475 7.6, v: 0.0 terminated at: None, hard retracel: Tick: 51484 7.85, v: 0.0, soft: None, conf: -62.50000000000003, Down change %: -0.25
# 2024-03-14 04:38:44,729 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51479 7.3, v: 13600.0 to Tick: 51509 8.0, v: 7700.0, confirmation:Tick: 51486 7.9, v: 14200.0 terminated at: None, hard retracel: Tick: 51509 8.0, v: 7700.0, soft: None, conf: 77.27272727272728, Up change %: 0.09999999999999964
# 2024-03-14 04:38:44,736 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51506 8.5, v: 6450.0 to Tick: 51524 7.9, v: 3100.0, confirmation:Tick: 51511 7.75, v: 0.0 terminated at: None, hard retracel: Tick: 51524 7.9, v: 3100.0, soft: None, conf: -85.71428571428564, Down change %: -0.15000000000000036
# 2024-03-14 04:38:44,739 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51521 7.65, v: 12750.0 to Tick: 51528 7.5, v: 12450.0, confirmation:Tick: 51526 7.85, v: 2100.0 terminated at: None, hard retracel: Tick: 51528 7.5, v: 12450.0, soft: None, conf: 64.28571428571425, Up change %: -0.34999999999999964
# 2024-03-14 04:38:44,744 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51523 7.8, v: 1500.0 to Tick: 51540 7.6, v: 10450.0, confirmation:Tick: 51528 7.5, v: 0.0 terminated at: None, hard retracel: Tick: 51540 7.6, v: 10450.0, soft: None, conf: -66.66666666666667, Down change %: -0.09999999999999964
# 2024-03-14 04:38:44,749 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51535 7.45, v: 2600.0 to Tick: 51555 7.75, v: 14700.0, confirmation:Tick: 51540 7.65, v: 0.0 terminated at: None, hard retracel: Tick: 51555 7.75, v: 14700.0, soft: None, conf: 64.28571428571429, Up change %: 0.09999999999999964
# 2024-03-14 04:38:44,754 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51551 7.9, v: 4350.0 to Tick: 51567 8.0, v: 8250.0, confirmation:Tick: 51557 7.7, v: 1750.0 terminated at: None, hard retracel: Tick: 51567 8.0, v: 8250.0, soft: None, conf: -64.28571428571429, Down change %: -0.2999999999999998
# 2024-03-14 04:38:44,759 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51562 7.65, v: 300.0 to Tick: 51586 8.25, v: 700.0, confirmation:Tick: 51567 8.1, v: 5350.0 terminated at: None, hard retracel: Tick: 51586 8.25, v: 700.0, soft: None, conf: 84.61538461538464, Up change %: 0.15000000000000036
# 2024-03-14 04:38:44,766 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51581 8.55, v: 38400.0 to Tick: 51611 8.15, v: 3550.0, confirmation:Tick: 51587 8.15, v: 10950.0 terminated at: None, hard retracel: Tick: 51611 8.15, v: 3550.0, soft: None, conf: -100.0, Down change %: 0.0
# 2024-03-14 04:38:44,774 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51608 7.9, v: 1150.0 to Tick: 51631 8.05, v: 3300.0, confirmation:Tick: 51613 7.95, v: 4300.0 terminated at: None, hard retracel: Tick: 51631 8.05, v: 3300.0, soft: None, conf: 53.84615384615383, Up change %: 0.10000000000000053
# 2024-03-14 04:38:44,788 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51627 8.1, v: 7150.0 to Tick: 51654 7.95, v: 2800.0, confirmation:Tick: 51632 8.05, v: 0.0 terminated at: None, hard retracel: Tick: 51654 7.95, v: 2800.0, soft: None, conf: -57.142857142857, Down change %: 0.10000000000000053
# 2024-03-14 04:38:44,796 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51650 7.75, v: 950.0 to Tick: 51678 8.45, v: 3100.0, confirmation:Tick: 51656 7.8, v: 6200.0 terminated at: None, hard retracel: Tick: 51678 8.45, v: 3100.0, soft: None, conf: 55.555555555555536, Up change %: 0.6499999999999995
# 2024-03-14 04:38:44,806 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51673 8.6, v: 17750.0 to Tick: 51707 8.0, v: 4000.0, confirmation:Tick: 51679 8.5, v: 5800.0 terminated at: None, hard retracel: Tick: 51707 8.0, v: 4000.0, soft: None, conf: -59.99999999999993, Down change %: 0.5
# 2024-03-14 04:38:44,812 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51703 7.8, v: 3550.0 to Tick: 51722 8.05, v: 2800.0, confirmation:Tick: 51708 8.1, v: 800.0 terminated at: None, hard retracel: Tick: 51722 8.05, v: 2800.0, soft: None, conf: 71.42857142857147, Up change %: -0.049999999999998934
# 2024-03-14 04:38:44,823 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51717 8.15, v: 2250.0 to Tick: 51730 8.15, v: 15250.0, confirmation:Tick: 51723 7.9, v: 4850.0 terminated at: None, hard retracel: Tick: 51730 8.15, v: 15250.0, soft: None, conf: -72.72727272727285, Down change %: -0.25
# 2024-03-14 04:38:44,827 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51725 7.9, v: 4750.0 to Tick: 51740 8.1, v: 2350.0, confirmation:Tick: 51731 8.2, v: 1650.0 terminated at: None, hard retracel: Tick: 51740 8.1, v: 2350.0, soft: None, conf: 68.74999999999991, Up change %: -0.09999999999999964
# 2024-03-14 04:38:44,833 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51737 8.0, v: 4600.0 to Tick: 51750 7.95, v: 0.0, confirmation:Tick: 51743 8.1, v: 1000.0 terminated at: None, hard retracel: Tick: 51750 7.95, v: 0.0, soft: None, conf: 62.49999999999994, Up change %: -0.14999999999999947
# 2024-03-14 04:38:44,840 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51745 8.3, v: 1550.0 to Tick: 51770 7.6, v: 2250.0, confirmation:Tick: 51752 8.05, v: 10600.0 terminated at: None, hard retracel: Tick: 51770 7.6, v: 2250.0, soft: None, conf: -66.66666666666663, Down change %: 0.45000000000000107
# 2024-03-14 04:38:44,844 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51765 7.7, v: 3250.0 to Tick: 51773 7.65, v: 0.0, confirmation:Tick: 51771 7.75, v: 2550.0 terminated at: None, hard retracel: Tick: 51773 7.65, v: 0.0, soft: None, conf: 53.333333333333314, Up change %: -0.09999999999999964
# 2024-03-14 04:38:44,849 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51768 7.55, v: 13200.0 to Tick: 51782 7.65, v: 0.0, confirmation:Tick: 51774 7.7, v: 1000.0 terminated at: None, hard retracel: Tick: 51782 7.65, v: 0.0, soft: None, conf: 63.636363636363654, Up change %: -0.04999999999999982
# 2024-03-14 04:38:44,856 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51777 7.9, v: 1250.0 to Tick: 51796 7.6, v: 7600.0, confirmation:Tick: 51783 7.6, v: 6700.0 terminated at: None, hard retracel: Tick: 51796 7.6, v: 7600.0, soft: None, conf: -79.99999999999997, Down change %: 0.0
# 2024-03-14 04:38:44,864 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51791 7.5, v: 1400.0 to Tick: 51819 8.3, v: 2650.0, confirmation:Tick: 51797 7.55, v: 4250.0 terminated at: None, hard retracel: Tick: 51819 8.3, v: 2650.0, soft: None, conf: 53.333333333333336, Up change %: 0.7500000000000009
# 2024-03-14 04:38:44,868 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51814 8.35, v: 7500.0 to Tick: 51827 8.45, v: 14050.0, confirmation:Tick: 51820 8.25, v: 8150.0 terminated at: None, hard retracel: Tick: 51827 8.45, v: 14050.0, soft: None, conf: -74.99999999999977, Down change %: -0.1999999999999993
# 2024-03-14 04:38:44,880 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51822 8.2, v: 2450.0 to Tick: 51854 8.75, v: 21450.0, confirmation:Tick: 51828 8.45, v: 4350.0 terminated at: None, hard retracel: Tick: 51854 8.75, v: 21450.0, soft: None, conf: 77.77777777777783, Up change %: 0.3000000000000007
# 2024-03-14 04:38:44,885 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51849 9.2, v: 12300.0 to Tick: 51864 9.05, v: 9400.0, confirmation:Tick: 51855 8.65, v: 25550.0 terminated at: None, hard retracel: Tick: 51864 9.05, v: 9400.0, soft: None, conf: -78.94736842105254, Down change %: -0.40000000000000036
# 2024-03-14 04:38:44,891 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51860 9.2, v: 15500.0 to Tick: 51880 8.65, v: 10600.0, confirmation:Tick: 51866 8.9, v: 6650.0 terminated at: None, hard retracel: Tick: 51880 8.65, v: 10600.0, soft: None, conf: -74.99999999999993, Down change %: 0.25
# 2024-03-14 04:38:44,901 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51876 8.85, v: 16600.0 to Tick: 51906 8.25, v: 2550.0, confirmation:Tick: 51881 8.6, v: 0.0 terminated at: None, hard retracel: Tick: 51906 8.25, v: 2550.0, soft: None, conf: -66.66666666666667, Down change %: 0.34999999999999964
# 2024-03-14 04:38:44,904 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51901 8.15, v: 8800.0 to Tick: 51911 8.1, v: 13550.0, confirmation:Tick: 51906 8.4, v: 0.0 terminated at: None, hard retracel: Tick: 51911 8.1, v: 13550.0, soft: None, conf: 72.72727272727269, Up change %: -0.3000000000000007
# 2024-03-14 04:38:44,908 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51906 8.25, v: 2550.0 to Tick: 51920 8.3, v: 3450.0, confirmation:Tick: 51912 8.05, v: 4600.0 terminated at: None, hard retracel: Tick: 51920 8.3, v: 3450.0, soft: None, conf: -64.28571428571425, Down change %: -0.25
# 2024-03-14 04:38:44,911 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51915 8.2, v: 6250.0 to Tick: 51927 8.0, v: 22600.0, confirmation:Tick: 51921 8.25, v: 2700.0 terminated at: None, hard retracel: Tick: 51927 8.0, v: 22600.0, soft: None, conf: 57.14285714285722, Up change %: -0.25
# 2024-03-14 04:38:44,915 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51922 8.4, v: 11150.0 to Tick: 51939 8.15, v: 3200.0, confirmation:Tick: 51928 7.85, v: 16950.0 terminated at: None, hard retracel: Tick: 51939 8.15, v: 3200.0, soft: None, conf: -100.0, Down change %: -0.3000000000000007
# 2024-03-14 04:38:44,918 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51934 7.75, v: 3150.0 to Tick: 51948 7.9, v: 2050.0, confirmation:Tick: 51940 8.15, v: 8500.0 terminated at: None, hard retracel: Tick: 51948 7.9, v: 2050.0, soft: None, conf: 78.57142857142863, Up change %: -0.25
# before u: 0.35000000000000053, d: -0.04999999999999982
# after u: 0.35000000000000053, d: -0.15000000000000036, ch: -0.10000000000000053, -1 id: 51469, -2 id: 51467
# before u: 0.35000000000000053, d: -0.15000000000000036
# after u: 0.35000000000000053, d: -0.20000000000000018, ch: -0.04999999999999982, -1 id: 51469, -2 id: 51469
# before u: 0.35000000000000053, d: -0.20000000000000018
# after u: 0.35000000000000053, d: -0.25, ch: -0.04999999999999982, -1 id: 51470, -2 id: 51469
# before u: 0.35000000000000053, d: -0.25
# after u: 0.35000000000000053, d: -0.25, ch: 0.0, -1 id: 51470, -2 id: 51470
# before u: 0.35000000000000053, d: -0.25
# after u: 0.35000000000000053, d: -0.35000000000000053, ch: -0.10000000000000053, -1 id: 51471, -2 id: 51470
# before u: 0.35000000000000053, d: -0.35000000000000053
# after u: 0.40000000000000124, d: -0.35000000000000053, ch: 0.05000000000000071, -1 id: 51471, -2 id: 51471
# before u: 0.40000000000000124, d: -0.35000000000000053
# after u: 0.40000000000000124, d: -0.40000000000000124, ch: -0.05000000000000071, -1 id: 51472, -2 id: 51471
# before u: 0.40000000000000124, d: -0.40000000000000124
# after u: 0.40000000000000124, d: -0.40000000000000124, ch: 0.0, -1 id: 51473, -2 id: 51472
# before u: 0.40000000000000124, d: -0.40000000000000124
# after u: 0.40000000000000124, d: -0.5000000000000009, ch: -0.09999999999999964, -1 id: 51475, -2 id: 51473
# 2024-03-14 04:38:44,926 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51943 8.0, v: 2200.0 to Tick: 51957 8.05, v: 4950.0, confirmation:Tick: 51948 7.8, v: 0.0 terminated at: None, hard retracel: Tick: 51957 8.05, v: 4950.0, soft: None, conf: -66.66666666666671, Down change %: -0.2500000000000009
# 2024-03-14 04:38:44,931 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51952 7.9, v: 3100.0 to Tick: 51966 7.85, v: 0.0, confirmation:Tick: 51958 7.95, v: 3500.0 terminated at: None, hard retracel: Tick: 51966 7.85, v: 0.0, soft: None, conf: 55.55555555555549, Up change %: -0.10000000000000053
# 2024-03-14 04:38:44,933 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51961 7.95, v: 2050.0 to Tick: 51969 8.25, v: 9300.0, confirmation:Tick: 51967 7.8, v: 7350.0 terminated at: None, hard retracel: Tick: 51969 8.25, v: 9300.0, soft: None, conf: -58.82352941176473, Down change %: -0.4500000000000002
# 2024-03-14 04:38:44,945 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51964 8.1, v: 5600.0 to Tick: 51980 8.2, v: 2400.0, confirmation:Tick: 51969 8.25, v: 0.0 terminated at: None, hard retracel: Tick: 51980 8.2, v: 2400.0, soft: None, conf: 60.00000000000002, Up change %: -0.05000000000000071
# 2024-03-14 04:38:44,949 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51975 8.4, v: 7100.0 to Tick: 51986 8.5, v: 14350.0, confirmation:Tick: 51980 8.2, v: 0.0 terminated at: None, hard retracel: Tick: 51986 8.5, v: 14350.0, soft: None, conf: -75.00000000000011, Down change %: -0.3000000000000007
# 2024-03-14 04:38:44,955 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51981 8.25, v: 2750.0 to Tick: 51997 8.3, v: 850.0, confirmation:Tick: 51987 8.4, v: 5100.0 terminated at: None, hard retracel: Tick: 51997 8.3, v: 850.0, soft: None, conf: 61.53846153846156, Up change %: -0.09999999999999964
# 2024-03-14 04:38:44,959 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51992 8.45, v: 5800.0 to Tick: 52006 8.35, v: 1550.0, confirmation:Tick: 51998 8.35, v: 2550.0 terminated at: None, hard retracel: Tick: 52006 8.35, v: 1550.0, soft: None, conf: -66.66666666666687, Down change %: 0.0
# 2024-03-14 04:38:44,961 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52003 8.35, v: 2900.0 to Tick: 52010 8.25, v: 300.0, confirmation:Tick: 52008 8.5, v: 0.0 terminated at: None, hard retracel: Tick: 52010 8.25, v: 300.0, soft: None, conf: 60.0, Up change %: -0.25
# 2024-03-14 04:38:44,969 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52006 8.35, v: 1550.0 to Tick: 52034 8.05, v: 9750.0, confirmation:Tick: 52011 8.25, v: 0.0 terminated at: None, hard retracel: Tick: 52034 8.05, v: 9750.0, soft: None, conf: -55.555555555555536, Down change %: 0.1999999999999993
# 2024-03-14 04:38:44,985 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52030 7.8, v: 5350.0 to Tick: 52058 8.25, v: 1750.0, confirmation:Tick: 52035 8.05, v: 0.0 terminated at: None, hard retracel: Tick: 52058 8.25, v: 1750.0, soft: None, conf: 64.70588235294126, Up change %: 0.1999999999999993
# 2024-03-14 04:38:44,987 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52053 8.3, v: 100.0 to Tick: 52059 8.4, v: 4000.0, confirmation:Tick: 52058 8.25, v: 1850.0 terminated at: None, hard retracel: Tick: 52059 8.4, v: 4000.0, soft: None, conf: -55.55555555555564, Down change %: -0.15000000000000036
# 2024-03-14 04:38:44,997 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52055 8.4, v: 4600.0 to Tick: 52074 8.1, v: 3800.0, confirmation:Tick: 52060 8.2, v: 0.0 terminated at: None, hard retracel: Tick: 52074 8.1, v: 3800.0, soft: None, conf: -70.00000000000003, Down change %: 0.09999999999999964
# 2024-03-14 04:38:45,002 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52069 8.0, v: 2800.0 to Tick: 52082 7.9, v: 0.0, confirmation:Tick: 52075 8.1, v: 100.0 terminated at: None, hard retracel: Tick: 52082 7.9, v: 0.0, soft: None, conf: 66.66666666666667, Up change %: -0.1999999999999993
# 2024-03-14 04:38:45,012 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52077 8.05, v: 100.0 to Tick: 52097 7.95, v: 100.0, confirmation:Tick: 52084 7.9, v: 11400.0 terminated at: None, hard retracel: Tick: 52097 7.95, v: 100.0, soft: None, conf: -63.6363636363637, Down change %: -0.04999999999999982
# 2024-03-14 04:38:45,016 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52094 7.95, v: 1350.0 to Tick: 52105 8.05, v: 29800.0, confirmation:Tick: 52099 7.8, v: 0.0 terminated at: None, hard retracel: Tick: 52105 8.05, v: 29800.0, soft: None, conf: -71.42857142857139, Down change %: -0.2500000000000009
# 2024-03-14 04:38:45,019 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52100 7.85, v: 20350.0 to Tick: 52110 7.75, v: 36150.0, confirmation:Tick: 52105 8.05, v: 0.0 terminated at: None, hard retracel: Tick: 52110 7.75, v: 36150.0, soft: None, conf: 75.0, Up change %: -0.3000000000000007
# 2024-03-14 04:38:45,027 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52105 8.05, v: 29800.0 to Tick: 52123 7.75, v: 1000.0, confirmation:Tick: 52110 7.75, v: 500.0 terminated at: None, hard retracel: Tick: 52123 7.75, v: 1000.0, soft: None, conf: -100.0, Down change %: 0.0
# 2024-03-14 04:38:45,037 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52118 7.45, v: 6500.0 to Tick: 52137 7.85, v: 2150.0, confirmation:Tick: 52123 7.7, v: 0.0 terminated at: None, hard retracel: Tick: 52137 7.85, v: 2150.0, soft: None, conf: 77.77777777777771, Up change %: 0.14999999999999947
# 2024-03-14 04:38:45,045 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52132 8.0, v: 4600.0 to Tick: 52148 7.9, v: 6550.0, confirmation:Tick: 52139 7.85, v: 3250.0 terminated at: None, hard retracel: Tick: 52148 7.9, v: 6550.0, soft: None, conf: -71.42857142857129, Down change %: -0.05000000000000071
# 2024-03-14 04:38:45,050 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52143 7.75, v: 2050.0 to Tick: 52156 7.8, v: 2600.0, confirmation:Tick: 52148 7.85, v: 3750.0 terminated at: None, hard retracel: Tick: 52156 7.8, v: 2600.0, soft: None, conf: 62.499999999999886, Up change %: -0.04999999999999982
# 2024-03-14 04:38:45,052 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52151 7.9, v: 6750.0 to Tick: 52158 8.0, v: 1750.0, confirmation:Tick: 52156 7.85, v: 400.0 terminated at: None, hard retracel: Tick: 52158 8.0, v: 1750.0, soft: None, conf: -60.00000000000014, Down change %: -0.15000000000000036
# 2024-03-14 04:38:45,072 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52153 7.75, v: 8800.0 to Tick: 52194 8.4, v: 6550.0, confirmation:Tick: 52158 7.95, v: 0.0 terminated at: None, hard retracel: Tick: 52194 8.4, v: 6550.0, soft: None, conf: 83.33333333333339, Up change %: 0.4500000000000002
# 2024-03-14 04:38:45,076 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52189 8.55, v: 5000.0 to Tick: 52197 8.6, v: 0.0, confirmation:Tick: 52194 8.4, v: 0.0 terminated at: None, hard retracel: Tick: 52197 8.6, v: 0.0, soft: None, conf: -71.4285714285715, Down change %: -0.1999999999999993
# 2024-03-14 04:38:45,093 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52192 8.6, v: 5900.0 to Tick: 52205 8.45, v: 2200.0, confirmation:Tick: 52198 8.5, v: 6300.0 terminated at: None, hard retracel: Tick: 52205 8.45, v: 2200.0, soft: None, conf: -57.142857142857146, Down change %: 0.05000000000000071
# 2024-03-14 04:38:45,099 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52201 8.35, v: 9700.0 to Tick: 52222 9.05, v: 15600.0, confirmation:Tick: 52208 8.5, v: 19450.0 terminated at: None, hard retracel: Tick: 52222 9.05, v: 15600.0, soft: None, conf: 61.53846153846156, Up change %: 0.5500000000000007
# 2024-03-14 04:38:45,101 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52217 9.0, v: 14100.0 to Tick: 52226 8.95, v: 0.0, confirmation:Tick: 52222 9.05, v: 0.0 terminated at: None, hard retracel: Tick: 52226 8.95, v: 0.0, soft: None, conf: 57.14285714285722, Up change %: -0.10000000000000142
# 2024-03-14 04:38:45,104 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52222 9.05, v: 15600.0 to Tick: 52234 9.1, v: 21850.0, confirmation:Tick: 52227 8.9, v: 0.0 terminated at: None, hard retracel: Tick: 52234 9.1, v: 21850.0, soft: None, conf: -61.53846153846156, Down change %: -0.1999999999999993
# 2024-03-14 04:38:45,107 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52229 8.8, v: 8000.0 to Tick: 52238 8.75, v: 9200.0, confirmation:Tick: 52235 9.05, v: 17300.0 terminated at: None, hard retracel: Tick: 52238 8.75, v: 9200.0, soft: None, conf: 69.23076923076938, Up change %: -0.3000000000000007
# 2024-03-14 04:38:45,116 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52235 9.05, v: 17300.0 to Tick: 52262 9.7, v: 9150.0, confirmation:Tick: 52240 9.1, v: 0.0 terminated at: None, hard retracel: Tick: 52262 9.7, v: 9150.0, soft: None, conf: 52.941176470588175, Up change %: 0.5999999999999996
# 2024-03-14 04:38:45,119 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52259 9.8, v: 34800.0 to Tick: 52266 9.9, v: 0.0, confirmation:Tick: 52264 9.75, v: 0.0 terminated at: None, hard retracel: Tick: 52266 9.9, v: 0.0, soft: None, conf: -53.333333333333364, Down change %: -0.15000000000000036
# 2024-03-14 04:38:45,123 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52262 9.7, v: 9150.0 to Tick: 52274 9.6, v: 28850.0, confirmation:Tick: 52267 10.0, v: 0.0 terminated at: None, hard retracel: Tick: 52274 9.6, v: 28850.0, soft: None, conf: 79.99999999999986, Up change %: -0.40000000000000036
# 2024-03-14 04:38:45,127 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52269 9.9, v: 19750.0 to Tick: 52285 9.7, v: 51050.0, confirmation:Tick: 52275 9.55, v: 19400.0 terminated at: None, hard retracel: Tick: 52285 9.7, v: 51050.0, soft: None, conf: -88.88888888888907, Down change %: -0.14999999999999858
# 2024-03-14 04:38:45,130 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52280 9.55, v: 6550.0 to Tick: 52290 9.45, v: 20000.0, confirmation:Tick: 52285 9.8, v: 0.0 terminated at: None, hard retracel: Tick: 52290 9.45, v: 20000.0, soft: None, conf: 69.23076923076917, Up change %: -0.3500000000000014
# 2024-03-14 04:38:45,134 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52285 9.7, v: 51050.0 to Tick: 52297 9.75, v: 12250.0, confirmation:Tick: 52291 9.4, v: 8200.0 terminated at: None, hard retracel: Tick: 52297 9.75, v: 12250.0, soft: None, conf: -64.99999999999991, Down change %: -0.34999999999999964
# 2024-03-14 04:38:45,139 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52293 9.25, v: 8100.0 to Tick: 52311 10.35, v: 2800.0, confirmation:Tick: 52299 9.85, v: 10600.0 terminated at: None, hard retracel: Tick: 52311 10.35, v: 2800.0, soft: None, conf: 92.85714285714299, Up change %: 0.5
# 2024-03-14 04:38:45,142 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52306 10.4, v: 31850.0 to Tick: 52315 10.75, v: 40500.0, confirmation:Tick: 52311 10.35, v: 0.0 terminated at: None, hard retracel: Tick: 52315 10.75, v: 40500.0, soft: None, conf: -57.14285714285729, Down change %: -0.40000000000000036
# 2024-03-14 04:38:45,148 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52310 10.25, v: 17100.0 to Tick: 52330 10.65, v: 0.0, confirmation:Tick: 52316 10.95, v: 36250.0 terminated at: None, hard retracel: Tick: 52330 10.65, v: 0.0, soft: None, conf: 88.8888888888889, Up change %: -0.29999999999999893
# 2024-03-14 04:38:45,155 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52326 11.0, v: 63350.0 to Tick: 52336 11.1, v: 0.0, confirmation:Tick: 52331 10.9, v: 0.0 terminated at: None, hard retracel: Tick: 52336 11.1, v: 0.0, soft: None, conf: -57.142857142857146, Down change %: -0.1999999999999993
# 2024-03-14 04:38:45,157 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52331 10.95, v: 25200.0 to Tick: 52339 10.9, v: 9950.0, confirmation:Tick: 52338 11.0, v: 32450.0 terminated at: None, hard retracel: Tick: 52339 10.9, v: 9950.0, soft: None, conf: 53.84615384615391, Up change %: -0.09999999999999964
# 2024-03-14 04:38:45,161 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52334 10.9, v: 16400.0 to Tick: 52346 11.15, v: 65600.0, confirmation:Tick: 52340 10.75, v: 25300.0 terminated at: None, hard retracel: Tick: 52346 11.15, v: 65600.0, soft: None, conf: -58.82352941176473, Down change %: -0.40000000000000036
# 2024-03-14 04:38:45,167 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52341 10.75, v: 12850.0 to Tick: 52363 11.75, v: 19250.0, confirmation:Tick: 52347 11.35, v: 8700.0 terminated at: None, hard retracel: Tick: 52363 11.75, v: 19250.0, soft: None, conf: 80.00000000000003, Up change %: 0.40000000000000036
# 2024-03-14 04:38:45,172 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52358 12.35, v: 39950.0 to Tick: 52376 11.95, v: 15700.0, confirmation:Tick: 52363 11.8, v: 0.0 terminated at: None, hard retracel: Tick: 52376 11.95, v: 15700.0, soft: None, conf: -82.35294117647054, Down change %: -0.14999999999999858
# 2024-03-14 04:38:45,177 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52371 11.35, v: 6650.0 to Tick: 52391 12.75, v: 22850.0, confirmation:Tick: 52377 12.0, v: 35500.0 terminated at: None, hard retracel: Tick: 52391 12.75, v: 22850.0, soft: None, conf: 80.95238095238089, Up change %: 0.75
# 2024-03-14 04:38:45,179 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52386 12.9, v: 62600.0 to Tick: 52393 13.0, v: 17100.0, confirmation:Tick: 52392 12.8, v: 39050.0 terminated at: None, hard retracel: Tick: 52393 13.0, v: 17100.0, soft: None, conf: -54.16666666666664, Down change %: -0.1999999999999993
# 2024-03-14 04:38:45,183 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52388 12.25, v: 11500.0 to Tick: 52404 12.9, v: 23100.0, confirmation:Tick: 52394 12.95, v: 20350.0 terminated at: None, hard retracel: Tick: 52404 12.9, v: 23100.0, soft: None, conf: 93.74999999999991, Up change %: -0.049999999999998934
# 2024-03-14 04:38:45,185 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52399 12.7, v: 23450.0 to Tick: 52407 12.65, v: 22800.0, confirmation:Tick: 52405 12.95, v: 24350.0 terminated at: None, hard retracel: Tick: 52407 12.65, v: 22800.0, soft: None, conf: 60.86956521739129, Up change %: -0.29999999999999893
# 2024-03-14 04:38:45,187 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52402 13.1, v: 12450.0 to Tick: 52410 13.15, v: 0.0, confirmation:Tick: 52408 12.65, v: 5050.0 terminated at: None, hard retracel: Tick: 52410 13.15, v: 0.0, soft: None, conf: -76.47058823529414, Down change %: -0.5
# 2024-03-14 04:38:45,190 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52405 12.95, v: 24350.0 to Tick: 52418 12.9, v: 8700.0, confirmation:Tick: 52411 13.15, v: 21150.0 terminated at: None, hard retracel: Tick: 52418 12.9, v: 8700.0, soft: None, conf: 61.111111111111164, Up change %: -0.25
# 2024-03-14 04:38:45,198 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52413 13.1, v: 21450.0 to Tick: 52440 12.2, v: 11800.0, confirmation:Tick: 52419 12.85, v: 17350.0 terminated at: None, hard retracel: Tick: 52440 12.2, v: 11800.0, soft: None, conf: -85.71428571428557, Down change %: 0.6500000000000004
# 2024-03-14 04:38:45,203 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52435 12.05, v: 33850.0 to Tick: 52459 13.2, v: 7550.0, confirmation:Tick: 52441 12.25, v: 9650.0 terminated at: None, hard retracel: Tick: 52459 13.2, v: 7550.0, soft: None, conf: 59.99999999999993, Up change %: 0.9499999999999993
# 2024-03-14 04:38:45,212 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52454 12.9, v: 8550.0 to Tick: 52485 14.15, v: 21550.0, confirmation:Tick: 52459 13.2, v: 0.0 terminated at: None, hard retracel: Tick: 52485 14.15, v: 21550.0, soft: None, conf: 64.99999999999991, Up change %: 0.9500000000000011
# 2024-03-14 04:38:45,215 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52480 14.55, v: 32300.0 to Tick: 52492 14.55, v: 37100.0, confirmation:Tick: 52486 14.0, v: 59300.0 terminated at: None, hard retracel: Tick: 52492 14.55, v: 37100.0, soft: None, conf: -78.9473684210528, Down change %: -0.5500000000000007
# 2024-03-14 04:38:45,218 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52487 13.85, v: 52550.0 to Tick: 52503 14.25, v: 16450.0, confirmation:Tick: 52493 14.55, v: 13800.0 terminated at: None, hard retracel: Tick: 52503 14.25, v: 16450.0, soft: None, conf: 84.99999999999999, Up change %: -0.3000000000000007
# 2024-03-14 04:38:45,221 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52498 14.1, v: 6300.0 to Tick: 52509 14.0, v: 15200.0, confirmation:Tick: 52504 14.3, v: 17850.0 terminated at: None, hard retracel: Tick: 52509 14.0, v: 15200.0, soft: None, conf: 58.33333333333334, Up change %: -0.3000000000000007
# 2024-03-14 04:38:45,224 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52504 14.3, v: 17850.0 to Tick: 52520 14.15, v: 7200.0, confirmation:Tick: 52510 13.45, v: 80550.0 terminated at: None, hard retracel: Tick: 52520 14.15, v: 7200.0, soft: None, conf: -94.73684210526326, Down change %: -0.7000000000000011
# 2024-03-14 04:38:45,229 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52516 14.0, v: 27150.0 to Tick: 52530 13.95, v: 13850.0, confirmation:Tick: 52522 13.9, v: 8450.0 terminated at: None, hard retracel: Tick: 52530 13.95, v: 13850.0, soft: None, conf: -56.249999999999986, Down change %: -0.049999999999998934
# 2024-03-14 04:38:45,232 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52525 13.4, v: 14250.0 to Tick: 52547 13.75, v: 8850.0, confirmation:Tick: 52531 13.75, v: 8550.0 terminated at: None, hard retracel: Tick: 52547 13.75, v: 8850.0, soft: None, conf: 66.66666666666661, Up change %: 0.0
# 2024-03-14 04:38:45,236 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52542 14.4, v: 31650.0 to Tick: 52569 13.45, v: 30800.0, confirmation:Tick: 52548 13.6, v: 10950.0 terminated at: None, hard retracel: Tick: 52569 13.45, v: 30800.0, soft: None, conf: -83.33333333333348, Down change %: 0.15000000000000036
# 2024-03-14 04:38:45,241 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52564 12.95, v: 20300.0 to Tick: 52585 13.35, v: 12650.0, confirmation:Tick: 52570 13.35, v: 7850.0 terminated at: None, hard retracel: Tick: 52585 13.35, v: 12650.0, soft: None, conf: 66.66666666666667, Up change %: 0.0
# 2024-03-14 04:38:45,242 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52580 13.55, v: 8650.0 to Tick: 52588 13.65, v: 14350.0, confirmation:Tick: 52587 13.35, v: 4850.0 terminated at: None, hard retracel: Tick: 52588 13.65, v: 14350.0, soft: None, conf: -83.33333333333363, Down change %: -0.3000000000000007
# 2024-03-14 04:38:45,245 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52583 13.5, v: 6550.0 to Tick: 52594 13.45, v: 0.0, confirmation:Tick: 52589 13.65, v: 8950.0 terminated at: None, hard retracel: Tick: 52594 13.45, v: 0.0, soft: None, conf: 66.66666666666667, Up change %: -0.20000000000000107
# 2024-03-14 04:38:45,249 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52589 13.65, v: 8950.0 to Tick: 52606 13.4, v: 10400.0, confirmation:Tick: 52595 13.3, v: 5550.0 terminated at: None, hard retracel: Tick: 52606 13.4, v: 10400.0, soft: None, conf: -65.21739130434786, Down change %: -0.09999999999999964
# 2024-03-14 04:38:45,253 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52601 13.5, v: 6750.0 to Tick: 52622 13.4, v: 21050.0, confirmation:Tick: 52607 13.3, v: 7900.0 terminated at: None, hard retracel: Tick: 52622 13.4, v: 21050.0, soft: None, conf: -62.49999999999994, Down change %: -0.09999999999999964
# 2024-03-14 04:38:45,258 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52617 12.7, v: 23500.0 to Tick: 52640 13.5, v: 8000.0, confirmation:Tick: 52623 13.15, v: 10150.0 terminated at: None, hard retracel: Tick: 52640 13.5, v: 8000.0, soft: None, conf: 66.6666666666667, Up change %: 0.34999999999999964
# 2024-03-14 04:38:45,260 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52637 13.7, v: 13650.0 to Tick: 52645 13.6, v: 10100.0, confirmation:Tick: 52643 13.95, v: 11250.0 terminated at: None, hard retracel: Tick: 52645 13.6, v: 10100.0, soft: None, conf: 61.90476190476193, Up change %: -0.34999999999999964
# 2024-03-14 04:38:45,263 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52640 13.5, v: 8000.0 to Tick: 52655 14.0, v: 11050.0, confirmation:Tick: 52646 13.7, v: 6350.0 terminated at: None, hard retracel: Tick: 52655 14.0, v: 11050.0, soft: None, conf: 57.69230769230766, Up change %: 0.3000000000000007
# 2024-03-14 04:38:45,267 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52651 14.45, v: 27500.0 to Tick: 52661 14.4, v: 27650.0, confirmation:Tick: 52658 14.5, v: 56250.0 terminated at: None, hard retracel: Tick: 52661 14.4, v: 27650.0, soft: None, conf: 51.61290322580648, Up change %: -0.09999999999999964
# 2024-03-14 04:38:45,269 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52656 13.85, v: 12250.0 to Tick: 52668 14.35, v: 17000.0, confirmation:Tick: 52661 14.3, v: 0.0 terminated at: None, hard retracel: Tick: 52668 14.35, v: 17000.0, soft: None, conf: 71.4285714285715, Up change %: 0.049999999999998934
# 2024-03-14 04:38:45,276 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52665 14.4, v: 5650.0 to Tick: 52691 13.45, v: 7650.0, confirmation:Tick: 52671 14.15, v: 4200.0 terminated at: None, hard retracel: Tick: 52691 13.45, v: 7650.0, soft: None, conf: -77.77777777777783, Down change %: 0.7000000000000011
# 2024-03-14 04:38:45,277 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52686 13.5, v: 7350.0 to Tick: 52693 13.7, v: 13450.0, confirmation:Tick: 52691 13.3, v: 13650.0 terminated at: None, hard retracel: Tick: 52693 13.7, v: 13450.0, soft: None, conf: -75.0, Down change %: -0.3999999999999986
# 2024-03-14 04:38:45,281 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52689 13.4, v: 13950.0 to Tick: 52705 13.6, v: 3350.0, confirmation:Tick: 52695 13.85, v: 8600.0 terminated at: None, hard retracel: Tick: 52705 13.6, v: 3350.0, soft: None, conf: 69.56521739130433, Up change %: -0.25
# 2024-03-14 04:38:45,296 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52702 13.9, v: 6800.0 to Tick: 52762 16.1, v: 14400.0, confirmation:Tick: 52707 14.2, v: 0.0 terminated at: None, hard retracel: Tick: 52762 16.1, v: 14400.0, soft: None, conf: 66.6666666666666, Up change %: 1.9000000000000021
# 2024-03-14 04:38:45,301 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52758 16.1, v: 35700.0 to Tick: 52776 15.85, v: 13300.0, confirmation:Tick: 52763 15.6, v: 0.0 terminated at: None, hard retracel: Tick: 52776 15.85, v: 13300.0, soft: None, conf: -72.72727272727288, Down change %: -0.25
# 2024-03-14 04:38:45,306 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52770 14.8, v: 0.0 to Tick: 52793 15.45, v: 17300.0, confirmation:Tick: 52777 15.7, v: 11450.0 terminated at: None, hard retracel: Tick: 52793 15.45, v: 17300.0, soft: None, conf: 76.47058823529409, Up change %: -0.25
# 2024-03-14 04:38:45,310 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52788 15.8, v: 27250.0 to Tick: 52804 15.65, v: 10200.0, confirmation:Tick: 52793 15.3, v: 6700.0 terminated at: None, hard retracel: Tick: 52804 15.65, v: 10200.0, soft: None, conf: -85.71428571428575, Down change %: -0.34999999999999964
# 2024-03-14 04:38:45,313 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52799 15.3, v: 13350.0 to Tick: 52816 15.8, v: 2400.0, confirmation:Tick: 52806 16.1, v: 38250.0 terminated at: None, hard retracel: Tick: 52816 15.8, v: 2400.0, soft: None, conf: 76.66666666666669, Up change %: -0.3000000000000007
# 2024-03-14 04:38:45,321 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52811 15.55, v: 11150.0 to Tick: 52845 17.8, v: 13550.0, confirmation:Tick: 52816 15.85, v: 0.0 terminated at: None, hard retracel: Tick: 52845 17.8, v: 13550.0, soft: None, conf: 75.00000000000007, Up change %: 1.950000000000001
# 2024-03-14 04:38:45,325 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52840 18.65, v: 34100.0 to Tick: 52860 18.25, v: 36400.0, confirmation:Tick: 52846 17.7, v: 15150.0 terminated at: None, hard retracel: Tick: 52860 18.25, v: 36400.0, soft: None, conf: -95.23809523809517, Down change %: -0.5500000000000007
# 2024-03-14 04:38:45,334 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52855 17.15, v: 75550.0 to Tick: 52894 19.75, v: 35450.0, confirmation:Tick: 52861 18.25, v: 26200.0 terminated at: None, hard retracel: Tick: 52894 19.75, v: 35450.0, soft: None, conf: 89.28571428571438, Up change %: 1.5
# 2024-03-14 04:38:45,335 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52889 19.3, v: 28850.0 to Tick: 52896 19.05, v: 57700.0, confirmation:Tick: 52895 19.6, v: 27600.0 terminated at: None, hard retracel: Tick: 52896 19.05, v: 57700.0, soft: None, conf: 75.00000000000014, Up change %: -0.5500000000000007
# 2024-03-14 04:38:45,338 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52891 19.6, v: 30750.0 to Tick: 52902 19.7, v: 57750.0, confirmation:Tick: 52896 18.95, v: 0.0 terminated at: None, hard retracel: Tick: 52902 19.7, v: 57750.0, soft: None, conf: -84.21052631578961, Down change %: -0.75
# 2024-03-14 04:38:45,341 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52897 18.7, v: 35100.0 to Tick: 52913 19.0, v: 21650.0, confirmation:Tick: 52902 19.7, v: 0.0 terminated at: None, hard retracel: Tick: 52913 19.0, v: 21650.0, soft: None, conf: 77.77777777777783, Up change %: -0.6999999999999993
# 2024-03-14 04:38:45,343 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52908 19.6, v: 11300.0 to Tick: 52916 19.85, v: 0.0, confirmation:Tick: 52914 19.1, v: 22100.0 terminated at: None, hard retracel: Tick: 52916 19.85, v: 0.0, soft: None, conf: -74.99999999999983, Down change %: -0.75
# 2024-03-14 04:38:45,347 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52912 19.0, v: 39250.0 to Tick: 52928 19.65, v: 24850.0, confirmation:Tick: 52917 19.85, v: 3850.0 terminated at: None, hard retracel: Tick: 52928 19.65, v: 24850.0, soft: None, conf: 72.97297297297291, Up change %: -0.20000000000000284
# 2024-03-14 04:38:45,349 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52925 19.3, v: 28300.0 to Tick: 52933 19.2, v: 11300.0, confirmation:Tick: 52931 19.6, v: 21000.0 terminated at: None, hard retracel: Tick: 52933 19.2, v: 11300.0, soft: None, conf: 60.71428571428578, Up change %: -0.40000000000000213
# 2024-03-14 04:38:45,355 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52928 19.65, v: 24850.0 to Tick: 52953 18.8, v: 11250.0, confirmation:Tick: 52933 19.05, v: 0.0 terminated at: None, hard retracel: Tick: 52953 18.8, v: 11250.0, soft: None, conf: -92.85714285714275, Down change %: 0.25
# 2024-03-14 04:38:45,358 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52948 17.8, v: 18350.0 to Tick: 52963 18.25, v: 15350.0, confirmation:Tick: 52954 18.45, v: 7900.0 terminated at: None, hard retracel: Tick: 52963 18.25, v: 15350.0, soft: None, conf: 65.8536585365853, Up change %: -0.1999999999999993
# 2024-03-14 04:38:45,363 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52958 18.4, v: 25500.0 to Tick: 52985 17.9, v: 26050.0, confirmation:Tick: 52963 18.25, v: 0.0 terminated at: None, hard retracel: Tick: 52985 17.9, v: 26050.0, soft: None, conf: -57.89473684210517, Down change %: 0.3500000000000014
# 2024-03-14 04:38:45,366 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52982 17.5, v: 11950.0 to Tick: 52993 17.05, v: 16500.0, confirmation:Tick: 52987 17.65, v: 0.0 terminated at: None, hard retracel: Tick: 52993 17.05, v: 16500.0, soft: None, conf: 57.142857142857096, Up change %: -0.5999999999999979
# 2024-03-14 04:38:45,368 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52988 17.9, v: 11700.0 to Tick: 53004 17.4, v: 17450.0, confirmation:Tick: 52994 16.75, v: 92950.0 terminated at: None, hard retracel: Tick: 53004 17.4, v: 17450.0, soft: None, conf: -89.65517241379297, Down change %: -0.6499999999999986
# 2024-03-14 04:38:45,370 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52999 17.3, v: 8850.0 to Tick: 53006 17.2, v: 7700.0, confirmation:Tick: 53005 17.35, v: 18000.0 terminated at: None, hard retracel: Tick: 53006 17.2, v: 7700.0, soft: None, conf: 54.54545454545466, Up change %: -0.15000000000000213
# 2024-03-14 04:38:45,372 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53001 17.4, v: 10250.0 to Tick: 53017 17.35, v: 12350.0, confirmation:Tick: 53007 17.15, v: 4000.0 terminated at: None, hard retracel: Tick: 53017 17.35, v: 12350.0, soft: None, conf: -69.23076923076948, Down change %: -0.20000000000000284
# 2024-03-14 04:38:45,376 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53012 16.9, v: 5650.0 to Tick: 53032 17.9, v: 7600.0, confirmation:Tick: 53017 17.6, v: 7650.0 terminated at: None, hard retracel: Tick: 53032 17.9, v: 7600.0, soft: None, conf: 85.00000000000014, Up change %: 0.29999999999999716
# 2024-03-14 04:38:45,380 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53027 18.4, v: 6300.0 to Tick: 53044 18.05, v: 19000.0, confirmation:Tick: 53032 18.0, v: 0.0 terminated at: None, hard retracel: Tick: 53044 18.05, v: 19000.0, soft: None, conf: -66.66666666666657, Down change %: -0.05000000000000071
# 2024-03-14 04:38:45,385 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53039 17.55, v: 8550.0 to Tick: 53055 17.65, v: 6350.0, confirmation:Tick: 53044 18.3, v: 0.0 terminated at: None, hard retracel: Tick: 53055 17.65, v: 6350.0, soft: None, conf: 74.19354838709671, Up change %: -0.6500000000000021
# 2024-03-14 04:38:45,390 - INFO - 2409830248.py:63 - [139965923841280] -
# ...
# 2024-03-14 04:38:46,000 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55176 12.1, v: 5750.0 to Tick: 55191 12.25, v: 5500.0, confirmation:Tick: 55182 12.5, v: 7350.0 terminated at: None, hard retracel: Tick: 55191 12.25, v: 5500.0, soft: None, conf: 90.00000000000018, Up change %: -0.25
# 2024-03-14 04:38:46,003 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55186 12.5, v: 9550.0 to Tick: 55199 12.2, v: 6350.0, confirmation:Tick: 55191 12.35, v: 0.0 terminated at: None, hard retracel: Tick: 55199 12.2, v: 6350.0, soft: None, conf: -63.6363636363637, Down change %: 0.15000000000000036
# 2024-03-14 04:38:46,006 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55194 12.25, v: 5350.0 to Tick: 55213 12.15, v: 2550.0, confirmation:Tick: 55199 12.2, v: 0.0 terminated at: None, hard retracel: Tick: 55213 12.15, v: 2550.0, soft: None, conf: -66.66666666666667, Down change %: 0.049999999999998934
# 2024-03-14 04:38:46,007 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55208 12.0, v: 13050.0 to Tick: 55216 11.9, v: 9100.0, confirmation:Tick: 55214 12.1, v: 1300.0 terminated at: None, hard retracel: Tick: 55216 11.9, v: 9100.0, soft: None, conf: 74.99999999999977, Up change %: -0.1999999999999993
# 2024-03-14 04:38:46,011 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55211 12.1, v: 17800.0 to Tick: 55228 12.0, v: 35500.0, confirmation:Tick: 55216 11.8, v: 0.0 terminated at: None, hard retracel: Tick: 55228 12.0, v: 35500.0, soft: None, conf: -79.99999999999979, Down change %: -0.1999999999999993
# 2024-03-14 04:38:46,015 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55223 11.7, v: 13500.0 to Tick: 55246 12.35, v: 9750.0, confirmation:Tick: 55228 12.05, v: 0.0 terminated at: None, hard retracel: Tick: 55246 12.35, v: 9750.0, soft: None, conf: 70.5882352941177, Up change %: 0.29999999999999893
# 2024-03-14 04:38:46,018 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55242 12.35, v: 3150.0 to Tick: 55259 12.25, v: 2750.0, confirmation:Tick: 55247 12.1, v: 0.0 terminated at: None, hard retracel: Tick: 55259 12.25, v: 2750.0, soft: None, conf: -72.72727272727269, Down change %: -0.15000000000000036
# 2024-03-14 04:38:46,022 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55254 11.85, v: 8700.0 to Tick: 55279 12.3, v: 14700.0, confirmation:Tick: 55259 12.25, v: 0.0 terminated at: None, hard retracel: Tick: 55279 12.3, v: 14700.0, soft: None, conf: 90.00000000000018, Up change %: 0.05000000000000071
# 2024-03-14 04:38:46,025 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55274 12.3, v: 11150.0 to Tick: 55283 12.2, v: 11050.0, confirmation:Tick: 55279 12.35, v: 0.0 terminated at: None, hard retracel: Tick: 55283 12.2, v: 11050.0, soft: None, conf: 55.555555555555465, Up change %: -0.15000000000000036
# 2024-03-14 04:38:46,029 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55278 12.35, v: 2700.0 to Tick: 55300 12.2, v: 0.0, confirmation:Tick: 55283 12.25, v: 0.0 terminated at: None, hard retracel: Tick: 55300 12.2, v: 0.0, soft: None, conf: -60.0, Down change %: 0.05000000000000071
# 2024-03-14 04:38:46,033 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55295 12.15, v: 4900.0 to Tick: 55315 12.3, v: 1450.0, confirmation:Tick: 55301 12.25, v: 5100.0 terminated at: None, hard retracel: Tick: 55315 12.3, v: 1450.0, soft: None, conf: 60.0, Up change %: 0.05000000000000071
# 2024-03-14 04:38:46,036 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55310 12.45, v: 10800.0 to Tick: 55324 12.35, v: 8950.0, confirmation:Tick: 55316 12.25, v: 3500.0 terminated at: None, hard retracel: Tick: 55324 12.35, v: 8950.0, soft: None, conf: -83.33333333333313, Down change %: -0.09999999999999964
# 2024-03-14 04:38:46,038 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55320 12.3, v: 16250.0 to Tick: 55327 12.25, v: 0.0, confirmation:Tick: 55325 12.5, v: 36600.0 terminated at: None, hard retracel: Tick: 55327 12.25, v: 0.0, soft: None, conf: 70.00000000000007, Up change %: -0.25
# 2024-03-14 04:38:46,044 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55322 12.35, v: 4600.0 to Tick: 55356 12.0, v: 11400.0, confirmation:Tick: 55328 12.25, v: 9400.0 terminated at: None, hard retracel: Tick: 55356 12.0, v: 11400.0, soft: None, conf: -58.33333333333336, Down change %: 0.25
# 2024-03-14 04:38:46,048 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55351 11.75, v: 14400.0 to Tick: 55370 11.95, v: 13050.0, confirmation:Tick: 55356 11.8, v: 0.0 terminated at: None, hard retracel: Tick: 55370 11.95, v: 13050.0, soft: None, conf: 52.380952380952415, Up change %: 0.14999999999999858
# 2024-03-14 04:38:46,051 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55366 12.0, v: 7250.0 to Tick: 55377 12.05, v: 5350.0, confirmation:Tick: 55371 11.9, v: 0.0 terminated at: None, hard retracel: Tick: 55377 12.05, v: 5350.0, soft: None, conf: -58.33333333333336, Down change %: -0.15000000000000036
# 2024-03-14 04:38:46,055 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55373 11.8, v: 11150.0 to Tick: 55392 12.1, v: 3950.0, confirmation:Tick: 55379 12.05, v: 2550.0 terminated at: None, hard retracel: Tick: 55392 12.1, v: 3950.0, soft: None, conf: 66.66666666666667, Up change %: 0.049999999999998934
# 2024-03-14 04:38:46,059 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55390 12.1, v: 5800.0 to Tick: 55408 12.35, v: 3150.0, confirmation:Tick: 55396 12.25, v: 10650.0 terminated at: None, hard retracel: Tick: 55408 12.35, v: 3150.0, soft: None, conf: 63.6363636363637, Up change %: 0.09999999999999964
# 2024-03-14 04:38:46,063 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55404 12.3, v: 3750.0 to Tick: 55428 12.4, v: 9200.0, confirmation:Tick: 55410 12.4, v: 1550.0 terminated at: None, hard retracel: Tick: 55428 12.4, v: 9200.0, soft: None, conf: 58.33333333333336, Up change %: 0.0
# 2024-03-14 04:38:46,070 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55423 12.5, v: 22550.0 to Tick: 55447 12.3, v: 1250.0, confirmation:Tick: 55428 12.3, v: 0.0 terminated at: None, hard retracel: Tick: 55447 12.3, v: 1250.0, soft: None, conf: -66.66666666666647, Down change %: 0.0
# 2024-03-14 04:38:46,072 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55442 12.3, v: 2500.0 to Tick: 55451 12.35, v: 2100.0, confirmation:Tick: 55448 12.15, v: 8650.0 terminated at: None, hard retracel: Tick: 55451 12.35, v: 2100.0, soft: None, conf: -63.636363636363605, Down change %: -0.1999999999999993
# 2024-03-14 04:38:46,074 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55446 12.3, v: 9800.0 to Tick: 55456 12.25, v: 7100.0, confirmation:Tick: 55451 12.4, v: 0.0 terminated at: None, hard retracel: Tick: 55456 12.25, v: 7100.0, soft: None, conf: 58.33333333333326, Up change %: -0.15000000000000036
# 2024-03-14 04:38:46,080 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55452 12.3, v: 22550.0 to Tick: 55463 12.4, v: 0.0, confirmation:Tick: 55457 12.2, v: 10200.0 terminated at: None, hard retracel: Tick: 55463 12.4, v: 0.0, soft: None, conf: -62.500000000000114, Down change %: -0.20000000000000107
# 2024-03-14 04:38:46,084 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55459 12.25, v: 21850.0 to Tick: 55485 12.3, v: 15350.0, confirmation:Tick: 55465 12.45, v: 8500.0 terminated at: None, hard retracel: Tick: 55485 12.3, v: 15350.0, soft: None, conf: 66.66666666666657, Up change %: -0.14999999999999858
# 2024-03-14 04:38:46,088 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55480 12.4, v: 4500.0 to Tick: 55507 12.05, v: 5800.0, confirmation:Tick: 55487 12.25, v: 8000.0 terminated at: None, hard retracel: Tick: 55507 12.05, v: 5800.0, soft: None, conf: -71.4285714285715, Down change %: 0.1999999999999993
# 2024-03-14 04:38:46,092 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55503 12.1, v: 9300.0 to Tick: 55520 12.15, v: 0.0, confirmation:Tick: 55509 12.2, v: 11750.0 terminated at: None, hard retracel: Tick: 55520 12.15, v: 0.0, soft: None, conf: 62.50000000000006, Up change %: -0.049999999999998934
# 2024-03-14 04:38:46,094 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55517 12.15, v: 6900.0 to Tick: 55528 12.1, v: 0.0, confirmation:Tick: 55522 12.25, v: 0.0 terminated at: None, hard retracel: Tick: 55528 12.1, v: 0.0, soft: None, conf: 62.49999999999994, Up change %: -0.15000000000000036
# 2024-03-14 04:38:46,098 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55523 12.35, v: 6500.0 to Tick: 55545 12.05, v: 12100.0, confirmation:Tick: 55530 12.05, v: 4000.0 terminated at: None, hard retracel: Tick: 55545 12.05, v: 12100.0, soft: None, conf: -80.0, Down change %: 0.0
# 2024-03-14 04:38:46,103 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55540 11.85, v: 10700.0 to Tick: 55565 12.25, v: 3400.0, confirmation:Tick: 55546 12.1, v: 5650.0 terminated at: None, hard retracel: Tick: 55565 12.25, v: 3400.0, soft: None, conf: 77.77777777777804, Up change %: 0.15000000000000036
# 2024-03-14 04:38:46,104 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55560 12.2, v: 5200.0 to Tick: 55566 12.15, v: 4900.0, confirmation:Tick: 55565 12.25, v: 0.0 terminated at: None, hard retracel: Tick: 55566 12.15, v: 4900.0, soft: None, conf: 57.142857142857146, Up change %: -0.09999999999999964
# 2024-03-14 04:38:46,107 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55563 12.3, v: 4300.0 to Tick: 55576 12.3, v: 3600.0, confirmation:Tick: 55569 12.25, v: 4000.0 terminated at: None, hard retracel: Tick: 55576 12.3, v: 3600.0, soft: None, conf: -60.00000000000014, Down change %: -0.05000000000000071
# 2024-03-14 04:38:46,110 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55571 12.2, v: 800.0 to Tick: 55586 12.25, v: 0.0, confirmation:Tick: 55576 12.3, v: 0.0 terminated at: None, hard retracel: Tick: 55586 12.25, v: 0.0, soft: None, conf: 75.0, Up change %: -0.05000000000000071
# 2024-03-14 04:38:46,113 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55583 12.25, v: 3100.0 to Tick: 55598 12.3, v: 13500.0, confirmation:Tick: 55588 12.3, v: 1050.0 terminated at: None, hard retracel: Tick: 55598 12.3, v: 13500.0, soft: None, conf: 57.14285714285722, Up change %: 0.0
# 2024-03-14 04:38:46,116 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55593 12.35, v: 10500.0 to Tick: 55607 12.4, v: 0.0, confirmation:Tick: 55599 12.3, v: 5600.0 terminated at: None, hard retracel: Tick: 55607 12.4, v: 0.0, soft: None, conf: -59.999999999999716, Down change %: -0.09999999999999964
# 2024-03-14 04:38:46,117 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55603 12.35, v: 4200.0 to Tick: 55609 12.3, v: 0.0, confirmation:Tick: 55609 12.4, v: 16950.0 terminated at: None, hard retracel: Tick: 55609 12.3, v: 0.0, soft: None, conf: 60.00000000000014, Up change %: -0.09999999999999964
# 2024-03-14 04:38:46,130 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55604 12.35, v: 1350.0 to Tick: 55635 12.25, v: 0.0, confirmation:Tick: 55610 12.3, v: 2700.0 terminated at: None, hard retracel: Tick: 55635 12.25, v: 0.0, soft: None, conf: -57.142857142857, Down change %: 0.05000000000000071
# 2024-03-14 04:38:46,134 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55631 12.15, v: 8300.0 to Tick: 55648 12.2, v: 3900.0, confirmation:Tick: 55637 12.1, v: 5000.0 terminated at: None, hard retracel: Tick: 55648 12.2, v: 3900.0, soft: None, conf: -55.55555555555564, Down change %: -0.09999999999999964
# 2024-03-14 04:38:46,142 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55643 12.05, v: 20450.0 to Tick: 55673 12.25, v: 4800.0, confirmation:Tick: 55648 12.2, v: 0.0 terminated at: None, hard retracel: Tick: 55673 12.25, v: 4800.0, soft: None, conf: 80.00000000000014, Up change %: 0.05000000000000071
# 2024-03-14 04:38:46,149 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55671 12.25, v: 10450.0 to Tick: 55686 12.25, v: 11050.0, confirmation:Tick: 55677 12.3, v: 4350.0 terminated at: None, hard retracel: Tick: 55686 12.25, v: 11050.0, soft: None, conf: 54.545454545454604, Up change %: -0.05000000000000071
# 2024-03-14 04:38:46,154 - INFO - 2409830248.py:63 - [139965923841280] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55681 12.35, v: 6900.0 to Tick: 55701 12.3, v: 4700.0, confirmation:Tick: 55686 12.3, v: 0.0 terminated at: None, hard retracel: Tick: 55701 12.3, v: 4700.0, soft: None, conf: -57.142857142857, Down change %: 0.0
# 2024-03-14 04:38:46,167 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55696 12.2, v: 12400.0 to Tick: 55746 12.9, v: 35650.0, confirmation:Tick: 55702 12.25, v: 6350.0 terminated at: None, hard retracel: Tick: 55746 12.9, v: 35650.0, soft: None, conf: 57.142857142857146, Up change %: 0.6500000000000004
# 2024-03-14 04:38:46,174 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55741 12.85, v: 9450.0 to Tick: 55767 13.05, v: 27950.0, confirmation:Tick: 55747 12.9, v: 9150.0 terminated at: None, hard retracel: Tick: 55767 13.05, v: 27950.0, soft: None, conf: 60.000000000000284, Up change %: 0.15000000000000036
# 2024-03-14 04:38:46,181 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55762 13.05, v: 2900.0 to Tick: 55790 13.3, v: 5700.0, confirmation:Tick: 55767 13.2, v: 0.0 terminated at: None, hard retracel: Tick: 55790 13.3, v: 5700.0, soft: None, conf: 66.66666666666667, Up change %: 0.10000000000000142
# 2024-03-14 04:38:46,184 - INFO - 2409830248.py:61 - [139965923841280] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55785 13.25, v: 12800.0 to Tick: 55797 12.8, v: 0.0, confirmation:Tick: 55791 13.35, v: 6050.0 terminated at: None, hard retracel: Tick: 55797 12.8, v: 0.0, soft: None, conf: 66.66666666666667, Up change %: -0.5499999999999989
# Continuation: None, INITIATED from Tick: 55794 13.45, v: 16550.0 to Tick: 55799 13.45, v: 3850.0, confirmation:None terminated at: None, hard retracel: None, soft: None, conf: None

# %%
pm.closed_orders.sort(key=lambda x: x.order.pnl)

# %%
# Losses
# multi_y = [[po.order.limit_price, po.order.square_off_price] for po in pm.closed_orders if po.order.pnl <= 0]
# multi_x = [[po.phase.started_at.id, po.phase.hard_retraced_at.id] for po in pm.closed_orders if po.order.pnl <= 0]
# texts = [str(po.order.pnl) for po in pm.closed_orders if po.order.pnl <= 0]
# subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

# All
from bokeh.models import ColumnDataSource

multi_y = [[po.order.limit_price, po.order.square_off_price] for po in pm.closed_orders]
multi_x = [[po.phase.started_at.id, po.phase.hard_retraced_at.id] for po in pm.closed_orders]
texts = [f"{po.order.pnl}, {round(po.phase.confidence_at_confirmation)}, s:{round(po.phase.svac)}, l:{round(po.phase.lvac)}" for po in pm.closed_orders]
subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

subplot = ColumnDataSource(subplot)

# phase_in_id = [phase.t_start.id for phase in pm.ps]
# phase_in_price = [phase.t_start.last_price for phase in pm.ps]
# phase_start_plot = ColumnDataSource({'x': phase_in_id, 'y': phase_in_price})

# p_end_id = [phase.t_end.id for phase in pm.ps]
# p_end_price = [phase.t_end.last_price for phase in pm.ps]
# phase_end_plot = ColumnDataSource({'x': p_end_id, 'y': p_end_price})

up_start_id = [phase.t_start.id for phase in pm.ps if phase.direction == ph.Direction.UP]
up_start_price = [phase.t_start.last_price for phase in pm.ps if phase.direction == ph.Direction.UP]
up_start_plot = ColumnDataSource({'x': up_start_id, 'y': up_start_price})

up_end_id = [phase.t_end.id for phase in pm.ps if phase.direction == ph.Direction.UP]
up_end_price = [phase.t_end.last_price for phase in pm.ps if phase.direction == ph.Direction.UP]
up_end_plot = ColumnDataSource({'x': up_end_id, 'y': up_end_price})

up_confirm_id = [phase.started_at.id for phase in pm.ps if phase.direction == ph.Direction.UP]
up_confirm_price = [phase.started_at.last_price for phase in pm.ps if phase.direction == ph.Direction.UP]
up_confirm_plot = ColumnDataSource({'x': up_confirm_id, 'y': up_confirm_price})

down_confirm_id = [phase.started_at.id for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_confirm_price = [phase.started_at.last_price for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_confirm_plot = ColumnDataSource({'x': down_confirm_id, 'y': down_confirm_price})

down_start_id = [phase.t_start.id for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_start_price = [phase.t_start.last_price for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_start_plot = ColumnDataSource({'x': down_start_id, 'y': down_start_price})

down_end_id = [phase.t_end.id for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_end_price = [phase.t_end.last_price for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_end_plot = ColumnDataSource({'x': down_end_id, 'y': down_end_price})

v_high_thresh = 100000
high_volume_id = [tick.id for tick in pm.ticks if tick.volume >= v_high_thresh]
high_volume_price = [tick.last_price for tick in pm.ticks if tick.volume >= v_high_thresh]
high_volume_plot = ColumnDataSource({'x': high_volume_id, 'y': high_volume_price})

v_low_thresh = 1000
low_volume_id = [tick.id for tick in pm.ticks if tick.volume != 0 and tick.volume <= v_low_thresh]
low_volume_price = [tick.last_price for tick in pm.ticks if tick.volume != 0 and tick.volume <= v_low_thresh]
low_volume_plot = ColumnDataSource({'x': low_volume_id, 'y': low_volume_price})

ticks_df = pd.DataFrame([tick.__dict__ for tick in pm.ticks])
ticks_df["sma_small_volume"] = ticks_df.volume.rolling(window=3).mean()
ticks_df["sma_big_volume"] = ticks_df.volume.rolling(window=10).mean().shift(3)

sma_high_id = ticks_df.loc[ticks_df.sma_small_volume >= (3 * ticks_df.sma_big_volume)].id
sma_high_price = ticks_df.loc[ticks_df.sma_small_volume >= (3 * ticks_df.sma_big_volume)].last_price
high_vsma_plot = ColumnDataSource({'x': sma_high_id, 'y': sma_high_price})

ticks_cdf = ColumnDataSource(ticks_df)
# phase_plot.data
import utils as ut
# ut.bokeh_plot(x=list(range(tdf.shape[0])), y=tdf.last_price, x_label="timestamp", y_label="price", plot='line')
# ut.bokeh_plot(x=[m.id for m in pm.ticks], y=[tick.last_price for tick in pm.ticks], x_label="timestamp", y_label="price", plot='line', multi_plots=subplot, subplots=[up_start_plot, up_end_plot, down_start_plot, down_end_plot, up_confirm_plot, down_confirm_plot], subplot_labels=['Up start', 'Up end', 'Down start', 'Down end', 'Up confirm', 'Down confirm'])
# ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', multi_plots=subplot, subplots=[up_start_plot, up_end_plot, down_start_plot, down_end_plot, up_confirm_plot, down_confirm_plot, high_volume_plot], subplot_labels=['Up start', 'Up end', 'Down start', 'Down end', 'Up confirm', 'Down confirm', 'High Volume'])
ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[high_volume_plot, high_vsma_plot], subplot_labels=['High Volume', 'SMA High'])
# tdf
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d91d297e-0c8b-417d-9695-facbc4efb07d">Loading BokehJS ...</span>
#     </div>
#   <div id="c49cdd35-04c7-4369-b20e-8ffd292b1fbe" data-root-id="p3698" style="display: contents;"></div>
