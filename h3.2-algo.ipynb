# %%
import base as b
import pandas as pd
import datetime as dt
from typing import Dict
import talib as ta
import utils as ut
from constants import *
from scipy.stats import linregress
from logger_settings import logger

settings = {
    "vwch_thresh": 3,
    "quantity": 50 * 1, # 1 lot
    "stagnation_cooldown": 5, # cooldown period after stagnation to resume, in ticks
    "svs_mn_thresh": 5000, # stagnation_volume_std_max_threshold
    "svs_mx_thresh": 10000, # stagnation_volume_std_min_threshold
}

instrument = b.Instrument(name="NIFTY 22650 CALL 7 Mar 2024")

SYMBOL = "NIFTY"
expiry = dt.datetime.strptime("2024-03-21", "%Y-%m-%d").date()
otype = "CE"
strike = 22000
date = dt.datetime.strptime("2024-03-15", "%Y-%m-%d").date()

tdf = ut.get_ticks(symbol=SYMBOL, expiry=expiry, strike=strike, otype=otype, date=date)

# %%
REASON_REVERSE_SIGNIFICANCE = "reverse significance found"
REASON_STAGNATING = "trend stagnating"
REASON_CONFIRM = "confirmed"

class Phase(b.BasePhase):
    def __init__(self, initiated_at, strategy):
        super().__init__(initiated_at, strategy)
        self.volume_confirmed = False
        self.parent_volume_confirmed = False
        self.last_slope = None
        self.stagnated_at = None
        self.stagnate_reason = None
        logger.info(f"created new phase{self.id} at: {initiated_at}")
        if initiated_at < strategy.ticks.iloc[-1].name:
            self.rerun()

    def __repr__(self):
        return (f"==Phase {self.id}:{self.direction}, {self.status} I:{self.initiated_at}, C:{self.confirmed_at} R:{self.retraced_at}, "
               f"T:{self.term_at}, RJ:{self.rejected_at}, cr:{self.created_at} tr: {self.term_reason}, rr:{self.retrace_reason}, "
               f"end:{self.ended_at}, vc: {self.volume_confirmed}, pc: {self.parent_volume_confirmed}, st: {self.stagnated_at}==")

    def rerun(self):
        self.next()

    def has_breached_start(self):
        up_breach = self.direction == UP and (self.strategy.ticks.iloc[-1].last_price <= self.strategy.ticks.loc[self.initiated_at].last_price).all()
        if up_breach:
            return up_breach
        down_breach = self.direction == DOWN and (self.strategy.ticks.iloc[-1].last_price >= self.strategy.ticks.loc[self.initiated_at].last_price).all()
        return down_breach

    def get_new_phase_start(self):
        """
        Return new phase start when current phase is breached
        """
        if self.direction == UP:
            return self.strategy.ticks.loc[self.strategy.ticks.index > self.initiated_at].last_price.idxmax()
        else:
            return self.strategy.ticks.loc[self.strategy.ticks.index > self.initiated_at].last_price.idxmin()

    def is_tick_significant(self):
        """
        If a tick has a very high vwch, that could mean that its a very significant tick.
        If opposite direction tick has a very high vwch, its a good sign of reversal.
        Returns -1 if its opposite direction significant
        Returns 1 if same direction significant
        Returns 0 if not significant
        """
        thresh = self.strategy.vwch_thresh
        is_volume_significant = self.pticks.iloc[-1].volume >= (thresh * self.pticks.volume.mean())
        if not is_volume_significant:
            return 0
        if self.direction == UP and self.pticks.iloc[-1].ch <= 0:
            return -1
        if self.direction == DOWN and self.pticks.iloc[-1].ch >= 0:
            return -1
        return 1

    def terminate(self, reason):
        self.status = self.STATUS_TERM
        self.term_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_termination(self, reason)
        self.term_reason = reason
        if self.retraced_at is None:
            self.retraced_at = self.strategy.ticks.iloc[-1].name
            self.retrace_reason = "on phase termination"

    def retracing(self, reason):
        self.status = self.STATUS_RETRACING
        self.retraced_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_retracel(self, reason)
        self.retrace_reason = reason

    def stagnating(self, reason):
        if self.status == self.STATUS_STAGNATING:
            return
        self.status = self.STATUS_STAGNATING
        self.stagnated_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_stagnation(self, reason)
        self.stagnate_reason = reason

    def confirm(self):
        self.status = self.STATUS_CONFIRMED
        self.strategy.on_confirmed(self, REASON_CONFIRM)

    def calculate_pdata(self):
        self.pticks["ch"] = self.pticks.last_price.diff()
        self.pticks["vwch"] = self.pticks.ch * self.pticks.volume  # Volume weighted change
        self.pticks["cum_vwch"] = self.pticks.vwch.cumsum()
        self.pticks["std_vwch"] = self.pticks.cum_vwch.rolling(window=5).std()  # Volume weighted change
        self.last_slope = self.get_slope(self.ended_at)

    def get_slope(self, eidx):
        if self.direction == UP:
            last_idx = self.pticks.loc[:eidx-1].cum_vwch.idxmax()
        else:
            last_idx = self.pticks.loc[:eidx-1].cum_vwch.idxmin()
        if pd.isna(last_idx) or eidx - last_idx < 4:
            return
        df = self.pticks.loc[last_idx: eidx]
        factor = 1.6
        if self.status == self.STATUS_STAGNATING:
            multiplier = self.pticks.loc[:self.stagnated_at].vwch.mean() * factor
        else:
            multiplier = self.pticks.vwch.mean() * factor
        multiplier = multiplier * (7 / (eidx - last_idx))
        try:
            lr = linregress(df.id * multiplier, df.cum_vwch)
        except ValueError:
            raise Exception(f"asd: {last_idx}, {eidx}")
        logger.info(f"slope: {last_idx} to {eidx}: {lr.slope}, init: {self.pticks.iloc[0].name}, m: {multiplier}, {self}")
        return lr.slope

    def is_retracing(self):
        if self.last_slope is None:
            return self.status == self.STATUS_RETRACING
        if self.direction == UP:
            return self.last_slope < - .6
        else:
            return self.last_slope > .6

    def is_stagnating(self):
        if self.last_slope is None:
            return self.status == self.STATUS_STAGNATING
        return (- .6 <= self.last_slope <= .6)
        # if self.status == Phase.STATUS_STAGNATING:
        #     logger.info(f"stagnating1? {self.pticks.iloc[-1].name}, {self.pticks.iloc[-1].std_vwch}: {self.pticks.iloc[-1].std_vwch < self.strategy.svs_mx_thresh}")
        #     return self.pticks.iloc[-1].std_vwch < self.strategy.svs_mx_thresh and (self.ended_at - self.stagnated_at >= self.strategy.stagnation_cooldown)
        # logger.info(f"stagnating2? {self.pticks.iloc[-1].name}, {self.pticks.iloc[-1].std_vwch}: {self.pticks.iloc[-1].std_vwch <= self.strategy.svs_mn_thresh}")
        # return self.pticks.iloc[-1].std_vwch <= self.strategy.svs_mn_thresh

    def next(self):
        super().next()
        self.calculate_pdata()
        if self.status == self.STATUS_TERM:
            raise Exception(f"phase {self} already terminated")
        if self.status == self.STATUS_INITIATED:
            if self.pticks.iloc[-1].ch > 0:
                self.direction = UP
            else:
                self.direction = DOWN
            self.confirm()
            return
        if self.has_breached_start():
            self.terminate("breached start")
            return
        # if self.status == self.STATUS_RETRACING:
        #     return
        significance = self.is_tick_significant()
        is_retr = self.is_retracing()
        if self.ended_at >= 90:
            pass
        if significance == -1 or is_retr:
            self.retracing(REASON_REVERSE_SIGNIFICANCE)
            return
        elif significance == 1:
            self.volume_confirmed = True
        is_stagnating = self.is_stagnating()
        if is_stagnating:
            if self.status != self.STATUS_STAGNATING:
                self.stagnating(REASON_STAGNATING)
            return
        else:
            if self.status == self.STATUS_STAGNATING and self.ended_at - self.stagnated_at < self.strategy.stagnation_cooldown:
                return
        self.confirm()

class PhaseStrategy(b.BasePhaseStrategy):
    def __init__(self, instrument: "Instrument", settings: Dict):
        super().__init__(instrument, settings)
        self.om = b.OrderManager()

    def calculate_data(self):
        pass

    def next(self, tick: Dict):
        super().next(tick)
        self.calculate_data()
        if self.current_phase is None:
            self.current_phase = Phase(initiated_at=self.ticks.iloc[-1].name, strategy=self)
        else:
            self.current_phase.next()
        for phase in self.active_ph:
            phase.next()

    def _terminate_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_TERM:
            raise Exception("expected terminated status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            if self.current_phase.status == Phase.STATUS_CONFIRMED:
                self.current_phase.confirm()
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
        self.inactive_ph.append(last_phase)

    def _retrace_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_RETRACING:
            raise Exception(f"expected {Phase.STATUS_RETRACING} status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            if self.current_phase.status == Phase.STATUS_CONFIRMED:
                self.current_phase.confirm()
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
            if reason == REASON_REVERSE_SIGNIFICANCE:
                self.current_phase.volume_confirmed = True
        self.active_ph.append(last_phase)

    def _stagnate_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_STAGNATING:
            raise Exception(f"expected {Phase.STATUS_STAGNATING} status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            if self.current_phase.status == Phase.STATUS_CONFIRMED:
                self.current_phase.confirm()
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
        self.active_ph.append(last_phase)
    
    def set_new_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status == Phase.STATUS_TERM:
            self._terminate_last_phase(reason)
        elif last_phase.status == Phase.STATUS_RETRACING:
            self._retrace_last_phase(reason)
        elif last_phase.status == Phase.STATUS_STAGNATING:
            self._stagnate_last_phase(reason)
        else:
            raise Exception("status not handled")

    def on_termination(self, phase, reason):
        logger.info(f"phase terminated: {phase}")
        if self.om.has_intrade_orders(phase):
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=phase)
        if phase.id != self.current_phase.id:
            idx = [i for i, cphase in enumerate(self.active_ph) if cphase.id == phase.id][0]
            self.inactive_ph.append(self.active_ph[idx])
            del self.active_ph[idx]
            return
        self.set_new_phase(reason)
        if self.current_phase.direction == UP and self.current_phase.status == Phase.STATUS_CONFIRMED and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed:
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_retracel(self, phase, reason):
        logger.info(f"phase retracing {phase}")
        if phase.id != self.current_phase.id:
            return
        if self.om.has_intrade_orders():
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=self.current_phase)
        self.set_new_phase(reason)
        if self.current_phase.direction == UP and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed:
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_confirmed(self, phase, reason):
        logger.info(f"phase on confirmed {phase}")
        if phase.id != self.current_phase.id:
            return
        if self.current_phase.direction == UP and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed and not (self.om.has_intrade_orders()):
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_stagnation(self, phase, reason):
        logger.info(f"phase stagnating {phase}, slope: {phase.last_slope}")
        if phase.id != self.current_phase.id:
            return
        if self.om.has_intrade_orders():
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=self.current_phase)
        # self.set_new_phase(reason)

ps = PhaseStrategy(instrument=instrument, settings=settings)
# for i in range(tdf.shape[0]):
# for i in range(1000, 3000):
for i in range(200):
    ps.next(tdf.iloc[i].to_dict())

print(ps.current_phase)
print(ps.inactive_ph)
print(ps.active_ph)
# Out:
# 2024-03-20 15:19:42,222 - INFO - 1920277605.py:13 - [135190550721792] -
# created new phase0 at: 0
# /tmp/ipykernel_128665/1920277605.py:97: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   last_idx = self.pticks.loc[:eidx-1].cum_vwch.idxmin()
# 2024-03-20 15:19:42,250 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 0:DOWN, CONFIRMED I:0, C:None R:None, T:None, RJ:None, cr:0 tr: None, rr:None, end:1, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,280 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 0:DOWN, CONFIRMED I:0, C:None R:None, T:None, RJ:None, cr:0 tr: None, rr:None, end:2, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,297 - INFO - 1920277605.py:248 - [135190550721792] -
# phase terminated: ==Phase 0:DOWN, TERMINATED I:0, C:None R:None, T:3, RJ:None, cr:0 tr: None, rr:None, end:3, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,298 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,301 - INFO - 1920277605.py:13 - [135190550721792] -
# created new phase1 at: 1
# 2024-03-20 15:19:42,318 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 1:UP, CONFIRMED I:1, C:None R:None, T:None, RJ:None, cr:3 tr: None, rr:None, end:3, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,336 - INFO - 1920277605.py:248 - [135190550721792] -
# phase terminated: ==Phase 1:UP, TERMINATED I:1, C:None R:None, T:4, RJ:None, cr:3 tr: None, rr:None, end:4, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,337 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,341 - INFO - 1920277605.py:13 - [135190550721792] -
# created new phase2 at: 3
# /tmp/ipykernel_128665/1920277605.py:97: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   last_idx = self.pticks.loc[:eidx-1].cum_vwch.idxmin()
# 2024-03-20 15:19:42,349 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:4, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,357 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:5, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,365 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:6, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,373 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:7, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,380 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:8, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,388 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:9, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,397 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:10, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,405 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:11, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,416 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:12, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,426 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:13, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,435 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:14, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,443 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:15, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,451 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:16, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,461 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:17, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,471 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:18, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,481 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:19, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,488 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:20, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,497 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:21, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,505 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:None, end:22, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,506 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,509 - INFO - 1920277605.py:13 - [135190550721792] -
# created new phase3 at: 19
# 2024-03-20 15:19:42,514 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:22, vc: False, pc: False, st: None==
# 2024-03-20 15:19:42,515 - INFO - base.py:140 - [135190550721792] -
# place_order called
# 2024-03-20 15:19:42,516 - INFO - 1920277605.py:274 - [135190550721792] -
# placed order for phase start: ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:22, vc: True, pc: True, st: None==, order: buy, b:214.2, s:None, pnl:NA
# 2024-03-20 15:19:42,523 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:22, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,530 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:23, vc: True, pc: True, st: None==
# 2024-03-20 15:19:42,531 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,537 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 19 to 23: -2.0260135556660783, init: 3, m: -7182.350000000012, ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:23, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,539 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:23, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,547 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:24, vc: True, pc: True, st: None==
# 2024-03-20 15:19:42,548 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,554 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 19 to 24: -2.504798842156319, init: 3, m: -5544.266666666679, ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:24, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,556 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:24, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,564 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:25, vc: True, pc: True, st: None==
# 2024-03-20 15:19:42,565 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,571 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 19 to 25: -49.5477303070754, init: 3, m: -385.848484848488, ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:25, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,574 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:25, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,584 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:26, vc: True, pc: True, st: None==
# 2024-03-20 15:19:42,586 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,592 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 19 to 26: -66.30028684672489, init: 3, m: -316.3478260869576, ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:26, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,594 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:26, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,604 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:27, vc: True, pc: True, st: None==
# 2024-03-20 15:19:42,606 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,614 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 19 to 27: -13.399706415141283, init: 3, m: -1334.083333333346, ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:27, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,616 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:reverse significance found, end:27, vc: True, pc: False, st: None==
# 2024-03-20 15:19:42,624 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:28, vc: True, pc: True, st: None==
# 2024-03-20 15:19:42,625 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:42,632 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 19 to
- INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:43,515 - INFO - 1920277605.py:194 - [135190550721792] -
# Reactivated phase: ==Phase 3:UP, RETRACING I:19, C:None R:92, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:92, vc: True, pc: True, st: 90== at: 93
# 2024-03-20 15:19:43,523 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 73 to 94: -0.6647861634714308, init: 19, m: 936.7288888888882, ==Phase 3:UP, RETRACING I:19, C:None R:92, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:94, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,525 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:94, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:94, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,526 - INFO - base.py:145 - [135190550721792] -
# has_intrade_orders called
# 2024-03-20 15:19:43,529 - INFO - 1920277605.py:13 - [135190550721792] -
# created new phase5 at: 93
# /tmp/ipykernel_128665/1920277605.py:97: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   last_idx = self.pticks.loc[:eidx-1].cum_vwch.idxmin()
# 2024-03-20 15:19:43,540 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 5:DOWN, CONFIRMED I:93, C:None R:None, T:None, RJ:None, cr:94 tr: None, rr:None, end:94, vc: False, pc: False, st: None==
# 2024-03-20 15:19:43,554 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 73 to 94: -0.6647861634714308, init: 19, m: 936.7288888888882, ==Phase 3:UP, RETRACING I:19, C:None R:94, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:94, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,556 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:94, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:94, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,563 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 5:DOWN, CONFIRMED I:93, C:None R:None, T:None, RJ:None, cr:94 tr: None, rr:None, end:95, vc: True, pc: True, st: None==
# 2024-03-20 15:19:43,580 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 73 to 95: -0.6970768680215278, init: 19, m: 882.3851674641143, ==Phase 3:UP, RETRACING I:19, C:None R:94, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:95, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,585 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:95, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:95, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,606 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 5:DOWN, CONFIRMED I:93, C:None R:None, T:None, RJ:None, cr:94 tr: None, rr:None, end:96, vc: True, pc: True, st: None==
# 2024-03-20 15:19:43,618 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 73 to 96: -1.1739661124991991, init: 19, m: 718.2292490118577, ==Phase 3:UP, RETRACING I:19, C:None R:95, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:96, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,619 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:96, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:96, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,636 - INFO - 1920277605.py:277 - [135190550721792] -
# phase on confirmed ==Phase 5:DOWN, CONFIRMED I:93, C:None R:None, T:None, RJ:None, cr:94 tr: None, rr:None, end:97, vc: True, pc: True, st: None==
# 2024-03-20 15:19:43,650 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 73 to 97: -1.4886404077282056, init: 19, m: 679.4786324786324, ==Phase 3:UP, RETRACING I:19, C:None R:96, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:97, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,652 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:97, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:97, vc: True, pc: True, st: 90==
# 2024-03-20 15:19:43,665 - INFO - 1920277605.py:277 - [135190550721792] -
# ...
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:189, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:189, vc: True, pc: True, st: 174==
# 2024-03-20 15:19:45,151 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 174 to 189: -3.3992300201962333, init: 146, m: 300.92403100775005, ==Phase 10:UP, RETRACING I:146, C:None R:188, T:None, RJ:None, cr:146 tr: None, rr:reverse significance found, end:189, vc: True, pc: True, st: 154==
# 2024-03-20 15:19:45,153 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 10:UP, RETRACING I:146, C:None R:189, T:None, RJ:None, cr:146 tr: None, rr:reverse significance found, end:189, vc: True, pc: True, st: 154==
# 2024-03-20 15:19:45,164 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 183 to 190: -0.2502780867630695, init: 175, m: -957.0000000000053, ==Phase 11:DOWN, STAGNATING I:175, C:None R:None, T:None, RJ:None, cr:186 tr: None, rr:None, end:190, vc: True, pc: True, st: 187==
# 2024-03-20 15:19:45,170 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 174 to 190: -1.5741727756540633, init: 19, m: 620.0628654970753, ==Phase 3:UP, RETRACING I:19, C:None R:189, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:190, vc: True, pc: True, st: 174==
# 2024-03-20 15:19:45,172 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:190, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:190, vc: True, pc: True, st: 174==
# 2024-03-20 15:19:45,178 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 174 to 190: -3.6239800532123896, init: 146, m: 269.3409090909074, ==Phase 10:UP, RETRACING I:146, C:None R:189, T:None, RJ:None, cr:146 tr: None, rr:reverse significance found, end:190, vc: True, pc: True, st: 154==
# 2024-03-20 15:19:45,180 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 10:UP, RETRACING I:146, C:None R:190, T:None, RJ:None, cr:146 tr: None, rr:reverse significance found, end:190, vc: True, pc: True, st: 154==
# 2024-03-20 15:19:45,186 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 183 to 191: -0.2533661740558231, init: 175, m: -837.3750000000047, ==Phase 11:DOWN, STAGNATING I:175, C:None R:None, T:None, RJ:None, cr:186 tr: None, rr:None, end:191, vc: True, pc: True, st: 187==
# 2024-03-20 15:19:45,191 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 174 to 191: -1.5553941524246158, init: 19, m: 581.0861833105328, ==Phase 3:UP, RETRACING I:19, C:None R:190, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end
- INFO - 1920277605.py:111 - [135190550721792] -
# slope: 174 to 199: -1.3444081547239226, init: 19, m: 379.6239999999995, ==Phase 3:UP, RETRACING I:19, C:None R:198, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:199, vc: True, pc: True, st: 174==
# 2024-03-20 15:19:45,379 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:199, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:199, vc: True, pc: True, st: 174==
# 2024-03-20 15:19:45,384 - INFO - 1920277605.py:111 - [135190550721792] -
# slope: 174 to 199: -3.357161333655102, init: 146, m: 152.02415094339477, ==Phase 10:UP, RETRACING I:146, C:None R:198, T:None, RJ:None, cr:146 tr: None, rr:reverse significance found, end:199, vc: True, pc: True, st: 154==
# 2024-03-20 15:19:45,386 - INFO - 1920277605.py:264 - [135190550721792] -
# phase retracing ==Phase 10:UP, RETRACING I:146, C:None R:199, T:None, RJ:None, cr:146 tr: None, rr:reverse significance found, end:199, vc: True, pc: True, st: 154==
# ==Phase 11:DOWN, STAGNATING I:175, C:None R:None, T:None, RJ:None, cr:186 tr: None, rr:None, end:199, vc: True, pc: True, st: 187==
# [==Phase 0:DOWN, TERMINATED I:0, C:None R:3, T:3, RJ:None, cr:0 tr: breached start, rr:on phase termination, end:3, vc: False, pc: False, st: None==, ==Phase 1:UP, TERMINATED I:1, C:None R:4, T:4, RJ:None, cr:3 tr: breached start, rr:on phase termination, end:4, vc: False, pc: False, st: None==, ==Phase 2:DOWN, TERMINATED I:3, C:None R:55, T:56, RJ:None, cr:4 tr: breached start, rr:reverse significance found, end:56, vc: True, pc: False, st: None==, ==Phase 4:DOWN, TERMINATED I:80, C:None R:93, T:93, RJ:None, cr:89 tr: breached start, rr:on phase termination, end:93, vc: True, pc: True, st: None==, ==Phase 5:DOWN, TERMINATED I:93, C:None R:125, T:125, RJ:None, cr:94 tr: breached start, rr:on phase termination, end:125, vc: True, pc: True, st: 100==, ==Phase 6:DOWN, TERMINATED I:126, C:None R:130, T:130, RJ:None, cr:126 tr: breached start, rr:on phase termination, end:130, vc: True, pc: True, st: None==, ==Phase 7:DOWN, TERMINATED I:131, C:None R:135, T:135, RJ:None, cr:131 tr: breached start, rr:on phase termination, end:135, vc: True, pc: True, st: None==, ==Phase 8:DOWN, TERMINATED I:135, C:None R:142, T:142, RJ:None, cr:136 tr: breached start, rr:on phase termination, end:142, vc: True, pc: True, st: None==, ==Phase 9:DOWN, TERMINATED I:143, C:None R:145, T:145, RJ:None, cr:143 tr: breached start, rr:on phase termination, end:145, vc: True, pc: True, st: None==]
# [==Phase 3:UP, RETRACING I:19, C:None R:199, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:199, vc: True, pc: True, st: 174==, ==Phase 10:UP, RETRACING I:146, C:None R:199, T:None, RJ:None, cr:146 tr: None, rr:reverse significance found, end:199, vc: True, pc: True, st: 154==]

# %%
print(f"Total orders: {len(ps.om.closed_orders)}")
print(f"Total PNL %: {sum([po.order.pnl for po in ps.om.closed_orders]) * 100 / sum([po.order.limit_price * po.order.quantity for po in ps.om.closed_orders])}")
# Out:
# Total orders: 2
# Total PNL %: 1.1438824716833016

# %%
from bokeh.models import ColumnDataSource
all_phases = ps.inactive_ph + [phase for phase in ps.active_ph if phase.retraced_at is not None]
up_ini_idx = [ps.ticks.loc[phase.initiated_at].id for phase in all_phases if phase.direction == UP]
up_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == UP]

up_end_idx = [ps.ticks.loc[phase.retraced_at].id for phase in all_phases if phase.direction == UP]
up_end = [ps.ticks.loc[phase.retraced_at].last_price for phase in all_phases if phase.direction == UP]

down_ini_idx = [ps.ticks.loc[phase.initiated_at].id for phase in all_phases if phase.direction == DOWN]
down_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == DOWN]
down_end_idx = [ps.ticks.loc[phase.retraced_at].id for phase in all_phases if phase.direction == DOWN]
down_end = [ps.ticks.loc[phase.retraced_at].last_price for phase in all_phases if phase.direction == DOWN]

up_ini_plot = ColumnDataSource({'x': up_ini_idx, 'y': up_initiate})
up_end_plot = ColumnDataSource({'x': up_end_idx, 'y': up_end})

down_ini_plot = ColumnDataSource({'x': down_ini_idx, 'y': down_initiate})
down_end_plot = ColumnDataSource({'x': down_end_idx, 'y': down_end})

order_created_at = [ps.ticks.loc[po.order.created_at].id for po in ps.om.closed_orders]
order_created_at_price = [ps.ticks.loc[po.order.created_at].last_price for po in ps.om.closed_orders]

order_sqo_at = [ps.ticks.loc[po.order.square_off_at].id for po in ps.om.closed_orders]
order_sqo_at_price = [ps.ticks.loc[po.order.square_off_at].last_price for po in ps.om.closed_orders]
order_at_cds = ColumnDataSource({'x': order_created_at, 'y': order_created_at_price})
order_sqo_at_cds = ColumnDataSource({'x': order_sqo_at, 'y': order_sqo_at_price})

down_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == DOWN]

ticks_cdf = ColumnDataSource(ps.ticks)
# ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end'])
# ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end'])
ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot, order_at_cds, order_sqo_at_cds], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end', 'Order At', 'Order SQO'])
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="aa68387a-eba5-46f0-a376-5c11615203fc">Loading BokehJS ...</span>
#     </div>
#   <div id="bb1c2b07-f216-4a45-879e-44d96bd33a74" data-root-id="p1022" style="display: contents;"></div>

# %%
# for i, row in ps.ticks.iterrows():

# ps.ticks['vwch_rolling'] = ps.ticks.vwch.rolling(window=5).sum()
# ps.ticks['vwch_cum'] = ps.ticks.vwch.cumsum()
ps.ticks.head(100)
# Out:
#     last_price  last_traded_quantity  total_buy_quantity  total_sell_quantity  \
# 0       220.35                    50               43000                45600
# 1       218.10                   250               56350                42950
# 2       218.30                   200               73600                47500
# 3       223.15                    50               89500                58800
# 4       218.10                    50               95500                67350
# ..         ...                   ...                 ...                  ...
# 76      224.95                    50              168600                82900
# 77      224.90                   100              157450                72000
# 78      224.40                    50              166000                88700
# 79      226.80                   300              174850                82250
# 80      227.10                    50              182150                84750
#
#        last_trade_time       oi  volume  id
# 0  2024-03-15 09:15:02  1879800     0.0   0
# 1  2024-03-15 09:15:03  1879800  7550.0   1
# 2  2024-03-15 09:15:03  1879800  1900.0   1
# 3  2024-03-15 09:15:04  1879800  2400.0   2
# 4  2024-03-15 09:15:05  1879800  6600.0   3
# ..                 ...      ...     ...  ..
# 76 2024-03-15 09:15:52  1906300  3800.0  50
# 77 2024-03-15 09:15:53  1906300  3500.0  51
# 78 2024-03-15 09:15:53  1906300  3100.0  51
# 79 2024-03-15 09:15:54  1906300  1400.0  52
# 80 2024-03-15 09:15:54  1906300  2900.0  52
#
# [81 rows x 8 columns]

# %% [markdown]
# # Per Quantity Movement Chart

# %%
print(ps.current_phase.pticks.vwch.iloc[:26].mean())
print(ps.current_phase.pticks.vwch.std())
# ps.current_phase.pticks.vwch
# Out:
# 3162.799999999983
# 8518.726262539245

# %%
# from matplotlib import pyplot as plt

# plt.ion()
# plt.figure(figsize=(30, 12))  # Adjust the width and height as needed

# plt.plot(ps.ticks.loc[ps.ticks.pqch.notna()].pqch)

# ut.bokeh_series_plot(ps.ticks, 'vwch_cum', 'id')
# ps.inactive_ph[5]
# ps.inactive_ph[2].id
# ut.bokeh_series_plot(ps.inactive_ph[2].pticks, 'cum_vwch', 'id')
# ut.bokeh_series_plot(ps.current_phase.pticks, 'cum_vwch', 'id')
# ut.bokeh_series_plot(ps.current_phase.pticks, 'vwch', 'id')

ps.ticks["ch"] = ps.ticks.last_price.diff()
ps.ticks["vwch"] = ps.ticks.ch * ps.ticks.volume
ps.ticks["cum_vwch"] = ps.ticks.vwch.cumsum()
ut.bokeh_series_plot(ps.ticks, 'cum_vwch', 'id')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="dc6f4353-9127-4ff7-9ebf-d25f770b9276">Loading BokehJS ...</span>
#     </div>
#   <div id="d81415c7-ed66-4d10-bb99-ad12de02bb8e" data-root-id="p1139" style="display: contents;"></div>

# %%
ut.bokeh_series_plot(ps.current_phase.pticks, 'std_vwch', 'id')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a713a7d5-6c33-4ceb-8264-57ce9fae97c7">Loading BokehJS ...</span>
#     </div>
#   <div id="b6623a48-7bcc-46b2-9325-77492cb87ea6" data-root-id="p1259" style="display: contents;"></div>

# %%
# print(ps.inactive_ph[5].pticks.to_json())
ps.inactive_ph[2].pticks['rolling_std'] = ps.inactive_ph[2].pticks.vwch.rolling(window=7).std()
print(ps.inactive_ph[2].pticks.vwch.abs().quantile(.7))
ps.inactive_ph[2].pticks
# Out:
# 5125.000000000037
#     last_price  last_traded_quantity  total_buy_quantity  total_sell_quantity  \
# 3       223.15                    50               89500                58800
# 4       218.10                    50               95500                67350
# 5       222.70                    50              104800                61750
# 6       219.60                    50               99900                76650
# 7       218.30                   100              108000                80000
# 8       216.55                   250              108800                82850
# 9       215.30                    50              106600                77100
# 10      217.95                   200              114050                67850
# 11      216.30                    50              106450                66550
# 12      215.95                    50              116000                73650
# 13      215.20                    50              111700                78350
# 14      216.05                   100              114200                79200
# 15      216.00                    50              123150                85050
# 16      215.50                    50              120050                71350
# 17      214.00                    50              116700                79900
# 18      212.80                    50              115050                74900
# 19      212.35                    50              122000                93250
# 20      212.75                    50              118000                81550
# 21      212.80                    50              118000                81550
# 22      214.20                    50              119450                77800
# 23      214.30                    50              121350                80500
# 24      214.00                   550              119850                86250
# 25      217.40                    50              128750                82600
# 26      218.25                   100              128750                82600
# 27      217.20                    50              135850                82400
# 28      217.00                   200              136000                84100
# 29      218.10                    50              141150                84750
# 30      219.10                   400              142400                91450
# 31      220.00                    50              144150                85500
# 32      219.40                    50              143200                90100
# 33      221.10                    50              146100                87900
# 34      219.10                    50              147900                89700
# 35      218.80                    50              146650                92450
# 36      218.60                    50              150400                81050
# 37      219.00                    50              150800                82550
# 38      219.85                    50              154900                89700
# 39      220.40                   100              155550                82200
# 40      219.50                   100              153550                83950
# 41      220.00                    50              152000                81600
# 42      220.00                   100              146450                89550
