# %%
import base as b
import pandas as pd
import datetime as dt
from typing import Dict
import talib as ta
import utils as ut
from constants import *
from scipy.stats import linregress
from logger_settings import logger

settings = {
    "vwch_thresh": 3,
    "quantity": 50 * 1, # 1 lot
    "stagnation_cooldown": 5, # cooldown period after stagnation to resume, in ticks
    "svs_mn_thresh": 5000, # stagnation_volume_std_max_threshold
    "svs_mx_thresh": 16000, # stagnation_volume_std_min_threshold
}

instrument = b.Instrument(name="NIFTY 22650 CALL 7 Mar 2024")

SYMBOL = "NIFTY"
expiry = dt.datetime.strptime("2024-03-21", "%Y-%m-%d").date()
otype = "CE"
strike = 22000
date = dt.datetime.strptime("2024-03-15", "%Y-%m-%d").date()

tdf = ut.get_ticks(symbol=SYMBOL, expiry=expiry, strike=strike, otype=otype, date=date)

# %%
REASON_REVERSE_SIGNIFICANCE = "reverse significance found"
REASON_STAGNATING = "trend stagnating"
REASON_CONFIRM = "confirmed"

class Phase(b.BasePhase):
    def __init__(self, initiated_at, strategy):
        super().__init__(initiated_at, strategy)
        self.volume_confirmed = False
        self.parent_volume_confirmed = False
        self.last_slope = None
        self.stagnated_at = None
        self.stagnate_reason = None
        logger.info(f"created new phase{self.id} at: {initiated_at}")
        if initiated_at < strategy.ticks.iloc[-1].name:
            self.rerun()

    def __repr__(self):
        return (f"==Phase {self.id}:{self.direction}, {self.status} I:{self.initiated_at}, C:{self.confirmed_at} R:{self.retraced_at}, "
               f"T:{self.term_at}, RJ:{self.rejected_at}, cr:{self.created_at} tr: {self.term_reason}, rr:{self.retrace_reason}, "
               f"end:{self.ended_at}, vc: {self.volume_confirmed}, pc: {self.parent_volume_confirmed}, st: {self.stagnated_at}==")

    def rerun(self):
        self.next()

    def has_breached_start(self):
        up_breach = self.direction == UP and (self.strategy.ticks.iloc[-1].last_price <= self.strategy.ticks.loc[self.initiated_at].last_price).all()
        if up_breach:
            return up_breach
        down_breach = self.direction == DOWN and (self.strategy.ticks.iloc[-1].last_price >= self.strategy.ticks.loc[self.initiated_at].last_price).all()
        return down_breach

    def get_new_phase_start(self):
        """
        Return new phase start when current phase is breached
        """
        if self.direction == UP:
            return self.strategy.ticks.loc[self.strategy.ticks.index > self.initiated_at].last_price.idxmax()
        else:
            return self.strategy.ticks.loc[self.strategy.ticks.index > self.initiated_at].last_price.idxmin()

    def is_tick_significant(self):
        """
        If a tick has a very high vwch, that could mean that its a very significant tick.
        If opposite direction tick has a very high vwch, its a good sign of reversal.
        Returns -1 if its opposite direction significant
        Returns 1 if same direction significant
        Returns 0 if not significant
        """
        thresh = self.strategy.vwch_thresh
        is_volume_significant = self.pticks.iloc[-1].volume >= (thresh * self.pticks.volume.mean())
        if not is_volume_significant:
            return 0
        if self.direction == UP and self.pticks.iloc[-1].ch <= 0:
            return -1
        if self.direction == DOWN and self.pticks.iloc[-1].ch >= 0:
            return -1
        return 1

    def terminate(self, reason):
        self.status = self.STATUS_TERM
        self.term_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_termination(self, reason)
        self.term_reason = reason
        if self.retraced_at is None:
            self.retraced_at = self.strategy.ticks.iloc[-1].name
            self.retrace_reason = "on phase termination"

    def retracing(self, reason):
        self.status = self.STATUS_RETRACING
        self.retraced_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_retracel(self, reason)
        self.retrace_reason = reason

    def stagnating(self, reason):
        if self.status == self.STATUS_STAGNATING:
            return
        self.status = self.STATUS_STAGNATING
        self.stagnated_at = self.strategy.ticks.iloc[-1].name
        self.strategy.on_stagnation(self, reason)
        self.stagnate_reason = reason

    def confirm(self):
        self.status = self.STATUS_CONFIRMED
        self.strategy.on_confirmed(self, REASON_CONFIRM)

    def calculate_pdata(self):
        self.pticks["ch"] = self.pticks.last_price.diff()
        self.pticks["vwch"] = self.pticks.ch * self.pticks.volume  # Volume weighted change
        self.pticks["std_vwch"] = self.pticks.vwch.rolling(window=5).std()  # Volume weighted change
        # self.pticks["cum_vwch"] = self.pticks.vwch.cumsum()
        # self.last_slope = self.get_slope(self.ended_at)

    def get_slope(self, eidx):
        if self.direction == UP:
            last_idx = self.pticks.last_price.idxmax()
        else:
            last_idx = self.pticks.last_price.idxmin()
        if eidx - last_idx < 6:
            return
        df = self.pticks.loc[last_idx: eidx+1]
        try:
            lr = linregress(df.id, df.cum_vwch)
        except ValueError:
            raise Exception("asd")
        logger.info(f"slope: {last_idx} to {eidx}: {lr.slope}, {self}")
        return lr.slope

    def is_stagnating(self):
        if self.status == Phase.STATUS_STAGNATING:
            logger.info(f"stagnating1? {self.pticks.iloc[-1].name}, {self.pticks.iloc[-1].std_vwch}: {self.pticks.iloc[-1].std_vwch < self.strategy.svs_mx_thresh}")
            return self.pticks.iloc[-1].std_vwch < self.strategy.svs_mx_thresh
        logger.info(f"stagnating2? {self.pticks.iloc[-1].name}, {self.pticks.iloc[-1].std_vwch}: {self.pticks.iloc[-1].std_vwch <= self.strategy.svs_mn_thresh}")
        return self.pticks.iloc[-1].std_vwch <= self.strategy.svs_mn_thresh

    def next(self):
        super().next()
        self.calculate_pdata()
        if self.status == self.STATUS_TERM:
            raise Exception(f"phase {self} already terminated")
        if self.status == self.STATUS_INITIATED:
            if self.pticks.iloc[-1].ch > 0:
                self.direction = UP
            else:
                self.direction = DOWN
            self.confirm()
            return
        if self.has_breached_start():
            self.terminate("breached start")
            return
        if self.status == self.STATUS_RETRACING:
            return
        significance = self.is_tick_significant()
        if significance == -1:
            self.retracing(REASON_REVERSE_SIGNIFICANCE)
            return
        elif significance == 1:
            self.volume_confirmed = True
        is_stagnating = self.is_stagnating()
        if is_stagnating:
            if self.status != self.STATUS_STAGNATING:
                self.stagnating(REASON_STAGNATING)
                return
        else:
            if self.status == self.STATUS_STAGNATING and self.ended_at - self.stagnated_at >= self.strategy.stagnation_cooldown:
                self.confirm()
                return

class PhaseStrategy(b.BasePhaseStrategy):
    def __init__(self, instrument: "Instrument", settings: Dict):
        super().__init__(instrument, settings)
        self.om = b.OrderManager()

    def calculate_data(self):
        pass

    def next(self, tick: Dict):
        super().next(tick)
        self.calculate_data()
        if self.current_phase is None:
            self.current_phase = Phase(initiated_at=self.ticks.iloc[-1].name, strategy=self)
        else:
            self.current_phase.next()
        for phase in self.active_ph:
            phase.next()

    def _terminate_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_TERM:
            raise Exception("expected terminated status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            self.current_phase.status = Phase.STATUS_CONFIRMED
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
        self.inactive_ph.append(last_phase)

    def _retrace_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_RETRACING:
            raise Exception(f"expected {Phase.STATUS_RETRACING} status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            self.current_phase.status = Phase.STATUS_CONFIRMED
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
            if reason == REASON_REVERSE_SIGNIFICANCE:
                self.current_phase.volume_confirmed = True
        self.active_ph.append(last_phase)

    def _stagnate_last_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status != Phase.STATUS_STAGNATING:
            raise Exception(f"expected {Phase.STATUS_STAGNATING} status")
        if self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction:
            self.current_phase = self.active_ph[-1]
            self.current_phase.status = Phase.STATUS_CONFIRMED
            logger.info(f"Reactivated phase: {self.current_phase} at: {last_phase.ended_at}")
            del self.active_ph[-1]
        else:
            new_start = last_phase.get_new_phase_start()
            self.current_phase = Phase(initiated_at=new_start, strategy=self)
            self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed
        self.active_ph.append(last_phase)
    
    def set_new_phase(self, reason):
        last_phase = self.current_phase
        if last_phase.status == Phase.STATUS_TERM:
            self._terminate_last_phase(reason)
        elif last_phase.status == Phase.STATUS_RETRACING:
            self._retrace_last_phase(reason)
        elif last_phase.status == Phase.STATUS_STAGNATING:
            self._stagnate_last_phase(reason)
        else:
            raise Exception("status not handled")
        # if last_phase.status == Phase.STATUS_TERM and self.active_ph is not None and len(self.active_ph) > 0 and self.active_ph[-1].direction != last_phase.direction and self.active_ph[-1].status == Phase.STATUS_RETRACING:
        #     self.current_phase = self.active_ph[-1]
        #     self.current_phase.status = Phase.STATUS_CONFIRMED
        #     del self.active_ph[-1]
        #     self.inactive_ph.append(last_phase)
        # else:
        #     new_start = last_phase.get_new_phase_start()
        #     if last_phase.status == Phase.STATUS_RETRACING and self.active_ph is not None and len(self.active_ph) > 0:
        #         if self.active_ph[-1].direction != last_phase.direction and self.active_ph[-1].status == Phase.STATUS_RETRACING:
        #             self.current_phase = self.active_ph[-1]
        #             del self.active_ph[-1]
        #             self.current_phase.status = Phase.STATUS_CONFIRMED
        #             self.active_ph.append(last_phase)
        #         else:
        #             print(f"ad: {self.active_ph[-1].direction}, cd: {last_phase.direction}, st: {self.active_ph[-1].status}, {self.active_ph[-1]}")
        #             raise NotImplementedError
        #     else:
        #         self.current_phase = Phase(initiated_at=new_start, strategy=self)
        #         if last_phase.status == Phase.STATUS_TERM:
        #             self.inactive_ph.append(last_phase)
        #         elif last_phase.status == Phase.STATUS_RETRACING:
        #             self.active_ph.append(last_phase)
        #             if reason == REASON_REVERSE_SIGNIFICANCE:
        #                 self.current_phase.volume_confirmed = True
        #         if self.active_ph is not None and self.active_ph:
        #             self.current_phase.parent_volume_confirmed = last_phase.volume_confirmed

    def on_termination(self, phase, reason):
        logger.info(f"phase terminated: {phase}")
        if self.om.has_intrade_orders(phase):
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=phase)
        if phase.id != self.current_phase.id:
            idx = [i for i, cphase in enumerate(self.active_ph) if cphase.id == phase.id][0]
            self.inactive_ph.append(self.active_ph[idx])
            del self.active_ph[idx]
            return
        self.set_new_phase(reason)
        if self.current_phase.direction == UP and self.current_phase.status == Phase.STATUS_CONFIRMED and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed:
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_retracel(self, phase, reason):
        logger.info(f"phase retracing {phase}")
        if phase.id != self.current_phase.id:
            return
        if self.om.has_intrade_orders():
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=self.current_phase)
        self.set_new_phase(reason)
        if self.current_phase.direction == UP and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed:
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_confirmed(self, phase, reason):
        logger.info(f"phase on confirmed {phase}")
        if phase.id != self.current_phase.id:
            return
        if self.current_phase.direction == UP and self.current_phase.volume_confirmed and self.current_phase.parent_volume_confirmed:
            order = b.Order(type=b.Order.TYPE_BUY, limit_price=self.ticks.iloc[-1].last_price, created_at=self.ticks.iloc[-1].name, quantity=self.quantity, exchange_order_id=None)
            po = b.PhaseOrder(self.current_phase, order)
            self.om.place_order(po)
            logger.info(f"placed order for phase start: {self.current_phase}, order: {order}")

    def on_stagnation(self, phase, reason):
        logger.info(f"phase stagnating {phase}, slope: {phase.last_slope}")
        if phase.id != self.current_phase.id:
            return
        if self.om.has_intrade_orders():
            self.om.square_off_all_orders(index=self.ticks.iloc[-1].name, last_price=self.ticks.iloc[-1].last_price, phase=self.current_phase)
        # self.set_new_phase(reason)

ps = PhaseStrategy(instrument=instrument, settings=settings)
# for i in range(tdf.shape[0]):
# for i in range(1000, 3000):
for i in range(100):
    ps.next(tdf.iloc[i].to_dict())

print(ps.current_phase)
print(ps.inactive_ph)
print(ps.active_ph)
# Out:
# 2024-03-19 18:50:20,534 - INFO - 399897856.py:13 - [130032296994048] -
# created new phase0 at: 0
# 2024-03-19 18:50:20,543 - INFO - 399897856.py:280 - [130032296994048] -
# phase on confirmed ==Phase 0:DOWN, CONFIRMED I:0, C:None R:None, T:None, RJ:None, cr:0 tr: None, rr:None, end:1, vc: False, pc: False, st: None==
# 2024-03-19 18:50:20,552 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 2, nan: False
# 2024-03-19 18:50:20,559 - INFO - 399897856.py:251 - [130032296994048] -
# phase terminated: ==Phase 0:DOWN, TERMINATED I:0, C:None R:None, T:3, RJ:None, cr:0 tr: None, rr:None, end:3, vc: False, pc: False, st: None==
# 2024-03-19 18:50:20,561 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:20,563 - INFO - 399897856.py:13 - [130032296994048] -
# created new phase1 at: 1
# 2024-03-19 18:50:20,568 - INFO - 399897856.py:280 - [130032296994048] -
# phase on confirmed ==Phase 1:UP, CONFIRMED I:1, C:None R:None, T:None, RJ:None, cr:3 tr: None, rr:None, end:3, vc: False, pc: False, st: None==
# 2024-03-19 18:50:20,575 - INFO - 399897856.py:251 - [130032296994048] -
# phase terminated: ==Phase 1:UP, TERMINATED I:1, C:None R:None, T:4, RJ:None, cr:3 tr: None, rr:None, end:4, vc: False, pc: False, st: None==
# 2024-03-19 18:50:20,576 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:20,579 - INFO - 399897856.py:13 - [130032296994048] -
# created new phase2 at: 3
# 2024-03-19 18:50:20,584 - INFO - 399897856.py:280 - [130032296994048] -
# phase on confirmed ==Phase 2:DOWN, CONFIRMED I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:4, vc: False, pc: False, st: None==
# 2024-03-19 18:50:20,594 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 5, nan: False
# 2024-03-19 18:50:20,606 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 6, nan: False
# 2024-03-19 18:50:20,614 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 7, nan: False
# 2024-03-19 18:50:20,622 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 8, 16668.88189861578: False
# 2024-03-19 18:50:20,628 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 9, 10954.304005732158: False
# 2024-03-19 18:50:20,637 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 10, 10907.995261504253: False
# 2024-03-19 18:50:20,646 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 11, 7042.553381054267: False
# 2024-03-19 18:50:20,654 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 12, 6934.233690538481: False
# 2024-03-19 18:50:20,662 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 13, 6911.247852233265: False
# 2024-03-19 18:50:20,670 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 14, 6969.040599322042: False
# 2024-03-19 18:50:20,678 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 15, 4970.794893676396: True
# 2024-03-19 18:50:20,680 - INFO - 399897856.py:290 - [130032296994048] -
# phase stagnating ==Phase 2:DOWN, STAGNATING I:3, C:None R:None, T:None, RJ:None, cr:4 tr: None, rr:None, end:15, vc: False, pc: False, st: 15==, slope: None
# 2024-03-19 18:50:20,684 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:20,692 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 16, 991.2280892912793: True
# 2024-03-19 18:50:20,715 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 17, 1240.8104710228865: True
# 2024-03-19 18:50:20,737 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 18, 11282.98503278266: True
# 2024-03-19 18:50:20,748 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 19, 11057.9287730568: True
# 2024-03-19 18:50:20,762 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 20, 11568.036458275783: True
# 2024-03-19 18:50:20,774 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 21, 11711.578885871779: True
# 2024-03-19 18:50:20,788 - INFO - 399897856.py:267 - [130032296994048] -
# phase retracing ==Phase 2:DOWN, RETRACING I:3, C:None R:22, T:None, RJ:None, cr:4 tr: None, rr:None, end:22, vc: True, pc: False, st: 15==
# 2024-03-19 18:50:20,793 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:20,797 - INFO - 399897856.py:13 - [130032296994048] -
# created new phase3 at: 19
# 2024-03-19 18:50:20,804 - INFO - 399897856.py:280 - [130032296994048] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:22, vc: False, pc: False, st: None==
# 2024-03-19 18:50:20,807 - INFO - base.py:140 - [130032296994048] -
# place_order called
# 2024-03-19 18:50:20,809 - INFO - 399897856.py:277 - [130032296994048] -
# placed order for phase start: ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:22, vc: True, pc: True, st: None==, order: buy, b:214.2, s:None, pnl:NA
# 2024-03-19 18:50:20,860 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 23, nan: False
# 2024-03-19 18:50:20,910 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 24, 14080.671770195946: False
# 2024-03-19 18:50:20,932 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 25, 22457.595318733398: False
# 2024-03-19 18:50:20,978 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 26, 22457.595318733398: False
# 2024-03-19 18:50:20,996 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 27, 24585.126067401074: False
# 2024-03-19 18:50:21,012 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 28, 24701.3882707026: False
# 2024-03-19 18:50:21,022 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 29, 24510.09228358808: False
# 2024-03-19 18:50:21,039 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 30, 9104.218870941195: False
# 2024-03-19 18:50:21,050 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 31, 9607.228723726832: False
# 2024-03-19 18:50:21,060 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 32, 2945.8309523799935: True
# 2024-03-19 18:50:21,062 - INFO - 399897856.py:290 - [130032296994048] -
# phase stagnating ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:32, vc: True, pc: True, st: 32==, slope: None
# 2024-03-19 18:50:21,063 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:21,065 - INFO - base.py:158 - [130032296994048] -
# squared off buy, b:214.2, s:219.4, pnl:260.0
# 2024-03-19 18:50:21,078 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 33, 2472.8687793734885: True
# 2024-03-19 18:50:21,087 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 34, 4262.692810888464: True
# 2024-03-19 18:50:21,095 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 35, 3895.039152563191: True
# 2024-03-19 18:50:21,103 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 36, 2635.080643927267: True
# 2024-03-19 18:50:21,110 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 37, 2837.0812466336142: True
# 2024-03-19 18:50:21,117 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 38, 4131.636479653073: True
# 2024-03-19 18:50:21,126 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 39, 2803.096502084804: True
# 2024-03-19 18:50:21,133 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 40, 2830.6324381664604: True
# 2024-03-19 18:50:21,141 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 41, 3247.381830028629: True
# 2024-03-19 18:50:21,148 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 42, 3310.4189689524337: True
# 2024-03-19 18:50:21,157 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 43, 3148.8839292676694: True
# 2024-03-19 18:50:21,167 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 44, 3744.7803673914204: True
# 2024-03-19 18:50:21,176 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 45, 3302.0039370055565: True
# 2024-03-19 18:50:21,186 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 46, 2595.4313225358533: True
# 2024-03-19 18:50:21,200 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 47, 3885.828660015826: True
# 2024-03-19 18:50:21,211 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 48, 15658.55403206196: True
# 2024-03-19 18:50:21,221 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 49, 16315.31724714552: False
# 2024-03-19 18:50:21,223 - INFO - 399897856.py:280 - [130032296994048] -
# phase on confirmed ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:49, vc: True, pc: True, st: 32==
# 2024-03-19 18:50:21,225 - INFO - base.py:140 - [130032296994048] -
# place_order called
# 2024-03-19 18:50:21,227 - INFO - 399897856.py:287 - [130032296994048] -
# placed order for phase start: ==Phase 3:UP, CONFIRMED I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:49, vc: True, pc: True, st: 32==, order: buy, b:222.0, s:None, pnl:NA
# 2024-03-19 18:50:21,237 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 50, 16431.298697151244: False
# 2024-03-19 18:50:21,247 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 51, 16529.01070844847: False
# 2024-03-19 18:50:21,258 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 52, 15854.406485264712: False
# 2024-03-19 18:50:21,268 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 53, 1397.4780856958687: True
# 2024-03-19 18:50:21,271 - INFO - 399897856.py:290 - [130032296994048] -
# phase stagnating ==Phase 3:UP, STAGNATING I:19, C:None R:None, T:None, RJ:None, cr:22 tr: None, rr:None, end:53, vc: True, pc: True, st: 53==, slope: None
# 2024-03-19 18:50:21,272 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:21,274 - INFO - base.py:158 - [130032296994048] -
# squared off buy, b:222.0, s:222.4, pnl:20.0
# 2024-03-19 18:50:21,284 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 54, 619.2899159522815: True
# 2024-03-19 18:50:21,295 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 55, 4130.849791507815: True
# 2024-03-19 18:50:21,306 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 56, 5232.721089452405: True
# 2024-03-19 18:50:21,312 - INFO - 399897856.py:251 - [130032296994048] -
# phase terminated: ==Phase 2:DOWN, TERMINATED I:3, C:None R:22, T:56, RJ:None, cr:4 tr: None, rr:reverse significance found, end:56, vc: True, pc: False, st: 15==
# 2024-03-19 18:50:21,313 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:21,324 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 57, 5643.052587031234: True
# 2024-03-19 18:50:21,332 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 58, 5685.140609518811: True
# 2024-03-19 18:50:21,340 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 59, 5225.589261030751: True
# 2024-03-19 18:50:21,349 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 60, 4641.793632314989: True
# 2024-03-19 18:50:21,357 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 61, 2194.1167072423923: True
# 2024-03-19 18:50:21,364 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 62, 2326.602942059547: True
# 2024-03-19 18:50:21,371 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 63, 2363.6809217828322: True
# 2024-03-19 18:50:21,379 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 64, 1571.559734785821: True
# 2024-03-19 18:50:21,386 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 65, 1401.9736088814625: True
# 2024-03-19 18:50:21,393 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 66, 1053.9236215211154: True
# 2024-03-19 18:50:21,398 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 67, 1609.0175573933864: True
# 2024-03-19 18:50:21,404 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 68, 1620.0787017920425: True
# 2024-03-19 18:50:21,410 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 69, 1290.0855107318173: True
# 2024-03-19 18:50:21,417 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 70, 1498.1624160952024: True
# 2024-03-19 18:50:21,422 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 71, 1757.2878605966125: True
# 2024-03-19 18:50:21,429 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 72, 3356.9329379658993: True
# 2024-03-19 18:50:21,438 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 73, 3335.455834664939: True
# 2024-03-19 18:50:21,447 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 74, 3403.018696686868: True
# 2024-03-19 18:50:21,456 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 75, 4736.959863667847: True
# 2024-03-19 18:50:21,464 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 76, 4694.841584121884: True
# 2024-03-19 18:50:21,470 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 77, 3548.8871495160206: True
# 2024-03-19 18:50:21,477 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 78, 2816.06551770373: True
# 2024-03-19 18:50:21,483 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 79, 3461.0988139606725: True
# 2024-03-19 18:50:21,489 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 80, 1912.1270878265655: True
# 2024-03-19 18:50:21,503 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 81, 3809.3952932191323: True
# 2024-03-19 18:50:21,513 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 82, 3815.551074222445: True
# 2024-03-19 18:50:21,520 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 83, 4150.61742395034: True
# 2024-03-19 18:50:21,527 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 84, 3724.292550270476: True
# 2024-03-19 18:50:21,533 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 85, 4246.804681169148: True
# 2024-03-19 18:50:21,542 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 86, 3012.9254886239823: True
# 2024-03-19 18:50:21,551 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 87, 3101.0635272435293: True
# 2024-03-19 18:50:21,566 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 88, 2703.6951566328617: True
# 2024-03-19 18:50:21,576 - INFO - 399897856.py:267 - [130032296994048] -
# phase retracing ==Phase 3:UP, RETRACING I:19, C:None R:89, T:None, RJ:None, cr:22 tr: None, rr:None, end:89, vc: True, pc: True, st: 53==
# 2024-03-19 18:50:21,577 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:21,580 - INFO - 399897856.py:13 - [130032296994048] -
# created new phase4 at: 80
# 2024-03-19 18:50:21,585 - INFO - 399897856.py:280 - [130032296994048] -
# phase on confirmed ==Phase 4:DOWN, CONFIRMED I:80, C:None R:None, T:None, RJ:None, cr:89 tr: None, rr:None, end:89, vc: False, pc: False, st: None==
# 2024-03-19 18:50:21,595 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 90, 2097.0592504742376: True
# 2024-03-19 18:50:21,597 - INFO - 399897856.py:290 - [130032296994048] -
# phase stagnating ==Phase 4:DOWN, STAGNATING I:80, C:None R:None, T:None, RJ:None, cr:89 tr: None, rr:None, end:90, vc: True, pc: True, st: 90==, slope: None
# 2024-03-19 18:50:21,599 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:21,609 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 91, 1898.391095111778: True
# 2024-03-19 18:50:21,620 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 92, 2006.7841189324981: True
# 2024-03-19 18:50:21,629 - INFO - 399897856.py:251 - [130032296994048] -
# phase terminated: ==Phase 4:DOWN, TERMINATED I:80, C:None R:None, T:93, RJ:None, cr:89 tr: None, rr:None, end:93, vc: True, pc: True, st: 90==
# 2024-03-19 18:50:21,631 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:21,632 - INFO - 399897856.py:173 - [130032296994048] -
# Reactivated phase: ==Phase 3:UP, CONFIRMED I:19, C:None R:89, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:92, vc: True, pc: True, st: 53== at: 93
# 2024-03-19 18:50:21,634 - INFO - base.py:140 - [130032296994048] -
# place_order called
# 2024-03-19 18:50:21,636 - INFO - 399897856.py:264 - [130032296994048] -
# placed order for phase start: ==Phase 3:UP, CONFIRMED I:19, C:None R:89, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:92, vc: True, pc: True, st: 53==, order: buy, b:227.25, s:None, pnl:NA
# 2024-03-19 18:50:21,643 - INFO - 399897856.py:112 - [130032296994048] -
# stagnating2? 94, 3109.970558542349: True
# 2024-03-19 18:50:21,645 - INFO - 399897856.py:290 - [130032296994048] -
# phase stagnating ==Phase 3:UP, STAGNATING I:19, C:None R:89, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:94, vc: True, pc: True, st: 94==, slope: None
# 2024-03-19 18:50:21,647 - INFO - base.py:145 - [130032296994048] -
# has_intrade_orders called
# 2024-03-19 18:50:21,648 - INFO - base.py:158 - [130032296994048] -
# squared off buy, b:227.25, s:226.15, pnl:-55.00000000000001
# 2024-03-19 18:50:21,656 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 95, 3109.970558542349: True
# 2024-03-19 18:50:21,664 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 96, 8841.972595241377: True
# 2024-03-19 18:50:21,675 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 97, 8841.972595241377: True
# 2024-03-19 18:50:21,684 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 98, 8357.08053090307: True
# 2024-03-19 18:50:21,693 - INFO - 399897856.py:110 - [130032296994048] -
# stagnating1? 99, 8384.623500789956: True
# ==Phase 3:UP, STAGNATING I:19, C:None R:89, T:None, RJ:None, cr:22 tr: None, rr:reverse significance found, end:99, vc: True, pc: True, st: 94==
# [==Phase 0:DOWN, TERMINATED I:0, C:None R:3, T:3, RJ:None, cr:0 tr: breached start, rr:on phase termination, end:3, vc: False, pc: False, st: None==, ==Phase 1:UP, TERMINATED I:1, C:None R:4, T:4, RJ:None, cr:3 tr: breached start, rr:on phase termination, end:4, vc: False, pc: False, st: None==, ==Phase 2:DOWN, TERMINATED I:3, C:None R:22, T:56, RJ:None, cr:4 tr: breached start, rr:reverse significance found, end:56, vc: True, pc: False, st: 15==, ==Phase 4:DOWN, TERMINATED I:80, C:None R:93, T:93, RJ:None, cr:89 tr: breached start, rr:on phase termination, end:93, vc: True, pc: True, st: 90==]
# []

# %%
print(f"Total orders: {len(ps.om.closed_orders)}")
print(f"Total PNL %: {sum([po.order.pnl for po in ps.om.closed_orders]) * 100 / sum([po.order.limit_price * po.order.quantity for po in ps.om.closed_orders])}")
# Out:
# Total orders: 3
# Total PNL %: 0.6024550041418781

# %%
from bokeh.models import ColumnDataSource
all_phases = ps.inactive_ph + [phase for phase in ps.active_ph if phase.retraced_at is not None]
up_ini_idx = [ps.ticks.loc[phase.initiated_at].id for phase in all_phases if phase.direction == UP]
up_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == UP]

up_end_idx = [ps.ticks.loc[phase.retraced_at].id for phase in all_phases if phase.direction == UP]
up_end = [ps.ticks.loc[phase.retraced_at].last_price for phase in all_phases if phase.direction == UP]

down_ini_idx = [ps.ticks.loc[phase.initiated_at].id for phase in all_phases if phase.direction == DOWN]
down_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == DOWN]
down_end_idx = [ps.ticks.loc[phase.retraced_at].id for phase in all_phases if phase.direction == DOWN]
down_end = [ps.ticks.loc[phase.retraced_at].last_price for phase in all_phases if phase.direction == DOWN]

up_ini_plot = ColumnDataSource({'x': up_ini_idx, 'y': up_initiate})
up_end_plot = ColumnDataSource({'x': up_end_idx, 'y': up_end})

down_ini_plot = ColumnDataSource({'x': down_ini_idx, 'y': down_initiate})
down_end_plot = ColumnDataSource({'x': down_end_idx, 'y': down_end})

order_created_at = [ps.ticks.loc[po.order.created_at].id for po in ps.om.closed_orders]
order_created_at_price = [ps.ticks.loc[po.order.created_at].last_price for po in ps.om.closed_orders]

order_sqo_at = [ps.ticks.loc[po.order.square_off_at].id for po in ps.om.closed_orders]
order_sqo_at_price = [ps.ticks.loc[po.order.square_off_at].last_price for po in ps.om.closed_orders]
order_at_cds = ColumnDataSource({'x': order_created_at, 'y': order_created_at_price})
order_sqo_at_cds = ColumnDataSource({'x': order_sqo_at, 'y': order_sqo_at_price})

down_initiate = [ps.ticks.loc[phase.initiated_at].last_price for phase in all_phases if phase.direction == DOWN]

ticks_cdf = ColumnDataSource(ps.ticks)
# ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end'])
# ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end'])
ut.bokeh_plot(cds=ticks_cdf, x_label="timestamp", y_label="price", plot='line', subplots=[up_ini_plot, up_end_plot, down_ini_plot, down_end_plot, order_at_cds, order_sqo_at_cds], subplot_labels=['Up Initiate', 'Up end', 'Down Initiate', 'Down end', 'Order At', 'Order SQO'])
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c951d8e2-ae1f-4b58-a92a-23362ca6e2cc">Loading BokehJS ...</span>
#     </div>
#   <div id="e26fbc15-e232-4714-a026-fa2d4c89ab64" data-root-id="p1022" style="display: contents;"></div>

# %%
# for i, row in ps.ticks.iterrows():

# ps.ticks['vwch_rolling'] = ps.ticks.vwch.rolling(window=5).sum()
# ps.ticks['vwch_cum'] = ps.ticks.vwch.cumsum()
ps.ticks.head(100)
# Out:
#     last_price  last_traded_quantity  total_buy_quantity  total_sell_quantity  \
# 0       220.35                    50               43000                45600
# 1       218.10                   250               56350                42950
# 2       218.30                   200               73600                47500
# 3       223.15                    50               89500                58800
# 4       218.10                    50               95500                67350
# ..         ...                   ...                 ...                  ...
# 76      224.95                    50              168600                82900
# 77      224.90                   100              157450                72000
# 78      224.40                    50              166000                88700
# 79      226.80                   300              174850                82250
# 80      227.10                    50              182150                84750
#
#        last_trade_time       oi  volume  id
# 0  2024-03-15 09:15:02  1879800     0.0   0
# 1  2024-03-15 09:15:03  1879800  7550.0   1
# 2  2024-03-15 09:15:03  1879800  1900.0   1
# 3  2024-03-15 09:15:04  1879800  2400.0   2
# 4  2024-03-15 09:15:05  1879800  6600.0   3
# ..                 ...      ...     ...  ..
# 76 2024-03-15 09:15:52  1906300  3800.0  50
# 77 2024-03-15 09:15:53  1906300  3500.0  51
# 78 2024-03-15 09:15:53  1906300  3100.0  51
# 79 2024-03-15 09:15:54  1906300  1400.0  52
# 80 2024-03-15 09:15:54  1906300  2900.0  52
#
# [81 rows x 8 columns]

# %% [markdown]
# # Per Quantity Movement Chart

# %%
# from matplotlib import pyplot as plt

# plt.ion()
# plt.figure(figsize=(30, 12))  # Adjust the width and height as needed

# plt.plot(ps.ticks.loc[ps.ticks.pqch.notna()].pqch)

# ut.bokeh_series_plot(ps.ticks, 'vwch_cum', 'id')
# ps.inactive_ph[5]
# ps.inactive_ph[2].id
ut.bokeh_series_plot(ps.inactive_ph[2].pticks, 'cum_vwch', 'id')
# ut.bokeh_series_plot(ps.current_phase.pticks, 'cum_vwch', 'id')
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b1136ddf-f9d9-4844-a8c3-efb364051881">Loading BokehJS ...</span>
#     </div>
#   <div id="e987517b-c7fa-435e-bf20-180320e530e4" data-root-id="p1139" style="display: contents;"></div>

# %%
# print(ps.inactive_ph[5].pticks.to_json())
ps.inactive_ph[2].pticks['rolling_std'] = ps.inactive_ph[2].pticks.vwch.rolling(window=7).std()
print(ps.inactive_ph[2].pticks.vwch.abs().quantile(.7))
ps.inactive_ph[2].pticks
# Out:
# 5125.000000000037
#     last_price  last_traded_quantity  total_buy_quantity  total_sell_quantity  \
# 3       223.15                    50               89500                58800
# 4       218.10                    50               95500                67350
# 5       222.70                    50              104800                61750
# 6       219.60                    50               99900                76650
# 7       218.30                   100              108000                80000
# 8       216.55                   250              108800                82850
# 9       215.30                    50              106600                77100
# 10      217.95                   200              114050                67850
# 11      216.30                    50              106450                66550
# 12      215.95                    50              116000                73650
# 13      215.20                    50              111700                78350
# 14      216.05                   100              114200                79200
# 15      216.00                    50              123150                85050
# 16      215.50                    50              120050                71350
# 17      214.00                    50              116700                79900
# 18      212.80                    50              115050                74900
# 19      212.35                    50              122000                93250
# 20      212.75                    50              118000                81550
# 21      212.80                    50              118000                81550
# 22      214.20                    50              119450                77800
# 23      214.30                    50              121350                80500
# 24      214.00                   550              119850                86250
# 25      217.40                    50              128750                82600
# 26      218.25                   100              128750                82600
# 27      217.20                    50              135850                82400
# 28      217.00                   200              136000                84100
# 29      218.10                    50              141150                84750
# 30      219.10                   400              142400                91450
# 31      220.00                    50              144150                85500
# 32      219.40                    50              143200                90100
# 33      221.10                    50              146100                87900
# 34      219.10                    50              147900                89700
# 35      218.80                    50              146650                92450
# 36      218.60                    50              150400                81050
# 37      219.00                    50              150800                82550
# 38      219.85                    50              154900                89700
# 39      220.40                   100              155550                82200
# 40      219.50                   100              153550                83950
# 41      220.00                    50              152000                81600
# 42      220.00                   100              146450                89550
# 43      219.10                    50              155000                90050
# 44      220.50                    50              152500                88300
# 45      221.25                    50              163550                83400
# 46      222.40                    50              162000                85200
# 47      220.95                    50              162050                86850
# 48      222.50                    50              163300                87450
# 49      222.00                   100              166050                86350
# 50      222.00                    50              162100                86950
# 51      222.00                   200              166100                83050
# 52      222.00                    50              168100                89250
# 53      222.40                    50              163100                89800
# 54      222.00                    50              169250                84950
# 55      223.00                   200              172800                83550
# 56      224.10                   400              172050                85450
#
#        last_trade_time       oi   volume  id    ch     vwch      std_vwch  \
# 3  2024-03-15 09:15:04  1879800   2400.0   2   NaN      NaN           NaN
# 4  2024-03-15 09:15:05  1879800   6600.0   3 -5.05 -33330.0           NaN
# 5  2024-03-15 09:15:05  1879800   1850.0   3  4.60   8510.0           NaN
# 6  2024-03-15 09:15:06  1879800   6950.0   4 -3.10 -21545.0           NaN
# 7  2024-03-15 09:15:07  1879800   3350.0   5 -1.30  -4355.0           NaN
# 8  2024-03-15 09:15:08  1879800   1250.0   6 -1.75  -2187.5  16668.881899
# 9  2024-03-15 09:15:08  1879800    400.0   6 -1.25   -500.0  10954.304006
# 10 2024-03-15 09:15:09  1879800   3150.0   7  2.65   8347.5  10907.995262
# 11 2024-03-15 09:15:10  1879800   6750.0   8 -1.65 -11137.5   7042.553381
# 12 2024-03-15 09:15:10  1879800    600.0   8 -0.35   -210.0   6934.233691
# 13 2024-03-15 09:15:11  1879800   1650.0   9 -0.75  -1237.5   6911.247852
# 14 2024-03-15 09:15:11  1879800   1200.0   9  0.85   1020.0   6969.040599
# 15 2024-03-15 09:15:12  1879800   4850.0  10 -0.05   -242.5   4970.794894
# 16 2024-03-15 09:15:13  1879800   2950.0  11 -0.50  -1475.0    991.228089
# 17 2024-03-15 09:15:13  1879800   1450.0  11 -1.50  -2175.0   1240.810471
# 18 2024-03-15 09:15:14  1879800  21500.0  12 -1.20 -25800.0  11282.985033
# 19 2024-03-15 09:15:14  1879800   1400.0  12 -0.45   -630.0  11057.928773
# 20 2024-03-15 09:15:15  1879800   7500.0  13  0.40   3000.0  11568.036458
# 21 2024-03-15 09:15:15  1879800      0.0  13  0.05      0.0  11711.578886
# 22 2024-03-15 09:15:16  1879800  22900.0  14  1.40  32060.0  20542.548041
# 23 2024-03-15 09:15:17  1879800   5850.0  15  0.10    585.0  14074.557542
# 24 2024-03-15 09:15:17  1879800   2250.0  15 -0.30   -675.0  14080.671770
# 25 2024-03-15 09:15:18  1879800  13950.0  16  3.40  47430.0  22457.595319
# 26 2024-03-15 09:15:18  1879800      0.0  16  0.85      0.0  22457.595319
# 27 2024-03-15 09:15:19  1906300  17450.0  17 -1.05 -18322.5  24585.126067
# 28 2024-03-15 09:15:20  1906300   6650.0  18 -0.20  -1330.0  24701.388271
# 29 2024-03-15 09:15:21  1906300   3300.0  19  1.10   3630.0  24510.092284
# 30 2024-03-15 09:15:21  1906300   3500.0  19  1.00   3500.0   9104.218871
# 31 2024-03-15 09:15:22  1906300   4900.0  20  0.90   4410.0   9607.228724
# 32 2024-03-15 09:15:23  1906300   2750.0  21 -0.60  -1650.0   2945.830952
# 33 2024-03-15 09:15:23  1906300    700.0  21  1.70   1190.0   2472.868779
# 34 2024-03-15 09:15:24  1906300   3050.0  22 -2.00  -6100.0   4262.692811
# 35 2024-03-15 09:15:25  1906300   5600.0  23 -0.30  -1680.0   3895.039153
# 36 2024-03-15 09:15:26  1906300   6050.0  24 -0.20  -1210.0   2635.080644
# 37 2024-03-15 09:15:26  1906300   1050.0  24  0.40    420.0   2837.081247
# 38 2024-03-15 09:15:27  1906300   6300.0  25  0.85   5355.0   4131.636480
# 39 2024-03-15 09:15:27  1906300   2550.0  25  0.55   1402.5   2803.096502
# 40 2024-03-15 09:15:28  1906300   2000.0  26 -0.90  -1800.0   2830.632438
# 41 2024-03-15 09:15:29  1906300  11450.0  27  0.50   5725.0   3247.381830
# 42 2024-03-15 09:15:29  1906300   1550.0  27  0.00      0.0   3310.418969
# 43 2024-03-15 09:15:30  1906300   2200.0  28 -0.90  -1980.0   3148.883929
# 44 2024-03-15 09:15:31  1906300   3650.0  29  1.40   5110.0   3744.780367
# 45 2024-03-15 09:15:32  1906300   2000.0  30  0.75   1500.0   3302.003937
# 46 2024-03-15 09:15:32  1906300   1150.0  30  1.15   1322.5   2595.431323
# 47 2024-03-15 09:15:33  1906300   3550.0  31 -1.45  -5147.5   3885.828660
# 48 2024-03-15 09:15:34  1906300  22400.0  32  1.55  34720.0  15658.554032
# 49 2024-03-15 09:15:35  1906300   5150.0  33 -0.50  -2575.0  16315.317247
# 50 2024-03-15 09:15:35  1906300   3450.0  33  0.00      0.0  16431.298697
# 51 2024-03-15 09:15:36  1906300   4400.0  34  0.00      0.0  16529.010708
# 52 2024-03-15 09:15:36  1906300   3350.0  34  0.00      0.0  15854.406485
# 53 2024-03-15 09:15:37  1906300   3100.0  35  0.40   1240.0   1397.478086
# 54 2024-03-15 09:15:37  1906300    950.0  35 -0.40   -380.0    619.289916
# 55 2024-03-15 09:15:38  1906300   9350.0  36  1.00   9350.0   4130.849792
# 56 2024-03-15 09:15:39  1906300   9250.0  37  1.10  10175.0   5232.721089
#
#      rolling_std
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10  15551.636063
# 11  10642.914282
# 12   9481.722549
# 13   5789.709776
# 14   5721.224166
# 15   5692.233692
# 16   5702.277688
# 17   4072.087843
# 18   9536.062302
# 19   9507.296368
# 20   9867.545393
# 21   9792.483375
# 22  16863.391492
# 23  16836.830271
# 24  16799.104887
# 25  19716.544811
# 26  19652.313841
# 27  22660.675760
# 28  22751.421221
# 29  20252.367344
# 30  20188.945739
# 31  20046.299883
# 32   7868.345923
# 33   7916.209692
# 34   3787.903680
# 35   3818.601090
# 36   3582.233940
# 37   3220.000000
# 38   3477.502696
# 39   3504.203980
# 40   3504.559488
# 41   3201.211592
# 42   3008.846233
# 43   3132.275103
# 44   3401.865516
# 45   3057.792981
# 46   3058.029682
# 47   3812.530445
# 48  13451.872779
# 49  13647.569566
# 50  13505.654294
# 51  13635.563718
# 52  13697.811011
# 53  13700.579813
# 54  13280.138365
# 55   3816.794498
# 56   4712.944813
