# %%
import pandas as pd
import datetime as dt
from logger_settings import logger
import phase as ph

pd.options.display.max_colwidth = 10
pd.options.display.max_rows = None

ticks_columns = {
    'last_price': float,
    'last_traded_quantity': int,
    'total_buy_quantity': int,
    'total_sell_quantity': int,
    'last_trade_time': 'datetime64[ns]',
    'volume_traded': 'int',
    'oi': int,
}
tdf = pd.read_json('ticks-formatted.json', dtype=ticks_columns, convert_dates={'last_trade_time': '%Y-%m-%d %H:%M:%S'})
columns_to_drop = set(tdf.columns).difference(ticks_columns.keys())
tdf.drop(columns=columns_to_drop, inplace=True)
tdf.set_index('last_trade_time', inplace=True, drop=False)
tdf['volume'] = tdf.volume_traded - tdf.volume_traded.shift(1)
tdf.drop('volume_traded', inplace=True, axis=1)
tdf.fillna({'volume': 0}, inplace=True)

class Settings:
    # MIN_UP_PC_CHG = 0.5 / 100 # .5%
    # MIN_DOWN_PC_CHG = -0.5 / 100 # -.5%
    # BREACH_PC = 5 / 100 # 5% Percentage of continuation phase gains required to breach the trend
    # LAST_TICKS_BREACH = {ph.Direction.UP: 5, ph.Direction.DOWN: 5}
    QUANTITY = 50
    CONFIRM_TICKS = 5 # 5 Seconds
    TP = .01 # 2%

# %%
class ContinuationPhase(ph.Phase):
    def __init__(self, ticks, pm):
        self.phase_type = ph.Phase.TYPE_CONT
        self.t_start = ticks[0]
        self.t_end = ticks[-1]
        self.status = self.STATUS_INITIATED
        # self.min_pc = None
        self.direction = None
        self.pm = pm
        self.last_processed_tid = ticks[-1].id
        self.started_at = None
        self.terminated_at = None
        self.hard_retraced_at = None
        self.soft_retraced_at = None
        self.second_last_5sec = ph.Candle(ticks, confirm_ticks=self.pm.settings.CONFIRM_TICKS)
        self.last_5sec = ph.Candle([], confirm_ticks=self.pm.settings.CONFIRM_TICKS)
        self.up_sum, self.down_sum = self.get_sums(ticks)
        self.confidence_at_confirmation = None
        self.svac = 0 # Second last candle volume at confirmation
        self.lvac = 0 # last candle volume at confirmation

    def get_sums(self, ticks):
        if len(ticks) == 1:
            return 0, 0
        cur_price = ticks[0].last_price
        up_sum = down_sum = 0
        for i in range(1, len(ticks)):
            ch = ticks[i].last_price - cur_price
            if ch >= 0:
                up_sum += ch
            else:
                down_sum += ch
            cur_price = ticks[i].last_price
        return up_sum, down_sum

    @property
    def confidence(self):
        total = (self.up_sum + abs(self.down_sum))
        if total == 0:
            logger.info(f"u: {self.up_sum}, d: {self.down_sum}")
            return 0
        if self.direction == ph.Direction.UP:
            return self.up_sum * 100 / total
        return self.down_sum * 100 / total

    def start_phase(self):
        if len(self.last_5sec) < 1:
            return False
        is_red_breach = self.second_last_5sec.IS_RED and self.last_5sec.CLOSE >= self.second_last_5sec.OPEN
        is_green_breach = (not self.second_last_5sec.IS_RED) and self.last_5sec.CLOSE <= self.second_last_5sec.OPEN
        if is_red_breach or is_green_breach:
            raise ph.PhaseStartFailed(f'failed to start phase at: {self.last_5sec.end_id}')
        # if self.second_last_5sec.volume > self.last_5sec.volume:
        #     return False
        price_change = self.last_5sec.CLOSE - self.second_last_5sec.OPEN
        self.direction = ph.Direction.UP if price_change >= 0 else ph.Direction.DOWN
        # self.min_pc = Settings.MIN_UP_PC_CHG if price_change >= 0 else Settings.MIN_DOWN_PC_CHG
        self.status = self.STATUS_STARTED
        self.started_at = self.last_5sec[-1]
        self.confidence_at_confirmation = self.confidence
        self.svac = self.second_last_5sec.volume
        self.lvac = self.last_5sec.volume
        return True

    def update_sum(self):
        if self.t_start.id == 51463:
            print(f"before u: {self.up_sum}, d: {self.down_sum}")
        ch = self.pm.ticks[-1].last_price - self.pm.ticks[-2].last_price
        if ch >= 0:
            self.up_sum += ch
        else:
            self.down_sum += ch
        if self.t_start.id == 51463:
            print(f"after u: {self.up_sum}, d: {self.down_sum}, ch: {ch}, -1 id: {self.pm.ticks[-1].id}, -2 id: {self.pm.ticks[-2].id}")

    def process(self, tick):
        """
        if it breaks previous open or previous nth tick
        """
        self.last_processed_tid = tick.id
        self.update_last_nsec(tick)
        self.update_sum()
        self.t_end = tick
        if self.status == self.STATUS_INITIATED:
            has_started = self.start_phase()
            if not has_started:
                return
            self.pm.on_phase_start(self, tick)
            return
        elif self.status == self.STATUS_TERM or self.status == self.STATUS_HARD_RETR:
            return
        change = self.last_5sec.CLOSE - self.second_last_5sec.OPEN
        open_change = self.last_5sec.CLOSE - self.t_start.last_price
        last_5sec_breach = (self.direction == ph.Direction.UP and change < 0) or (self.direction == ph.Direction.DOWN and change > 0)
        open_breach = (self.direction == ph.Direction.UP and open_change < 0) or (self.direction == ph.Direction.DOWN and open_change > 0)
        if last_5sec_breach or open_breach:
            self.status = self.STATUS_HARD_RETR
            self.hard_retraced_at = tick
            raise ph.PhaseHardRetraceException(f"Continuation Phase {self} hard retracing at: {tick}")
        self.status = self.STATUS_ONG

# %%
class MyPhaseManager(ph.PhaseManager):
    def __init__(self, instrument, settings):
        super().__init__(instrument, settings)

    def process(self, tick):
        if self.current_phase is None:
            # First call
            self.current_phase = ContinuationPhase(ticks=[tick], pm=self)
            return
        # Has existing phase
        try:
            self.current_phase.process(tick)
            self.on_ongoing(self.current_phase, tick)
        except ph.PhaseSoftRetraceException:
            self.on_soft_retracel(self.current_phase, tick)
        except ph.PhaseHardRetraceException:
            self.on_hard_retracel(self.current_phase, tick)
            self.ps.append(self.current_phase)
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        except ph.PhaseTerminatedException:
            self.on_hard_retracel(self.current_phase, tick)
            self.on_termination(self.current_phase, tick)
            self.aps.append(self.current_phase)
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        except ph.PhaseStartFailed:
            # logger.info(f"phase start failed at: {tick}, phase: {self.current_phase}")
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        # self.process_ps(tick)

    def process_ps(self, tick):
        # Process for process stack
        mark_for_removal = []
        for i in range(len(self.ps)):
            phase = self.ps[i]
            try:
                phase.process(tick)
            except ph.PhaseSoftRetraceException:
                # logger.info(f"soft retracel of {phase}")
                pass
            except ph.PhaseHardRetraceException:
                pass
            except ph.PhaseTerminatedException:
                mark_for_removal.append(i)
                self.aps.append(phase)
        mark_for_removal.reverse()
        for mark in mark_for_removal:
            del self.ps[mark]

    def on_ongoing(self, phase, tick):
        if self.current_order is None:
            if phase.direction == ph.Direction.UP:
                self.on_phase_start(phase, tick)
            return

        if (tick.last_price - self.current_order.limit_price) / self.current_order.limit_price > self.settings.TP:
            self.current_order.square_off(tick.last_price)
            self.closed_orders.append(ph.PhaseOrder(phase, self.current_order))
            self.current_order = None

    def on_phase_start(self, phase, tick):
        self.current_order = ph.Order(type=ph.Order.TYPE_BUY, limit_price=tick.last_price, quantity=Settings.QUANTITY)

    def on_hard_retracel(self, phase, tick):
        if self.current_order is None:
            return
        if phase.direction == ph.Direction.UP:
            if self.current_order is not None:
                self.current_order.square_off(tick.last_price)
                self.closed_orders.append(ph.PhaseOrder(phase, self.current_order))
                self.current_order = None
            logger.info(f"Retracel {phase}, Up change %: {phase.hard_retraced_at.last_price - phase.started_at.last_price}")
        else:
            logger.info(f"Retracel {phase}, Down change %: {phase.started_at.last_price - phase.hard_retraced_at.last_price}")

instrument = ph.Instrument(name="NIFTY 22650 CALL 7 Mar 2024")
pm = MyPhaseManager(instrument=instrument, settings=Settings)
# for i in range(100):
for i in range(tdf.shape[0]):
    pm.next(tdf.iloc[i].to_dict())

print(pm.current_phase)
# print(pm.ps)
# print(pm.aps)
# Out:
# 2024-03-13 07:13:05,032 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51391 8.6, v: 0.0 to Tick: 51410 8.45, v: 5600.0, confirmation:Tick: 51397 8.5, v: 4100.0 terminated at: None, hard retracel: Tick: 51410 8.45, v: 5600.0, soft: None, conf: -62.50000000000006, Down change %: 0.05000000000000071
# 2024-03-13 07:13:05,040 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51405 8.4, v: 17850.0 to Tick: 51428 8.65, v: 8600.0, confirmation:Tick: 51410 8.45, v: 0.0 terminated at: None, hard retracel: Tick: 51428 8.65, v: 8600.0, soft: None, conf: 59.99999999999986, Up change %: 0.20000000000000107
# 2024-03-13 07:13:05,059 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51463 7.6, v: 11650.0 to Tick: 51475 7.5, v: 4850.0, confirmation:Tick: 51469 7.75, v: 0.0 terminated at: None, hard retracel: Tick: 51475 7.5, v: 4850.0, soft: None, conf: 63.636363636363654, Up change %: -0.25
# 2024-03-13 07:13:05,067 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51470 7.7, v: 1100.0 to Tick: 51484 7.85, v: 0.0, confirmation:Tick: 51475 7.6, v: 0.0 terminated at: None, hard retracel: Tick: 51484 7.85, v: 0.0, soft: None, conf: -62.50000000000003, Down change %: -0.25
# 2024-03-13 07:13:05,084 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51479 7.3, v: 13600.0 to Tick: 51509 8.0, v: 7700.0, confirmation:Tick: 51486 7.9, v: 14200.0 terminated at: None, hard retracel: Tick: 51509 8.0, v: 7700.0, soft: None, conf: 77.27272727272728, Up change %: 0.09999999999999964
# 2024-03-13 07:13:05,092 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51521 7.65, v: 12750.0 to Tick: 51528 7.5, v: 12450.0, confirmation:Tick: 51526 7.85, v: 2100.0 terminated at: None, hard retracel: Tick: 51528 7.5, v: 12450.0, soft: None, conf: 64.28571428571425, Up change %: -0.34999999999999964
# 2024-03-13 07:13:05,100 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51535 7.45, v: 2600.0 to Tick: 51555 7.75, v: 14700.0, confirmation:Tick: 51540 7.65, v: 0.0 terminated at: None, hard retracel: Tick: 51555 7.75, v: 14700.0, soft: None, conf: 64.28571428571429, Up change %: 0.09999999999999964
# 2024-03-13 07:13:05,109 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51562 7.65, v: 300.0 to Tick: 51586 8.25, v: 700.0, confirmation:Tick: 51567 8.1, v: 5350.0 terminated at: None, hard retracel: Tick: 51586 8.25, v: 700.0, soft: None, conf: 84.61538461538464, Up change %: 0.15000000000000036
# 2024-03-13 07:13:05,134 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51608 7.9, v: 1150.0 to Tick: 51631 8.05, v: 3300.0, confirmation:Tick: 51613 7.95, v: 4300.0 terminated at: None, hard retracel: Tick: 51631 8.05, v: 3300.0, soft: None, conf: 53.84615384615383, Up change %: 0.10000000000000053
# 2024-03-13 07:13:05,144 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51627 8.1, v: 7150.0 to Tick: 51654 7.95, v: 2800.0, confirmation:Tick: 51632 8.05, v: 0.0 terminated at: None, hard retracel: Tick: 51654 7.95, v: 2800.0, soft: None, conf: -57.142857142857, Down change %: 0.10000000000000053
# 2024-03-13 07:13:05,153 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51650 7.75, v: 950.0 to Tick: 51678 8.45, v: 3100.0, confirmation:Tick: 51656 7.8, v: 6200.0 terminated at: None, hard retracel: Tick: 51678 8.45, v: 3100.0, soft: None, conf: 55.555555555555536, Up change %: 0.6499999999999995
# 2024-03-13 07:13:05,172 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51703 7.8, v: 3550.0 to Tick: 51722 8.05, v: 2800.0, confirmation:Tick: 51708 8.1, v: 800.0 terminated at: None, hard retracel: Tick: 51722 8.05, v: 2800.0, soft: None, conf: 71.42857142857147, Up change %: -0.049999999999998934
# 2024-03-13 07:13:05,188 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51725 7.9, v: 4750.0 to Tick: 51740 8.1, v: 2350.0, confirmation:Tick: 51731 8.2, v: 1650.0 terminated at: None, hard retracel: Tick: 51740 8.1, v: 2350.0, soft: None, conf: 68.74999999999991, Up change %: -0.09999999999999964
# 2024-03-13 07:13:05,193 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51737 8.0, v: 4600.0 to Tick: 51750 7.95, v: 0.0, confirmation:Tick: 51743 8.1, v: 1000.0 terminated at: None, hard retracel: Tick: 51750 7.95, v: 0.0, soft: None, conf: 62.49999999999994, Up change %: -0.14999999999999947
# 2024-03-13 07:13:05,206 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51745 8.3, v: 1550.0 to Tick: 51770 7.6, v: 2250.0, confirmation:Tick: 51752 8.05, v: 10600.0 terminated at: None, hard retracel: Tick: 51770 7.6, v: 2250.0, soft: None, conf: -66.66666666666663, Down change %: 0.45000000000000107
# 2024-03-13 07:13:05,210 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51765 7.7, v: 3250.0 to Tick: 51773 7.65, v: 0.0, confirmation:Tick: 51771 7.75, v: 2550.0 terminated at: None, hard retracel: Tick: 51773 7.65, v: 0.0, soft: None, conf: 53.333333333333314, Up change %: -0.09999999999999964
# 2024-03-13 07:13:05,221 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51768 7.55, v: 13200.0 to Tick: 51782 7.65, v: 0.0, confirmation:Tick: 51774 7.7, v: 1000.0 terminated at: None, hard retracel: Tick: 51782 7.65, v: 0.0, soft: None, conf: 63.636363636363654, Up change %: -0.04999999999999982
# 2024-03-13 07:13:05,230 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 51777 7.9, v: 1250.0 to Tick: 51796 7.6, v: 7600.0, confirmation:Tick: 51783 7.6, v: 6700.0 terminated at: None, hard retracel: Tick: 51796 7.6, v: 7600.0, soft: None, conf: -79.99999999999997, Down change %: 0.0
# before u: 0.35000000000000053, d: -0.04999999999999982
# after u: 0.35000000000000053, d: -0.15000000000000036, ch: -0.10000000000000053, -1 id: 51469, -2 id: 51467
# before u: 0.35000000000000053, d: -0.15000000000000036
# after u: 0.35000000000000053, d: -0.20000000000000018, ch: -0.04999999999999982, -1 id: 51469, -2 id: 51469
# before u: 0.35000000000000053, d: -0.20000000000000018
# after u: 0.35000000000000053, d: -0.25, ch: -0.04999999999999982, -1 id: 51470, -2 id: 51469
# before u: 0.35000000000000053, d: -0.25
# after u: 0.35000000000000053, d: -0.25, ch: 0.0, -1 id: 51470, -2 id: 51470
# before u: 0.35000000000000053, d: -0.25
# after u: 0.35000000000000053, d: -0.35000000000000053, ch: -0.10000000000000053, -1 id: 51471, -2 id: 51470
# before u: 0.35000000000000053, d: -0.35000000000000053
# after u: 0.40000000000000124, d: -0.35000000000000053, ch: 0.05000000000000071, -1 id: 51471, -2 id: 51471
# before u: 0.40000000000000124, d: -0.35000000000000053
# after u: 0.40000000000000124, d: -0.40000000000000124, ch: -0.05000000000000071, -1 id: 51472, -2 id: 51471
# before u: 0.40000000000000124, d: -0.40000000000000124
# after u: 0.40000000000000124, d: -0.40000000000000124, ch: 0.0, -1 id: 51473, -2 id: 51472
# before u: 0.40000000000000124, d: -0.40000000000000124
# after u: 0.40000000000000124, d: -0.5000000000000009, ch: -0.09999999999999964, -1 id: 51475, -2 id: 51473
# 2024-03-13 07:13:05,257 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51791 7.5, v: 1400.0 to Tick: 51819 8.3, v: 2650.0, confirmation:Tick: 51797 7.55, v: 4250.0 terminated at: None, hard retracel: Tick: 51819 8.3, v: 2650.0, soft: None, conf: 53.333333333333336, Up change %: 0.7500000000000009
# 2024-03-13 07:13:05,282 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51822 8.2, v: 2450.0 to Tick: 51854 8.75, v: 21450.0, confirmation:Tick: 51828 8.45, v: 4350.0 terminated at: None, hard retracel: Tick: 51854 8.75, v: 21450.0, soft: None, conf: 77.77777777777783, Up change %: 0.3000000000000007
# 2024-03-13 07:13:05,338 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51901 8.15, v: 8800.0 to Tick: 51911 8.1, v: 13550.0, confirmation:Tick: 51906 8.4, v: 0.0 terminated at: None, hard retracel: Tick: 51911 8.1, v: 13550.0, soft: None, conf: 72.72727272727269, Up change %: -0.3000000000000007
# 2024-03-13 07:13:05,344 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51915 8.2, v: 6250.0 to Tick: 51927 8.0, v: 22600.0, confirmation:Tick: 51921 8.25, v: 2700.0 terminated at: None, hard retracel: Tick: 51927 8.0, v: 22600.0, soft: None, conf: 57.14285714285722, Up change %: -0.25
# 2024-03-13 07:13:05,356 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51934 7.75, v: 3150.0 to Tick: 51948 7.9, v: 2050.0, confirmation:Tick: 51940 8.15, v: 8500.0 terminated at: None, hard retracel: Tick: 51948 7.9, v: 2050.0, soft: None, conf: 78.57142857142863, Up change %: -0.25
# 2024-03-13 07:13:05,374 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51952 7.9, v: 3100.0 to Tick: 51966 7.85, v: 0.0, confirmation:Tick: 51958 7.95, v: 3500.0 terminated at: None, hard retracel: Tick: 51966 7.85, v: 0.0, soft: None, conf: 55.55555555555549, Up change %: -0.10000000000000053
# 2024-03-13 07:13:05,381 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51964 8.1, v: 5600.0 to Tick: 51980 8.2, v: 2400.0, confirmation:Tick: 51969 8.25, v: 0.0 terminated at: None, hard retracel: Tick: 51980 8.2, v: 2400.0, soft: None, conf: 60.00000000000002, Up change %: -0.05000000000000071
# 2024-03-13 07:13:05,392 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 51981 8.25, v: 2750.0 to Tick: 51997 8.3, v: 850.0, confirmation:Tick: 51987 8.4, v: 5100.0 terminated at: None, hard retracel: Tick: 51997 8.3, v: 850.0, soft: None, conf: 61.53846153846156, Up change %: -0.09999999999999964
# 2024-03-13 07:13:05,398 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52003 8.35, v: 2900.0 to Tick: 52010 8.25, v: 300.0, confirmation:Tick: 52008 8.5, v: 0.0 terminated at: None, hard retracel: Tick: 52010 8.25, v: 300.0, soft: None, conf: 60.0, Up change %: -0.25
# 2024-03-13 07:13:05,428 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52030 7.8, v: 5350.0 to Tick: 52058 8.25, v: 1750.0, confirmation:Tick: 52035 8.05, v: 0.0 terminated at: None, hard retracel: Tick: 52058 8.25, v: 1750.0, soft: None, conf: 64.70588235294126, Up change %: 0.1999999999999993
# 2024-03-13 07:13:05,431 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52053 8.3, v: 100.0 to Tick: 52059 8.4, v: 4000.0, confirmation:Tick: 52058 8.25, v: 1850.0 terminated at: None, hard retracel: Tick: 52059 8.4, v: 4000.0, soft: None, conf: -55.55555555555564, Down change %: -0.15000000000000036
# 2024-03-13 07:13:05,443 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52069 8.0, v: 2800.0 to Tick: 52082 7.9, v: 0.0, confirmation:Tick: 52075 8.1, v: 100.0 terminated at: None, hard retracel: Tick: 52082 7.9, v: 0.0, soft: None, conf: 66.66666666666667, Up change %: -0.1999999999999993
# 2024-03-13 07:13:05,448 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52077 8.05, v: 100.0 to Tick: 52097 7.95, v: 100.0, confirmation:Tick: 52084 7.9, v: 11400.0 terminated at: None, hard retracel: Tick: 52097 7.95, v: 100.0, soft: None, conf: -63.6363636363637, Down change %: -0.04999999999999982
# 2024-03-13 07:13:05,453 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52100 7.85, v: 20350.0 to Tick: 52110 7.75, v: 36150.0, confirmation:Tick: 52105 8.05, v: 0.0 terminated at: None, hard retracel: Tick: 52110 7.75, v: 36150.0, soft: None, conf: 75.0, Up change %: -0.3000000000000007
# 2024-03-13 07:13:05,458 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52105 8.05, v: 29800.0 to Tick: 52123 7.75, v: 1000.0, confirmation:Tick: 52110 7.75, v: 500.0 terminated at: None, hard retracel: Tick: 52123 7.75, v: 1000.0, soft: None, conf: -100.0, Down change %: 0.0
# 2024-03-13 07:13:05,463 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52118 7.45, v: 6500.0 to Tick: 52137 7.85, v: 2150.0, confirmation:Tick: 52123 7.7, v: 0.0 terminated at: None, hard retracel: Tick: 52137 7.85, v: 2150.0, soft: None, conf: 77.77777777777771, Up change %: 0.14999999999999947
# 2024-03-13 07:13:05,469 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52143 7.75, v: 2050.0 to Tick: 52156 7.8, v: 2600.0, confirmation:Tick: 52148 7.85, v: 3750.0 terminated at: None, hard retracel: Tick: 52156 7.8, v: 2600.0, soft: None, conf: 62.499999999999886, Up change %: -0.04999999999999982
# 2024-03-13 07:13:05,471 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52151 7.9, v: 6750.0 to Tick: 52158 8.0, v: 1750.0, confirmation:Tick: 52156 7.85, v: 400.0 terminated at: None, hard retracel: Tick: 52158 8.0, v: 1750.0, soft: None, conf: -60.00000000000014, Down change %: -0.15000000000000036
# 2024-03-13 07:13:05,479 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52153 7.75, v: 8800.0 to Tick: 52194 8.4, v: 6550.0, confirmation:Tick: 52158 7.95, v: 0.0 terminated at: None, hard retracel: Tick: 52194 8.4, v: 6550.0, soft: None, conf: 83.33333333333339, Up change %: 0.4500000000000002
# 2024-03-13 07:13:05,484 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52192 8.6, v: 5900.0 to Tick: 52205 8.45, v: 2200.0, confirmation:Tick: 52198 8.5, v: 6300.0 terminated at: None, hard retracel: Tick: 52205 8.45, v: 2200.0, soft: None, conf: -57.142857142857146, Down change %: 0.05000000000000071
# 2024-03-13 07:13:05,489 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52201 8.35, v: 9700.0 to Tick: 52222 9.05, v: 15600.0, confirmation:Tick: 52208 8.5, v: 19450.0 terminated at: None, hard retracel: Tick: 52222 9.05, v: 15600.0, soft: None, conf: 61.53846153846156, Up change %: 0.5500000000000007
# 2024-03-13 07:13:05,491 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52217 9.0, v: 14100.0 to Tick: 52226 8.95, v: 0.0, confirmation:Tick: 52222 9.05, v: 0.0 terminated at: None, hard retracel: Tick: 52226 8.95, v: 0.0, soft: None, conf: 57.14285714285722, Up change %: -0.10000000000000142
# 2024-03-13 07:13:05,494 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52222 9.05, v: 15600.0 to Tick: 52234 9.1, v: 21850.0, confirmation:Tick: 52227 8.9, v: 0.0 terminated at: None, hard retracel: Tick: 52234 9.1, v: 21850.0, soft: None, conf: -61.53846153846156, Down change %: -0.1999999999999993
# 2024-03-13 07:13:05,495 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52229 8.8, v: 8000.0 to Tick: 52238 8.75, v: 9200.0, confirmation:Tick: 52235 9.05, v: 17300.0 terminated at: None, hard retracel: Tick: 52238 8.75, v: 9200.0, soft: None, conf: 69.23076923076938, Up change %: -0.3000000000000007
# 2024-03-13 07:13:05,502 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52235 9.05, v: 17300.0 to Tick: 52262 9.7, v: 9150.0, confirmation:Tick: 52240 9.1, v: 0.0 terminated at: None, hard retracel: Tick: 52262 9.7, v: 9150.0, soft: None, conf: 52.941176470588175, Up change %: 0.5999999999999996
# 2024-03-13 07:13:05,504 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52259 9.8, v: 34800.0 to Tick: 52266 9.9, v: 0.0, confirmation:Tick: 52264 9.75, v: 0.0 terminated at: None, hard retracel: Tick: 52266 9.9, v: 0.0, soft: None, conf: -53.333333333333364, Down change %: -0.15000000000000036
# 2024-03-13 07:13:05,507 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52262 9.7, v: 9150.0 to Tick: 52274 9.6, v: 28850.0, confirmation:Tick: 52267 10.0, v: 0.0 terminated at: None, hard retracel: Tick: 52274 9.6, v: 28850.0, soft: None, conf: 79.99999999999986, Up change %: -0.40000000000000036
# 2024-03-13 07:13:05,512 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52280 9.55, v: 6550.0 to Tick: 52290 9.45, v: 20000.0, confirmation:Tick: 52285 9.8, v: 0.0 terminated at: None, hard retracel: Tick: 52290 9.45, v: 20000.0, soft: None, conf: 69.23076923076917, Up change %: -0.3500000000000014
# 2024-03-13 07:13:05,517 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52293 9.25, v: 8100.0 to Tick: 52311 10.35, v: 2800.0, confirmation:Tick: 52299 9.85, v: 10600.0 terminated at: None, hard retracel: Tick: 52311 10.35, v: 2800.0, soft: None, conf: 92.85714285714299, Up change %: 0.5
# 2024-03-13 07:13:05,520 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52306 10.4, v: 31850.0 to Tick: 52315 10.75, v: 40500.0, confirmation:Tick: 52311 10.35, v: 0.0 terminated at: None, hard retracel: Tick: 52315 10.75, v: 40500.0, soft: None, conf: -57.14285714285729, Down change %: -0.40000000000000036
# 2024-03-13 07:13:05,524 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52310 10.25, v: 17100.0 to Tick: 52330 10.65, v: 0.0, confirmation:Tick: 52316 10.95, v: 36250.0 terminated at: None, hard retracel: Tick: 52330 10.65, v: 0.0, soft: None, conf: 88.8888888888889, Up change %: -0.29999999999999893
# 2024-03-13 07:13:05,526 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52326 11.0, v: 63350.0 to Tick: 52336 11.1, v: 0.0, confirmation:Tick: 52331 10.9, v: 0.0 terminated at: None, hard retracel: Tick: 52336 11.1, v: 0.0, soft: None, conf: -57.142857142857146, Down change %: -0.1999999999999993
# 2024-03-13 07:13:05,528 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52331 10.95, v: 25200.0 to Tick: 52339 10.9, v: 9950.0, confirmation:Tick: 52338 11.0, v: 32450.0 terminated at: None, hard retracel: Tick: 52339 10.9, v: 9950.0, soft: None, conf: 53.84615384615391, Up change %: -0.09999999999999964
# 2024-03-13 07:13:05,531 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52334 10.9, v: 16400.0 to Tick: 52346 11.15, v: 65600.0, confirmation:Tick: 52340 10.75, v: 25300.0 terminated at: None, hard retracel: Tick: 52346 11.15, v: 65600.0, soft: None, conf: -58.82352941176473, Down change %: -0.40000000000000036
# 2024-03-13 07:13:05,537 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52341 10.75, v: 12850.0 to Tick: 52363 11.75, v: 19250.0, confirmation:Tick: 52347 11.35, v: 8700.0 terminated at: None, hard retracel: Tick: 52363 11.75, v: 19250.0, soft: None, conf: 80.00000000000003, Up change %: 0.40000000000000036
# 2024-03-13 07:13:05,540 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52358 12.35, v: 39950.0 to Tick: 52376 11.95, v: 15700.0, confirmation:Tick: 52363 11.8, v: 0.0 terminated at: None, hard retracel: Tick: 52376 11.95, v: 15700.0, soft: None, conf: -82.35294117647054, Down change %: -0.14999999999999858
# 2024-03-13 07:13:05,544 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52371 11.35, v: 6650.0 to Tick: 52391 12.75, v: 22850.0, confirmation:Tick: 52377 12.0, v: 35500.0 terminated at: None, hard retracel: Tick: 52391 12.75, v: 22850.0, soft: None, conf: 80.95238095238089, Up change %: 0.75
# 2024-03-13 07:13:05,546 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52386 12.9, v: 62600.0 to Tick: 52393 13.0, v: 17100.0, confirmation:Tick: 52392 12.8, v: 39050.0 terminated at: None, hard retracel: Tick: 52393 13.0, v: 17100.0, soft: None, conf: -54.16666666666664, Down change %: -0.1999999999999993
# 2024-03-13 07:13:05,549 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52388 12.25, v: 11500.0 to Tick: 52404 12.9, v: 23100.0, confirmation:Tick: 52394 12.95, v: 20350.0 terminated at: None, hard retracel: Tick: 52404 12.9, v: 23100.0, soft: None, conf: 93.74999999999991, Up change %: -0.049999999999998934
# 2024-03-13 07:13:05,551 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52399 12.7, v: 23450.0 to Tick: 52407 12.65, v: 22800.0, confirmation:Tick: 52405 12.95, v: 24350.0 terminated at: None, hard retracel: Tick: 52407 12.65, v: 22800.0, soft: None, conf: 60.86956521739129, Up change %: -0.29999999999999893
# 2024-03-13 07:13:05,555 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52405 12.95, v: 24350.0 to Tick: 52418 12.9, v: 8700.0, confirmation:Tick: 52411 13.15, v: 21150.0 terminated at: None, hard retracel: Tick: 52418 12.9, v: 8700.0, soft: None, conf: 61.111111111111164, Up change %: -0.25
# 2024-03-13 07:13:05,560 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52413 13.1, v: 21450.0 to Tick: 52440 12.2, v: 11800.0, confirmation:Tick: 52419 12.85, v: 17350.0 terminated at: None, hard retracel: Tick: 52440 12.2, v: 11800.0, soft: None, conf: -85.71428571428557, Down change %: 0.6500000000000004
# 2024-03-13 07:13:05,564 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52435 12.05, v: 33850.0 to Tick: 52459 13.2, v: 7550.0, confirmation:Tick: 52441 12.25, v: 9650.0 terminated at: None, hard retracel: Tick: 52459 13.2, v: 7550.0, soft: None, conf: 59.99999999999993, Up change %: 0.9499999999999993
# 2024-03-13 07:13:05,573 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52454 12.9, v: 8550.0 to Tick: 52485 14.15, v: 21550.0, confirmation:Tick: 52459 13.2, v: 0.0 terminated at: None, hard retracel: Tick: 52485 14.15, v: 21550.0, soft: None, conf: 64.99999999999991, Up change %: 0.9500000000000011
# 2024-03-13 07:13:05,578 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52487 13.85, v: 52550.0 to Tick: 52503 14.25, v: 16450.0, confirmation:Tick: 52493 14.55, v: 13800.0 terminated at: None, hard retracel: Tick: 52503 14.25, v: 16450.0, soft: None, conf: 84.99999999999999, Up change %: -0.3000000000000007
# 2024-03-13 07:13:05,581 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52498 14.1, v: 6300.0 to Tick: 52509 14.0, v: 15200.0, confirmation:Tick: 52504 14.3, v: 17850.0 terminated at: None, hard retracel: Tick: 52509 14.0, v: 15200.0, soft: None, conf: 58.33333333333334, Up change %: -0.3000000000000007
# 2024-03-13 07:13:05,587 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52516 14.0, v: 27150.0 to Tick: 52530 13.95, v: 13850.0, confirmation:Tick: 52522 13.9, v: 8450.0 terminated at: None, hard retracel: Tick: 52530 13.95, v: 13850.0, soft: None, conf: -56.249999999999986, Down change %: -0.049999999999998934
# 2024-03-13 07:13:05,591 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52525 13.4, v: 14250.0 to Tick: 52547 13.75, v: 8850.0, confirmation:Tick: 52531 13.75, v: 8550.0 terminated at: None, hard retracel: Tick: 52547 13.75, v: 8850.0, soft: None, conf: 66.66666666666661, Up change %: 0.0
# 2024-03-13 07:13:05,596 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52542 14.4, v: 31650.0 to Tick: 52569 13.45, v: 30800.0, confirmation:Tick: 52548 13.6, v: 10950.0 terminated at: None, hard retracel: Tick: 52569 13.45, v: 30800.0, soft: None, conf: -83.33333333333348, Down change %: 0.15000000000000036
# 2024-03-13 07:13:05,600 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52564 12.95, v: 20300.0 to Tick: 52585 13.35, v: 12650.0, confirmation:Tick: 52570 13.35, v: 7850.0 terminated at: None, hard retracel: Tick: 52585 13.35, v: 12650.0, soft: None, conf: 66.66666666666667, Up change %: 0.0
# 2024-03-13 07:13:05,602 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52580 13.55, v: 8650.0 to Tick: 52588 13.65, v: 14350.0, confirmation:Tick: 52587 13.35, v: 4850.0 terminated at: None, hard retracel: Tick: 52588 13.65, v: 14350.0, soft: None, conf: -83.33333333333363, Down change %: -0.3000000000000007
# 2024-03-13 07:13:05,604 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52583 13.5, v: 6550.0 to Tick: 52594 13.45, v: 0.0, confirmation:Tick: 52589 13.65, v: 8950.0 terminated at: None, hard retracel: Tick: 52594 13.45, v: 0.0, soft: None, conf: 66.66666666666667, Up change %: -0.20000000000000107
# 2024-03-13 07:13:05,609 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52601 13.5, v: 6750.0 to Tick: 52622 13.4, v: 21050.0, confirmation:Tick: 52607 13.3, v: 7900.0 terminated at: None, hard retracel: Tick: 52622 13.4, v: 21050.0, soft: None, conf: -62.49999999999994, Down change %: -0.09999999999999964
# 2024-03-13 07:13:05,616 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52617 12.7, v: 23500.0 to Tick: 52640 13.5, v: 8000.0, confirmation:Tick: 52623 13.15, v: 10150.0 terminated at: None, hard retracel: Tick: 52640 13.5, v: 8000.0, soft: None, conf: 66.6666666666667, Up change %: 0.34999999999999964
# 2024-03-13 07:13:05,619 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52637 13.7, v: 13650.0 to Tick: 52645 13.6, v: 10100.0, confirmation:Tick: 52643 13.95, v: 11250.0 terminated at: None, hard retracel: Tick: 52645 13.6, v: 10100.0, soft: None, conf: 61.90476190476193, Up change %: -0.34999999999999964
# 2024-03-13 07:13:05,623 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52640 13.5, v: 8000.0 to Tick: 52655 14.0, v: 11050.0, confirmation:Tick: 52646 13.7, v: 6350.0 terminated at: None, hard retracel: Tick: 52655 14.0, v: 11050.0, soft: None, conf: 57.69230769230766, Up change %: 0.3000000000000007
# 2024-03-13 07:13:05,626 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52651 14.45, v: 27500.0 to Tick: 52661 14.4, v: 27650.0, confirmation:Tick: 52658 14.5, v: 56250.0 terminated at: None, hard retracel: Tick: 52661 14.4, v: 27650.0, soft: None, conf: 51.61290322580648, Up change %: -0.09999999999999964
# 2024-03-13 07:13:05,629 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52656 13.85, v: 12250.0 to Tick: 52668 14.35, v: 17000.0, confirmation:Tick: 52661 14.3, v: 0.0 terminated at: None, hard retracel: Tick: 52668 14.35, v: 17000.0, soft: None, conf: 71.4285714285715, Up change %: 0.049999999999998934
# 2024-03-13 07:13:05,636 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52665 14.4, v: 5650.0 to Tick: 52691 13.45, v: 7650.0, confirmation:Tick: 52671 14.15, v: 4200.0 terminated at: None, hard retracel: Tick: 52691 13.45, v: 7650.0, soft: None, conf: -77.77777777777783, Down change %: 0.7000000000000011
# 2024-03-13 07:13:05,640 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52689 13.4, v: 13950.0 to Tick: 52705 13.6, v: 3350.0, confirmation:Tick: 52695 13.85, v: 8600.0 terminated at: None, hard retracel: Tick: 52705 13.6, v: 3350.0, soft: None, conf: 69.56521739130433, Up change %: -0.25
# 2024-03-13 07:13:05,650 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52702 13.9, v: 6800.0 to Tick: 52762 16.1, v: 14400.0, confirmation:Tick: 52707 14.2, v: 0.0 terminated at: None, hard retracel: Tick: 52762 16.1, v: 14400.0, soft: None, conf: 66.6666666666666, Up change %: 1.9000000000000021
# 2024-03-13 07:13:05,654 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52758 16.1, v: 35700.0 to Tick: 52776 15.85, v: 13300.0, confirmation:Tick: 52763 15.6, v: 0.0 terminated at: None, hard retracel: Tick: 52776 15.85, v: 13300.0, soft: None, conf: -72.72727272727288, Down change %: -0.25
# 2024-03-13 07:13:05,658 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52770 14.8, v: 0.0 to Tick: 52793 15.45, v: 17300.0, confirmation:Tick: 52777 15.7, v: 11450.0 terminated at: None, hard retracel: Tick: 52793 15.45, v: 17300.0, soft: None, conf: 76.47058823529409, Up change %: -0.25
# 2024-03-13 07:13:05,664 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52799 15.3, v: 13350.0 to Tick: 52816 15.8, v: 2400.0, confirmation:Tick: 52806 16.1, v: 38250.0 terminated at: None, hard retracel: Tick: 52816 15.8, v: 2400.0, soft: None, conf: 76.66666666666669, Up change %: -0.3000000000000007
# 2024-03-13 07:13:05,671 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52811 15.55, v: 11150.0 to Tick: 52845 17.8, v: 13550.0, confirmation:Tick: 52816 15.85, v: 0.0 terminated at: None, hard retracel: Tick: 52845 17.8, v: 13550.0, soft: None, conf: 75.00000000000007, Up change %: 1.950000000000001
# 2024-03-13 07:13:05,680 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52855 17.15, v: 75550.0 to Tick: 52894 19.75, v: 35450.0, confirmation:Tick: 52861 18.25, v: 26200.0 terminated at: None, hard retracel: Tick: 52894 19.75, v: 35450.0, soft: None, conf: 89.28571428571438, Up change %: 1.5
# 2024-03-13 07:13:05,681 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52889 19.3, v: 28850.0 to Tick: 52896 19.05, v: 57700.0, confirmation:Tick: 52895 19.6, v: 27600.0 terminated at: None, hard retracel: Tick: 52896 19.05, v: 57700.0, soft: None, conf: 75.00000000000014, Up change %: -0.5500000000000007
# 2024-03-13 07:13:05,686 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52897 18.7, v: 35100.0 to Tick: 52913 19.0, v: 21650.0, confirmation:Tick: 52902 19.7, v: 0.0 terminated at: None, hard retracel: Tick: 52913 19.0, v: 21650.0, soft: None, conf: 77.77777777777783, Up change %: -0.6999999999999993
# 2024-03-13 07:13:05,691 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52912 19.0, v: 39250.0 to Tick: 52928 19.65, v: 24850.0, confirmation:Tick: 52917 19.85, v: 3850.0 terminated at: None, hard retracel: Tick: 52928 19.65, v: 24850.0, soft: None, conf: 72.97297297297291, Up change %: -0.20000000000000284
# 2024-03-13 07:13:05,693 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52925 19.3, v: 28300.0 to Tick: 52933 19.2, v: 11300.0, confirmation:Tick: 52931 19.6, v: 21000.0 terminated at: None, hard retracel: Tick: 52933 19.2, v: 11300.0, soft: None, conf: 60.71428571428578, Up change %: -0.40000000000000213
# 2024-03-13 07:13:05,701 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52948 17.8, v: 18350.0 to Tick: 52963 18.25, v: 15350.0, confirmation:Tick: 52954 18.45, v: 7900.0 terminated at: None, hard retracel: Tick: 52963 18.25, v: 15350.0, soft: None, conf: 65.8536585365853, Up change %: -0.1999999999999993
# 2024-03-13 07:13:05,707 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 52958 18.4, v: 25500.0 to Tick: 52985 17.9, v: 26050.0, confirmation:Tick: 52963 18.25, v: 0.0 terminated at: None, hard retracel: Tick: 52985 17.9, v: 26050.0, soft: None, conf: -57.89473684210517, Down change %: 0.3500000000000014
# 2024-03-13 07:13:05,710 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52982 17.5, v: 11950.0 to Tick: 52993 17.05, v: 16500.0, confirmation:Tick: 52987 17.65, v: 0.0 terminated at: None, hard retracel: Tick: 52993 17.05, v: 16500.0, soft: None, conf: 57.142857142857096, Up change %: -0.5999999999999979
# 2024-03-13 07:13:05,715 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 52999 17.3, v: 8850.0 to Tick: 53006 17.2, v: 7700.0, confirmation:Tick: 53005 17.35, v: 18000.0 terminated at: None, hard retracel: Tick: 53006 17.2, v: 7700.0, soft: None, conf: 54.54545454545466, Up change %: -0.15000000000000213
# 2024-03-13 07:13:05,725 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53012 16.9, v: 5650.0 to Tick: 53032 17.9, v: 7600.0, confirmation:Tick: 53017 17.6, v: 7650.0 terminated at: None, hard retracel: Tick: 53032 17.9, v: 7600.0, soft: None, conf: 85.00000000000014, Up change %: 0.29999999999999716
# 2024-03-13 07:13:05,730 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53027 18.4, v: 6300.0 to Tick: 53044 18.05, v: 19000.0, confirmation:Tick: 53032 18.0, v: 0.0 terminated at: None, hard retracel: Tick: 53044 18.05, v: 19000.0, soft: None, conf: -66.66666666666657, Down change %: -0.05000000000000071
# 2024-03-13 07:13:05,735 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53039 17.55, v: 8550.0 to Tick: 53055 17.65, v: 6350.0, confirmation:Tick: 53044 18.3, v: 0.0 terminated at: None, hard retracel: Tick: 53055 17.65, v: 6350.0, soft: None, conf: 74.19354838709671, Up change %: -0.6500000000000021
# 2024-03-13 07:13:05,741 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53050 18.15, v: 9100.0 to Tick: 53071 17.85, v: 6950.0, confirmation:Tick: 53055 17.9, v: 0.0 terminated at: None, hard retracel: Tick: 53071 17.85, v: 6950.0, soft: None, conf: -58.06451612903227, Down change %: 0.04999999999999716
# 2024-03-13 07:13:05,747 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53066 17.4, v: 6500.0 to Tick: 53082 17.6, v: 13750.0, confirmation:Tick: 53071 17.95, v: 0.0 terminated at: None, hard retracel: Tick: 53082 17.6, v: 13750.0, soft: None, conf: 71.99999999999997, Up change %: -0.34999999999999787
# 2024-03-13 07:13:05,754 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53087 17.4, v: 7750.0 to Tick: 53100 17.45, v: 9950.0, confirmation:Tick: 53093 18.05, v: 14350.0 terminated at: None, hard retracel: Tick: 53100 17.45, v: 9950.0, soft: None, conf: 93.33333333333327, Up change %: -0.6000000000000014
# 2024-03-13 07:13:05,758 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53095 17.85, v: 4250.0 to Tick: 53107 17.65, v: 0.0, confirmation:Tick: 53101 17.5, v: 4150.0 terminated at: None, hard retracel: Tick: 53107 17.65, v: 0.0, soft: None, conf: -66.66666666666679, Down change %: -0.14999999999999858
# 2024-03-13 07:13:05,766 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53102 17.55, v: 1650.0 to Tick: 53126 17.9, v: 0.0, confirmation:Tick: 53109 17.6, v: 7000.0 terminated at: None, hard retracel: Tick: 53126 17.9, v: 0.0, soft: None, conf: 55.55555555555564, Up change %: 0.29999999999999716
# 2024-03-13 07:13:05,776 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53121 18.2, v: 4650.0 to Tick: 53164 15.15, v: 23650.0, confirmation:Tick: 53127 17.9, v: 26050.0 terminated at: None, hard retracel: Tick: 53164 15.15, v: 23650.0, soft: None, conf: -80.00000000000028, Down change %: 2.7499999999999982
# 2024-03-13 07:13:05,779 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53159 14.3, v: 21800.0 to Tick: 53174 15.0, v: 9850.0, confirmation:Tick: 53165 15.3, v: 6550.0 terminated at: None, hard retracel: Tick: 53174 15.0, v: 9850.0, soft: None, conf: 83.33333333333341, Up change %: -0.3000000000000007
# 2024-03-13 07:13:05,789 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53182 13.95, v: 32450.0 to Tick: 53199 14.9, v: 9550.0, confirmation:Tick: 53187 14.75, v: 0.0 terminated at: None, hard retracel: Tick: 53199 14.9, v: 9550.0, soft: None, conf: 83.33333333333339, Up change %: 0.15000000000000036
# 2024-03-13 07:13:05,801 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53194 14.65, v: 3400.0 to Tick: 53227 15.65, v: 7050.0, confirmation:Tick: 53199 14.8, v: 0.0 terminated at: None, hard retracel: Tick: 53227 15.65, v: 7050.0, soft: None, conf: 60.00000000000005, Up change %: 0.8499999999999996
# 2024-03-13 07:13:05,806 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53222 15.95, v: 9000.0 to Tick: 53239 15.85, v: 7600.0, confirmation:Tick: 53228 15.8, v: 7950.0 terminated at: None, hard retracel: Tick: 53239 15.85, v: 7600.0, soft: None, conf: -55.5555555555555, Down change %: -0.049999999999998934
# 2024-03-13 07:13:05,817 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53234 15.65, v: 5250.0 to Tick: 53270 16.75, v: 20850.0, confirmation:Tick: 53240 15.9, v: 23950.0 terminated at: None, hard retracel: Tick: 53270 16.75, v: 20850.0, soft: None, conf: 61.90476190476189, Up change %: 0.8499999999999996
# 2024-03-13 07:13:05,822 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53276 16.65, v: 1450.0 to Tick: 53284 16.55, v: 11300.0, confirmation:Tick: 53282 16.95, v: 3100.0 terminated at: None, hard retracel: Tick: 53284 16.55, v: 11300.0, soft: None, conf: 68.75000000000003, Up change %: -0.3999999999999986
# 2024-03-13 07:13:05,824 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53279 16.4, v: 5350.0 to Tick: 53290 16.1, v: 20600.0, confirmation:Tick: 53284 16.6, v: 0.0 terminated at: None, hard retracel: Tick: 53290 16.1, v: 20600.0, soft: None, conf: 60.00000000000014, Up change %: -0.5
# 2024-03-13 07:13:05,829 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53285 16.75, v: 8350.0 to Tick: 53312 15.4, v: 4150.0, confirmation:Tick: 53291 16.0, v: 19800.0 terminated at: None, hard retracel: Tick: 53312 15.4, v: 4150.0, soft: None, conf: -100.0, Down change %: 0.5999999999999996
# 2024-03-13 07:13:05,834 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53307 15.0, v: 8150.0 to Tick: 53323 15.25, v: 8850.0, confirmation:Tick: 53312 15.3, v: 1350.0 terminated at: None, hard retracel: Tick: 53323 15.25, v: 8850.0, soft: None, conf: 80.00000000000007, Up change %: -0.05000000000000071
# 2024-03-13 07:13:05,836 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53318 15.35, v: 550.0 to Tick: 53324 15.95, v: 71350.0, confirmation:Tick: 53323 15.3, v: 0.0 terminated at: None, hard retracel: Tick: 53324 15.95, v: 71350.0, soft: None, conf: -51.85185185185181, Down change %: -0.6499999999999986
# 2024-03-13 07:13:05,838 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53319 15.8, v: 25800.0 to Tick: 53326 15.7, v: 0.0, confirmation:Tick: 53325 16.0, v: 16050.0 terminated at: None, hard retracel: Tick: 53326 15.7, v: 0.0, soft: None, conf: 56.249999999999964, Up change %: -0.3000000000000007
# 2024-03-13 07:13:05,839 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53321 15.6, v: 3000.0 to Tick: 53328 15.5, v: 6000.0, confirmation:Tick: 53328 15.65, v: 18450.0 terminated at: None, hard retracel: Tick: 53328 15.5, v: 6000.0, soft: None, conf: 51.724137931034505, Up change %: -0.15000000000000036
# 2024-03-13 07:13:05,841 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53323 15.25, v: 8850.0 to Tick: 53330 14.95, v: 244150.0, confirmation:Tick: 53328 15.4, v: 0.0 terminated at: None, hard retracel: Tick: 53330 14.95, v: 244150.0, soft: None, conf: 55.55555555555557, Up change %: -0.45000000000000107
# 2024-03-13 07:13:05,847 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53325 16.0, v: 16050.0 to Tick: 53344 14.75, v: 2350.0, confirmation:Tick: 53330 15.0, v: 0.0 terminated at: None, hard retracel: Tick: 53344 14.75, v: 2350.0, soft: None, conf: -85.71428571428567, Down change %: 0.25
# 2024-03-13 07:13:05,857 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53351 14.15, v: 14400.0 to Tick: 53374 14.85, v: 11750.0, confirmation:Tick: 53356 14.5, v: 0.0 terminated at: None, hard retracel: Tick: 53374 14.85, v: 11750.0, soft: None, conf: 68.42105263157885, Up change %: 0.34999999999999964
# 2024-03-13 07:13:05,864 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53380 14.8, v: 2500.0 to Tick: 53391 14.6, v: 7150.0, confirmation:Tick: 53385 15.0, v: 0.0 terminated at: None, hard retracel: Tick: 53391 14.6, v: 7150.0, soft: None, conf: 59.999999999999964, Up change %: -0.40000000000000036
# 2024-03-13 07:13:05,871 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53386 15.1, v: 11750.0 to Tick: 53411 14.5, v: 17650.0, confirmation:Tick: 53391 14.75, v: 0.0 terminated at: None, hard retracel: Tick: 53411 14.5, v: 17650.0, soft: None, conf: -65.2173913043478, Down change %: 0.25
# 2024-03-13 07:13:05,875 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53406 13.95, v: 12500.0 to Tick: 53426 14.7, v: 4000.0, confirmation:Tick: 53411 14.55, v: 0.0 terminated at: None, hard retracel: Tick: 53426 14.7, v: 4000.0, soft: None, conf: 77.27272727272731, Up change %: 0.14999999999999858
# 2024-03-13 07:13:05,880 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53433 14.8, v: 13400.0 to Tick: 53451 15.2, v: 6700.0, confirmation:Tick: 53439 15.45, v: 3950.0 terminated at: None, hard retracel: Tick: 53451 15.2, v: 6700.0, soft: None, conf: 74.07407407407406, Up change %: -0.25
# 2024-03-13 07:13:05,885 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53446 15.25, v: 4300.0 to Tick: 53469 14.7, v: 12100.0, confirmation:Tick: 53452 15.15, v: 2500.0 terminated at: None, hard retracel: Tick: 53469 14.7, v: 12100.0, soft: None, conf: -60.0, Down change %: 0.45000000000000107
# 2024-03-13 07:13:05,888 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53464 14.65, v: 1150.0 to Tick: 53477 14.6, v: 7750.0, confirmation:Tick: 53469 14.7, v: 6650.0 terminated at: None, hard retracel: Tick: 53477 14.6, v: 7750.0, soft: None, conf: 57.142857142857, Up change %: -0.09999999999999964
# 2024-03-13 07:13:05,893 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53475 14.7, v: 2250.0 to Tick: 53495 15.2, v: 5850.0, confirmation:Tick: 53481 15.2, v: 1000.0 terminated at: None, hard retracel: Tick: 53495 15.2, v: 5850.0, soft: None, conf: 75.0, Up change %: 0.0
# 2024-03-13 07:13:05,901 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53490 15.45, v: 6100.0 to Tick: 53522 14.55, v: 0.0, confirmation:Tick: 53495 15.05, v: 8300.0 terminated at: None, hard retracel: Tick: 53522 14.55, v: 0.0, soft: None, conf: -68.18181818181809, Down change %: 0.5
# 2024-03-13 07:13:05,904 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53517 14.4, v: 6150.0 to Tick: 53528 14.25, v: 0.0, confirmation:Tick: 53523 14.65, v: 4500.0 terminated at: None, hard retracel: Tick: 53528 14.25, v: 0.0, soft: None, conf: 69.23076923076917, Up change %: -0.40000000000000036
# 2024-03-13 07:13:05,910 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53544 14.15, v: 11950.0 to Tick: 53551 14.45, v: 44050.0, confirmation:Tick: 53549 14.1, v: 0.0 terminated at: None, hard retracel: Tick: 53551 14.45, v: 44050.0, soft: None, conf: -53.33333333333338, Down change %: -0.34999999999999964
# 2024-03-13 07:13:05,916 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53546 13.95, v: 9800.0 to Tick: 53562 14.4, v: 0.0, confirmation:Tick: 53552 14.35, v: 10150.0 terminated at: None, hard retracel: Tick: 53562 14.4, v: 0.0, soft: None, conf: 70.00000000000006, Up change %: 0.05000000000000071
# 2024-03-13 07:13:05,921 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53557 14.15, v: 7000.0 to Tick: 53571 14.4, v: 9850.0, confirmation:Tick: 53562 14.55, v: 3750.0 terminated at: None, hard retracel: Tick: 53571 14.4, v: 9850.0, soft: None, conf: 72.22222222222223, Up change %: -0.15000000000000036
# 2024-03-13 07:13:05,922 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53566 14.65, v: 4050.0 to Tick: 53574 14.7, v: 5000.0, confirmation:Tick: 53573 14.5, v: 1100.0 terminated at: None, hard retracel: Tick: 53574 14.7, v: 5000.0, soft: None, conf: -60.0, Down change %: -0.1999999999999993
# 2024-03-13 07:13:05,927 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 53569 14.25, v: 850.0 to Tick: 53584 14.35, v: 0.0, confirmation:Tick: 53575 14.7, v: 900.0 terminated at: None, hard retracel: Tick: 53584 14.35, v: 0.0, soft: None, conf: 90.90909090909079, Up change %: -0.34999999999999964
# 2024-03-13 07:13:05,937 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 53579 14.75, v: 800.0 to Tick: 53615 12.65, v: 5850.0, confirmation:Tick: 53585 14.4, v: 1600.0 terminated at: None, hard retracel: Tick: 53615 12.65, v: 5850.0, soft: None, conf: -76.92307692307688, Down change %: 1.75
# 2024-03-13 07:13:05,946 - INFO - 2816080513.py:76 - [140029717558528] -
# ...
# 2024-03-13 07:13:06,602 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55097 12.85, v: 16500.0 to Tick: 55104 12.75, v: 0.0, confirmation:Tick: 55103 13.05, v: 5800.0 terminated at: None, hard retracel: Tick: 55104 12.75, v: 0.0, soft: None, conf: 66.66666666666677, Up change %: -0.3000000000000007
# 2024-03-13 07:13:06,606 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55105 12.65, v: 3500.0 to Tick: 55116 12.6, v: 6650.0, confirmation:Tick: 55111 12.8, v: 7600.0 terminated at: None, hard retracel: Tick: 55116 12.6, v: 6650.0, soft: None, conf: 66.66666666666667, Up change %: -0.20000000000000107
# 2024-03-13 07:13:06,616 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55111 12.8, v: 7600.0 to Tick: 55141 11.8, v: 23600.0, confirmation:Tick: 55116 12.6, v: 0.0 terminated at: None, hard retracel: Tick: 55141 11.8, v: 23600.0, soft: None, conf: -64.28571428571442, Down change %: 0.7999999999999989
# 2024-03-13 07:13:06,622 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55136 11.25, v: 2300.0 to Tick: 55160 12.45, v: 5450.0, confirmation:Tick: 55141 11.95, v: 0.0 terminated at: None, hard retracel: Tick: 55160 12.45, v: 5450.0, soft: None, conf: 93.74999999999991, Up change %: 0.5
# 2024-03-13 07:13:06,625 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55155 12.5, v: 7450.0 to Tick: 55168 12.35, v: 1750.0, confirmation:Tick: 55162 12.6, v: 16750.0 terminated at: None, hard retracel: Tick: 55168 12.35, v: 1750.0, soft: None, conf: 74.99999999999977, Up change %: -0.25
# 2024-03-13 07:13:06,631 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55163 12.5, v: 8300.0 to Tick: 55181 12.4, v: 9800.0, confirmation:Tick: 55168 12.4, v: 0.0 terminated at: None, hard retracel: Tick: 55181 12.4, v: 9800.0, soft: None, conf: -56.24999999999996, Down change %: 0.0
# 2024-03-13 07:13:06,634 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55176 12.1, v: 5750.0 to Tick: 55191 12.25, v: 5500.0, confirmation:Tick: 55182 12.5, v: 7350.0 terminated at: None, hard retracel: Tick: 55191 12.25, v: 5500.0, soft: None, conf: 90.00000000000018, Up change %: -0.25
# 2024-03-13 07:13:06,637 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55186 12.5, v: 9550.0 to Tick: 55199 12.2, v: 6350.0, confirmation:Tick: 55191 12.35, v: 0.0 terminated at: None, hard retracel: Tick: 55199 12.2, v: 6350.0, soft: None, conf: -63.6363636363637, Down change %: 0.15000000000000036
# 2024-03-13 07:13:06,640 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55194 12.25, v: 5350.0 to Tick: 55213 12.15, v: 2550.0, confirmation:Tick: 55199 12.2, v: 0.0 terminated at: None, hard retracel: Tick: 55213 12.15, v: 2550.0, soft: None, conf: -66.66666666666667, Down change %: 0.049999999999998934
# 2024-03-13 07:13:06,642 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55208 12.0, v: 13050.0 to Tick: 55216 11.9, v: 9100.0, confirmation:Tick: 55214 12.1, v: 1300.0 terminated at: None, hard retracel: Tick: 55216 11.9, v: 9100.0, soft: None, conf: 74.99999999999977, Up change %: -0.1999999999999993
# 2024-03-13 07:13:06,649 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55223 11.7, v: 13500.0 to Tick: 55246 12.35, v: 9750.0, confirmation:Tick: 55228 12.05, v: 0.0 terminated at: None, hard retracel: Tick: 55246 12.35, v: 9750.0, soft: None, conf: 70.5882352941177, Up change %: 0.29999999999999893
# 2024-03-13 07:13:06,652 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55242 12.35, v: 3150.0 to Tick: 55259 12.25, v: 2750.0, confirmation:Tick: 55247 12.1, v: 0.0 terminated at: None, hard retracel: Tick: 55259 12.25, v: 2750.0, soft: None, conf: -72.72727272727269, Down change %: -0.15000000000000036
# 2024-03-13 07:13:06,658 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55254 11.85, v: 8700.0 to Tick: 55279 12.3, v: 14700.0, confirmation:Tick: 55259 12.25, v: 0.0 terminated at: None, hard retracel: Tick: 55279 12.3, v: 14700.0, soft: None, conf: 90.00000000000018, Up change %: 0.05000000000000071
# 2024-03-13 07:13:06,660 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55274 12.3, v: 11150.0 to Tick: 55283 12.2, v: 11050.0, confirmation:Tick: 55279 12.35, v: 0.0 terminated at: None, hard retracel: Tick: 55283 12.2, v: 11050.0, soft: None, conf: 55.555555555555465, Up change %: -0.15000000000000036
# 2024-03-13 07:13:06,668 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55278 12.35, v: 2700.0 to Tick: 55300 12.2, v: 0.0, confirmation:Tick: 55283 12.25, v: 0.0 terminated at: None, hard retracel: Tick: 55300 12.2, v: 0.0, soft: None, conf: -60.0, Down change %: 0.05000000000000071
# 2024-03-13 07:13:06,673 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55295 12.15, v: 4900.0 to Tick: 55315 12.3, v: 1450.0, confirmation:Tick: 55301 12.25, v: 5100.0 terminated at: None, hard retracel: Tick: 55315 12.3, v: 1450.0, soft: None, conf: 60.0, Up change %: 0.05000000000000071
# 2024-03-13 07:13:06,678 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55320 12.3, v: 16250.0 to Tick: 55327 12.25, v: 0.0, confirmation:Tick: 55325 12.5, v: 36600.0 terminated at: None, hard retracel: Tick: 55327 12.25, v: 0.0, soft: None, conf: 70.00000000000007, Up change %: -0.25
# 2024-03-13 07:13:06,688 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55322 12.35, v: 4600.0 to Tick: 55356 12.0, v: 11400.0, confirmation:Tick: 55328 12.25, v: 9400.0 terminated at: None, hard retracel: Tick: 55356 12.0, v: 11400.0, soft: None, conf: -58.33333333333336, Down change %: 0.25
# 2024-03-13 07:13:06,692 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55351 11.75, v: 14400.0 to Tick: 55370 11.95, v: 13050.0, confirmation:Tick: 55356 11.8, v: 0.0 terminated at: None, hard retracel: Tick: 55370 11.95, v: 13050.0, soft: None, conf: 52.380952380952415, Up change %: 0.14999999999999858
# 2024-03-13 07:13:06,695 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55366 12.0, v: 7250.0 to Tick: 55377 12.05, v: 5350.0, confirmation:Tick: 55371 11.9, v: 0.0 terminated at: None, hard retracel: Tick: 55377 12.05, v: 5350.0, soft: None, conf: -58.33333333333336, Down change %: -0.15000000000000036
# 2024-03-13 07:13:06,701 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55373 11.8, v: 11150.0 to Tick: 55392 12.1, v: 3950.0, confirmation:Tick: 55379 12.05, v: 2550.0 terminated at: None, hard retracel: Tick: 55392 12.1, v: 3950.0, soft: None, conf: 66.66666666666667, Up change %: 0.049999999999998934
# 2024-03-13 07:13:06,713 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55404 12.3, v: 3750.0 to Tick: 55428 12.4, v: 9200.0, confirmation:Tick: 55410 12.4, v: 1550.0 terminated at: None, hard retracel: Tick: 55428 12.4, v: 9200.0, soft: None, conf: 58.33333333333336, Up change %: 0.0
# 2024-03-13 07:13:06,723 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55446 12.3, v: 9800.0 to Tick: 55456 12.25, v: 7100.0, confirmation:Tick: 55451 12.4, v: 0.0 terminated at: None, hard retracel: Tick: 55456 12.25, v: 7100.0, soft: None, conf: 58.33333333333326, Up change %: -0.15000000000000036
# 2024-03-13 07:13:06,727 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55452 12.3, v: 22550.0 to Tick: 55463 12.4, v: 0.0, confirmation:Tick: 55457 12.2, v: 10200.0 terminated at: None, hard retracel: Tick: 55463 12.4, v: 0.0, soft: None, conf: -62.500000000000114, Down change %: -0.20000000000000107
# 2024-03-13 07:13:06,732 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55459 12.25, v: 21850.0 to Tick: 55485 12.3, v: 15350.0, confirmation:Tick: 55465 12.45, v: 8500.0 terminated at: None, hard retracel: Tick: 55485 12.3, v: 15350.0, soft: None, conf: 66.66666666666657, Up change %: -0.14999999999999858
# 2024-03-13 07:13:06,738 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55480 12.4, v: 4500.0 to Tick: 55507 12.05, v: 5800.0, confirmation:Tick: 55487 12.25, v: 8000.0 terminated at: None, hard retracel: Tick: 55507 12.05, v: 5800.0, soft: None, conf: -71.4285714285715, Down change %: 0.1999999999999993
# 2024-03-13 07:13:06,742 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55503 12.1, v: 9300.0 to Tick: 55520 12.15, v: 0.0, confirmation:Tick: 55509 12.2, v: 11750.0 terminated at: None, hard retracel: Tick: 55520 12.15, v: 0.0, soft: None, conf: 62.50000000000006, Up change %: -0.049999999999998934
# 2024-03-13 07:13:06,744 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55517 12.15, v: 6900.0 to Tick: 55528 12.1, v: 0.0, confirmation:Tick: 55522 12.25, v: 0.0 terminated at: None, hard retracel: Tick: 55528 12.1, v: 0.0, soft: None, conf: 62.49999999999994, Up change %: -0.15000000000000036
# 2024-03-13 07:13:06,757 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55540 11.85, v: 10700.0 to Tick: 55565 12.25, v: 3400.0, confirmation:Tick: 55546 12.1, v: 5650.0 terminated at: None, hard retracel: Tick: 55565 12.25, v: 3400.0, soft: None, conf: 77.77777777777804, Up change %: 0.15000000000000036
# 2024-03-13 07:13:06,758 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55560 12.2, v: 5200.0 to Tick: 55566 12.15, v: 4900.0, confirmation:Tick: 55565 12.25, v: 0.0 terminated at: None, hard retracel: Tick: 55566 12.15, v: 4900.0, soft: None, conf: 57.142857142857146, Up change %: -0.09999999999999964
# 2024-03-13 07:13:06,763 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55563 12.3, v: 4300.0 to Tick: 55576 12.3, v: 3600.0, confirmation:Tick: 55569 12.25, v: 4000.0 terminated at: None, hard retracel: Tick: 55576 12.3, v: 3600.0, soft: None, conf: -60.00000000000014, Down change %: -0.05000000000000071
# 2024-03-13 07:13:06,768 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55571 12.2, v: 800.0 to Tick: 55586 12.25, v: 0.0, confirmation:Tick: 55576 12.3, v: 0.0 terminated at: None, hard retracel: Tick: 55586 12.25, v: 0.0, soft: None, conf: 75.0, Up change %: -0.05000000000000071
# 2024-03-13 07:13:06,773 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55583 12.25, v: 3100.0 to Tick: 55598 12.3, v: 13500.0, confirmation:Tick: 55588 12.3, v: 1050.0 terminated at: None, hard retracel: Tick: 55598 12.3, v: 13500.0, soft: None, conf: 57.14285714285722, Up change %: 0.0
# 2024-03-13 07:13:06,777 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55593 12.35, v: 10500.0 to Tick: 55607 12.4, v: 0.0, confirmation:Tick: 55599 12.3, v: 5600.0 terminated at: None, hard retracel: Tick: 55607 12.4, v: 0.0, soft: None, conf: -59.999999999999716, Down change %: -0.09999999999999964
# 2024-03-13 07:13:06,780 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55603 12.35, v: 4200.0 to Tick: 55609 12.3, v: 0.0, confirmation:Tick: 55609 12.4, v: 16950.0 terminated at: None, hard retracel: Tick: 55609 12.3, v: 0.0, soft: None, conf: 60.00000000000014, Up change %: -0.09999999999999964
# 2024-03-13 07:13:06,789 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55604 12.35, v: 1350.0 to Tick: 55635 12.25, v: 0.0, confirmation:Tick: 55610 12.3, v: 2700.0 terminated at: None, hard retracel: Tick: 55635 12.25, v: 0.0, soft: None, conf: -57.142857142857, Down change %: 0.05000000000000071
# 2024-03-13 07:13:06,794 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55631 12.15, v: 8300.0 to Tick: 55648 12.2, v: 3900.0, confirmation:Tick: 55637 12.1, v: 5000.0 terminated at: None, hard retracel: Tick: 55648 12.2, v: 3900.0, soft: None, conf: -55.55555555555564, Down change %: -0.09999999999999964
# 2024-03-13 07:13:06,800 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55643 12.05, v: 20450.0 to Tick: 55673 12.25, v: 4800.0, confirmation:Tick: 55648 12.2, v: 0.0 terminated at: None, hard retracel: Tick: 55673 12.25, v: 4800.0, soft: None, conf: 80.00000000000014, Up change %: 0.05000000000000071
# 2024-03-13 07:13:06,804 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55671 12.25, v: 10450.0 to Tick: 55686 12.25, v: 11050.0, confirmation:Tick: 55677 12.3, v: 4350.0 terminated at: None, hard retracel: Tick: 55686 12.25, v: 11050.0, soft: None, conf: 54.545454545454604, Up change %: -0.05000000000000071
# 2024-03-13 07:13:06,808 - INFO - 2816080513.py:76 - [140029717558528] -
# Retracel Continuation: down, HARD RETRACING from Tick: 55681 12.35, v: 6900.0 to Tick: 55701 12.3, v: 4700.0, confirmation:Tick: 55686 12.3, v: 0.0 terminated at: None, hard retracel: Tick: 55701 12.3, v: 4700.0, soft: None, conf: -57.142857142857, Down change %: 0.0
# 2024-03-13 07:13:06,821 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55696 12.2, v: 12400.0 to Tick: 55746 12.9, v: 35650.0, confirmation:Tick: 55702 12.25, v: 6350.0 terminated at: None, hard retracel: Tick: 55746 12.9, v: 35650.0, soft: None, conf: 57.142857142857146, Up change %: 0.6500000000000004
# 2024-03-13 07:13:06,829 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55741 12.85, v: 9450.0 to Tick: 55767 13.05, v: 27950.0, confirmation:Tick: 55747 12.9, v: 9150.0 terminated at: None, hard retracel: Tick: 55767 13.05, v: 27950.0, soft: None, conf: 60.000000000000284, Up change %: 0.15000000000000036
# 2024-03-13 07:13:06,834 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55762 13.05, v: 2900.0 to Tick: 55790 13.3, v: 5700.0, confirmation:Tick: 55767 13.2, v: 0.0 terminated at: None, hard retracel: Tick: 55790 13.3, v: 5700.0, soft: None, conf: 66.66666666666667, Up change %: 0.10000000000000142
# 2024-03-13 07:13:06,837 - INFO - 2816080513.py:74 - [140029717558528] -
# Retracel Continuation: up, HARD RETRACING from Tick: 55785 13.25, v: 12800.0 to Tick: 55797 12.8, v: 0.0, confirmation:Tick: 55791 13.35, v: 6050.0 terminated at: None, hard retracel: Tick: 55797 12.8, v: 0.0, soft: None, conf: 66.66666666666667, Up change %: -0.5499999999999989
# Continuation: None, INITIATED from Tick: 55794 13.45, v: 16550.0 to Tick: 55799 13.45, v: 3850.0, confirmation:None terminated at: None, hard retracel: None, soft: None, conf: None

# %%
pm.ps[2]
# Out:
# Continuation: down, HARD RETRACING from Tick: 51423 2.91 to Tick: 51467 -8.14, confirmation:Tick: 51429 0.58 terminated at: None, hard retracel: Tick: 51467 -8.14, soft: None, conf: -83.33333333333313

# %%
profits = [po.order.pnl for po in pm.closed_orders]
# profits = [po.order.pnl for po in pm.closed_orders if po.phase.direction == ph.Direction.UP if po.phase.confidence_at_confirmation > 75]
# profits = [round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2) for ph in pm.ps if ph.direction == ph.Direction.UP if ph.confidence_at_confirmation > 65]
# profits = [round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2) for ph in pm.ps if ph.direction == ph.Direction.UP]
print(sum(profits))
print(len(profits))
# Out:
# 19.75
# 529

# %%
pm.closed_orders[0].phase
# Out:
# Continuation: up, HARD RETRACING from Tick: 52897 117.44, v: 35100.0 to Tick: 52913 120.93, v: 21650.0, confirmation:Tick: 52902 129.07, v: 0.0 terminated at: None, hard retracel: Tick: 52913 120.93, v: 21650.0, soft: None, conf: 77.77777777777784

# %%
pm.closed_orders.sort(key=lambda x: x.order.pnl)

# %%
pm.ticks
# Out:
# [Tick: 51391 0.0, v: 0.0,
#  Tick: 51393 0.58, v: 5400.0,
#  Tick: 51393 -0.58, v: 2300.0,
#  Tick: 51393 0.0, v: 0.0,
#  Tick: 51394 -0.58, v: 16800.0,
#  Tick: 51395 0.0, v: 7950.0,
#  Tick: 51396 -1.16, v: 5500.0,
#  Tick: 51397 -1.16, v: 4100.0,
#  Tick: 51398 -2.91, v: 6600.0,
#  Tick: 51399 -3.49, v: 11350.0,
#  Tick: 51401 -2.91, v: 6450.0,
#  Tick: 51402 -3.49, v: 9400.0,
#  Tick: 51403 -1.74, v: 13300.0,
#  Tick: 51403 -2.33, v: 2050.0,
#  Tick: 51403 -1.16, v: 0.0,
#  Tick: 51404 -1.74, v: 5100.0,
#  Tick: 51405 -2.33, v: 17850.0,
#  Tick: 51405 -2.33, v: 0.0,
#  Tick: 51406 -1.74, v: 3350.0,
#  Tick: 51407 -1.74, v: 1350.0,
#  Tick: 51409 -2.91, v: 4650.0,
#  Tick: 51410 -1.74, v: 5600.0,
#  Tick: 51410 -1.74, v: 0.0,
#  Tick: 51410 0.0, v: 12200.0,
#  Tick: 51411 -1.16, v: 8900.0,
#  Tick: 51413 -0.58, v: 2250.0,
#  Tick: 51414 -1.16, v: 3350.0,
#  Tick: 51414 -1.16, v: 2000.0,
#  Tick: 51414 -1.16, v: 0.0,
#  Tick: 51415 -0.58, v: 1650.0,
#  Tick: 51416 1.16, v: 12600.0,
#  Tick: 51416 1.74, v: 0.0,
#  Tick: 51417 2.91, v: 17550.0,
#  Tick: 51417 2.33, v: 0.0,
#  Tick: 51418 2.33, v: 10950.0,
#  Tick: 51419 1.16, v: 2950.0,
#  Tick: 51420 2.33, v: 1950.0,
#  Tick: 51420 2.33, v: 0.0,
#  Tick: 51421 2.91, v: 19200.0,
#  Tick: 51422 2.91, v: 39750.0,
#  Tick: 51423 2.91, v: 2550.0,
#  Tick: 51423 2.91, v: 0.0,
#  Tick: 51424 3.49, v: 7150.0,
#  Tick: 51426 2.91, v: 6950.0,
#  Tick: 51426 2.91, v: 2800.0,
#  Tick: 51428 0.58, v: 8600.0,
#  Tick: 51429 0.58, v: 18100.0,
#  Tick: 51430 2.33, v: 2500.0,
#  Tick: 51430 1.74, v: 450.0,
#  Tick: 51431 1.16, v: 3850.0,
#  Tick: 51433 1.16, v: 5800.0,
#  Tick: 51433 0.58, v: 1100.0,
#  Tick: 51435 -2.33, v: 6750.0,
#  Tick: 51435 -1.16, v: 150.0,
#  Tick: 51435 -0.58, v: 0.0,
#  Tick: 51436 -1.16, v: 3150.0,
#  Tick: 51437 -1.16, v: 1550.0,
#  Tick: 51438 -1.16, v: 11050.0,
#  Tick: 51438 -2.33, v: 0.0,
#  Tick: 51440 -2.33, v: 6600.0,
#  Tick: 51441 -2.91, v: 3750.0,
#  Tick: 51441 -2.33, v: 2700.0,
#  Tick: 51441 -3.49, v: 0.0,
#  Tick: 51442 -2.91, v: 5700.0,
#  Tick: 51443 -3.49, v: 4800.0,
#  Tick: 51445 -5.23, v: 11400.0,
#  Tick: 51446 -4.07, v: 4000.0,
#  Tick: 51447 -5.81, v: 10850.0,
#  Tick: 51448 -5.23, v: 12300.0,
#  Tick: 51449 -6.4, v: 9550.0,
#  Tick: 51450 -5.23, v: 10000.0,
#  Tick: 51450 -6.4, v: 5100.0,
#  Tick: 51450 -6.4, v: 0.0,
#  Tick: 51451 -8.72, v: 60050.0,
#  Tick: 51452 -9.3, v: 30100.0,
#  Tick: 51453 -9.3, v: 21450.0,
#  Tick: 51455 -9.3, v: 8550.0,
#  Tick: 51456 -10.47, v: 10600.0,
#  Tick: 51457 -9.3, v: 14700.0,
#  Tick: 51458 -10.47, v: 8400.0,
#  Tick: 51459 -10.47, v: 8250.0,
#  Tick: 51459 -11.63, v: 3700.0,
#  Tick: 51459 -11.63, v: 0.0,
#  Tick: 51460 -12.21, v: 4550.0,
#  Tick: 51461 -11.63, v: 23300.0,
#  Tick: 51463 -11.63, v: 11650.0,
#  Tick: 51464 -11.63, v: 11250.0,
#  Tick: 51464 -12.21, v: 700.0,
#  Tick: 51465 -11.05, v: 8150.0,
#  Tick: 51465 -9.88, v: 0.0,
#  Tick: 51466 -9.88, v: 8650.0,
#  Tick: 51467 -8.14, v: 2600.0,
#  Tick: 51469 -9.3, v: 4350.0,
#  Tick: 51469 -9.88, v: 0.0,
#  Tick: 51470 -10.47, v: 1100.0,
#  Tick: 51470 -10.47, v: 0.0,
#  Tick: 51471 -11.63, v: 13400.0,
#  Tick: 51471 -11.05, v: 0.0,
#  Tick: 51472 -11.63, v: 13550.0,
#  Tick: 51473 -11.63, v: 5150.0,
#  Tick: 51475 -12.79, v: 4850.0,
#  Tick: 51475 -11.63, v: 0.0,
#  Tick: 51476 -12.79, v: 5300.0,
#  Tick: 51476 -16.86, v: 0.0,
#  Tick: 51477 -16.86, v: 57800.0,
#  Tick: 51478 -14.53, v: 8450.0,
#  Tick: 51478 -16.28, v: 11350.0,
#  Tick: 51479 -15.12, v: 13600.0,
#  Tick: 51480 -13.37, v: 9400.0,
#  Tick: 51481 -12.21, v: 6200.0,
#  Tick: 51483 -12.79, v: 7350.0,
#  Tick: 51484 -15.12, v: 4950.0,
#  Tick: 51484 -12.79, v: 0.0,
#  Tick: 51484 -8.72, v: 0.0,
#  Tick: 51486 -8.14, v: 14200.0,
#  Tick: 51486 -9.88, v: 0.0,
#  Tick: 51487 -11.05, v: 16000.0,
#  Tick: 51488 -12.21, v: 3800.0,
#  Tick: 51490 -11.63, v: 950.0,
#  Tick: 51490 -10.47, v: 0.0,
#  Tick: 51491 -8.72, v: 12350.0,
#  Tick: 51492 -6.98, v: 12650.0,
#  Tick: 51493 -6.98, v: 5500.0,
#  Tick: 51493 -8.14, v: 0.0,
#  Tick: 51494 -7.56, v: 3100.0,
#  Tick: 51495 -8.72, v: 1050.0,
#  Tick: 51495 -7.56, v: 800.0,
#  Tick: 51495 -7.56, v: 0.0,
#  Tick: 51497 -4.07, v: 16950.0,
#  Tick: 51498 -6.4, v: 2350.0,
#  Tick: 51499 -8.14, v: 6700.0,
#  Tick: 51500 -9.3, v: 1600.0,
#  Tick: 51501 -4.65, v: 12300.0,
#  Tick: 51501 -4.65, v: 8300.0,
#  Tick: 51502 -4.07, v: 1500.0,
#  Tick: 51504 -6.4, v: 16050.0,
#  Tick: 51504 -4.07, v: 5350.0,
#  Tick: 51504 -3.49, v: 0.0,
#  Tick: 51504 -1.74, v: 0.0,
#  Tick: 51506 -1.16, v: 6450.0,
#  Tick: 51507 -2.91, v: 6050.0,
#  Tick: 51507 -4.07, v: 6550.0,
#  Tick: 51509 -6.98, v: 7700.0,
#  Tick: 51509 -6.4, v: 0.0,
#  Tick: 51510 -9.3, v: 17950.0,
#  Tick: 51511 -8.14, v: 14300.0,
#  Tick: 51511 -9.88, v: 0.0,
#  Tick: 51512 -9.3, v: 22750.0,
#  Tick: 51513 -9.88, v: 4450.0,
#  Tick: 51514 -12.21, v: 4550.0,
#  Tick: 51514 -11.05, v: 0.0,
#  Tick: 51515 -10.47, v: 2600.0,
#  Tick: 51515 -12.79, v: 800.0,
#  Tick: 51516 -11.63, v: 2650.0,
#  Tick: 51516 -12.21, v: 0.0,
#  Tick: 51518 -10.47, v: 8100.0,
#  Tick: 51519 -11.05, v: 4050.0,
#  Tick: 51519 -9.3, v: 4300.0,
#  Tick: 51519 -10.47, v: 0.0,
#  Tick: 51521 -11.05, v: 12750.0,
#  Tick: 51522 -9.88, v: 3000.0,
#  Tick: 51523 -9.3, v: 1500.0,
#  Tick: 51523 -8.72, v: 0.0,
#  Tick: 51524 -8.14, v: 3100.0,
#  Tick: 51525 -11.05, v: 4100.0,
#  Tick: 51526 -8.72, v: 4750.0,
#  Tick: 51526 -8.72, v: 2100.0,
#  Tick: 51528 -9.88, v: 3450.0,
#  Tick: 51528 -12.79, v: 12450.0,
#  Tick: 51528 -12.79, v: 0.0,
#  Tick: 51530 -12.79, v: 3150.0,
#  Tick: 51530 -11.63, v: 7050.0,
#  Tick: 51531 -11.63, v: 2600.0,
#  Tick: 51531 -12.21, v: 0.0,
#  Tick: 51533 -13.37, v: 4550.0,
#  Tick: 51534 -13.37, v: 11700.0,
#  Tick: 51535 -13.37, v: 2600.0,
#  Tick: 51536 -13.37, v: 7750.0,
#  Tick: 51537 -12.21, v: 3200.0,
#  Tick: 51538 -13.95, v: 10100.0,
#  Tick: 51538 -11.05, v: 0.0,
#  Tick: 51539 -12.21, v: 9150.0,
#  Tick: 51539 -12.21, v: 0.0,
#  Tick: 51540 -11.63, v: 10450.0,
#  Tick: 51540 -11.05, v: 0.0,
#  Tick: 51541 -11.05, v: 3350.0,
#  Tick: 51542 -11.05, v: 11950.0,
#  Tick: 51544 -8.72, v: 13550.0,
#  Tick: 51544 -7.56, v: 13350.0,
#  Tick: 51545 -8.14, v: 3350.0,
#  Tick: 51546 -9.88, v: 1300.0,
#  Tick: 51546 -8.72, v: 0.0,
#  Tick: 51548 -9.88, v: 5900.0,
#  Tick: 51549 -7.56, v: 5500.0,
#  Tick: 51549 -7.56, v: 250.0,
#  Tick: 51549 -6.98, v: 0.0,
#  Tick: 51551 -8.14, v: 4350.0,
#  Tick: 51552 -7.56, v: 250.0,
#  Tick: 51552 -8.14, v: 1300.0,
#  Tick: 51552 -8.14, v: 0.0,
#  Tick: 51553 -8.72, v: 3350.0,
#  Tick: 51555 -9.88, v: 14700.0,
#  Tick: 51555 -11.63, v: 5250.0,
#  Tick: 51555 -9.3, v: 0.0,
#  Tick: 51557 -9.88, v: 2400.0,
#  Tick: 51557 -10.47, v: 1750.0,
#  Tick: 51559 -11.63, v: 4600.0,
#  Tick: 51559 -11.05, v: 1200.0,
#  Tick: 51560 -10.47, v: 3600.0,
#  Tick: 51562 -11.05, v: 300.0,
#  Tick: 51562 -9.88, v: 0.0,
#  Tick: 51562 -9.88, v: 5150.0,
#  Tick: 51563 -8.72, v: 100.0,
#  Tick: 51564 -9.88, v: 6500.0,
#  Tick: 51566 -9.88, v: 3100.0,
#  Tick: 51567 -6.98, v: 8250.0,
#  Tick: 51567 -5.81, v: 5350.0,
#  Tick: 51569 -5.81, v: 17000.0,
#  Tick: 51570 -6.98, v: 4600.0,
#  Tick: 51570 -5.81, v: 1700.0,
#  Tick: 51572 -4.65, v: 3550.0,
#  Tick: 51573 -4.07, v: 3350.0,
#  Tick: 51573 -4.07, v: 4350.0,
#  Tick: 51573 -2.33, v: 0.0,
#  Tick: 51575 -1.74, v: 6950.0,
#  Tick: 51576 -2.91, v: 350.0,
#  Tick: 51576 -2.33, v: 5250.0,
#  Tick: 51577 -5.23, v: 5350.0,
#  Tick: 51578 -4.07, v: 3750.0,
#  Tick: 51579 -3.49, v: 9450.0,
#  Tick: 51581 -0.58, v: 38400.0,
#  Tick: 51582 -1.74, v: 12450.0,
#  Tick: 51582 -3.49, v: 0.0,
#  Tick: 51584 -4.07, v: 10450.0,
#  Tick: 51584 -4.07, v: 4200.0,
#  Tick: 51586 -4.07, v: 700.0,
#  Tick: 51587 -5.23, v: 10950.0,
#  Tick: 51588 -5.23, v: 4900.0,
#  Tick: 51589 -5.23, v: 2150.0,
#  Tick: 51590 -3.49, v: 2450.0,
#  Tick: 51590 -3.49, v: 1000.0,
#  Tick: 51591 -3.49, v: 1200.0,
#  Tick: 51593 -3.49, v: 3850.0,
#  Tick: 51594 -4.07, v: 1750.0,
#  Tick: 51595 -4.65, v: 450.0,
#  Tick: 51595 -5.23, v: 3550.0,
#  Tick: 51597 -5.23, v: 3700.0,
#  Tick: 51598 -4.07, v: 1250.0,
#  Tick: 51598 -6.4, v: 600.0,
#  Tick: 51600 -5.81, v: 8900.0,
#  Tick: 51601 -5.81, v: 2050.0,
#  Tick: 51601 -5.23, v: 1700.0,
#  Tick: 51603 -6.4, v: 5250.0,
#  Tick: 51604 -6.4, v: 8900.0,
#  Tick: 51604 -7.56, v: 1800.0,
#  Tick: 51604 -5.81, v: 0.0,
#  Tick: 51606 -5.81, v: 3050.0,
#  Tick: 51606 -6.98, v: 2150.0,
#  Tick: 51608 -8.14, v: 1150.0,
#  Tick: 51609 -7.56, v: 350.0,
#  Tick: 51610 -8.72, v: 1150.0,
#  Tick: 51610 -6.4, v: 2350.0,
#  Tick: 51611 -5.23, v: 3550.0,
#  Tick: 51613 -6.4, v: 7600.0,
#  Tick: 51613 -7.56, v: 4300.0,
#  Tick: 51613 -8.14, v: 0.0,
#  Tick: 51615 -6.98, v: 1450.0,
#  Tick: 51615 -6.98, v: 0.0,
#  Tick: 51617 -5.23, v: 3350.0,
#  Tick: 51617 -5.23, v: 0.0,
#  Tick: 51618 -5.81, v: 6750.0,
#  Tick: 51618 -6.4, v: 0.0,
#  Tick: 51619 -5.23, v: 8100.0,
#  Tick: 51620 -4.07, v: 600.0,
#  Tick: 51622 -2.33, v: 2750.0,
#  Tick: 51623 -2.91, v: 7350.0,
#  Tick: 51623 -2.91, v: 0.0,
#  Tick: 51624 -2.33, v: 5500.0,
#  Tick: 51624 -2.91, v: 400.0,
#  Tick: 51625 -4.07, v: 600.0,
#  Tick: 51625 -5.23, v: 0.0,
#  Tick: 51627 -5.81, v: 7150.0,
#  Tick: 51628 -4.65, v: 1350.0,
#  Tick: 51629 -4.65, v: 3250.0,
#  Tick: 51629 -5.81, v: 50.0,
#  Tick: 51631 -6.4, v: 3300.0,
#  Tick: 51632 -6.98, v: 7600.0,
#  Tick: 51632 -6.4, v: 0.0,
#  Tick: 51633 -6.4, v: 1700.0,
#  Tick: 51633 -6.4, v: 750.0,
#  Tick: 51634 -6.4, v: 2750.0,
#  Tick: 51636 -5.81, v: 600.0,
#  Tick: 51637 -5.81, v: 1050.0,
#  Tick: 51638 -7.56, v: 1800.0,
#  Tick: 51638 -7.56, v: 1400.0,
#  Tick: 51639 -7.56, v: 2950.0,
#  Tick: 51640 -9.3, v: 7250.0,
#  Tick: 51641 -8.72, v: 5950.0,
#  Tick: 51642 -9.88, v: 50.0,
#  Tick: 51644 -9.88, v: 1600.0,
#  Tick: 51644 -8.72, v: 2350.0,
#  Tick: 51646 -10.47, v: 4150.0,
#  Tick: 51647 -9.88, v: 3950.0,
#  Tick: 51648 -8.14, v: 32750.0,
#  Tick: 51649 -8.14, v: 3150.0,
#  Tick: 51650 -9.88, v: 950.0,
#  Tick: 51650 -9.88, v: 0.0,
#  Tick: 51651 -10.47, v: 1850.0,
#  Tick: 51651 -9.3, v: 3400.0,
#  Tick: 51652 -9.3, v: 750.0,
#  Tick: 51654 -7.56, v: 2800.0,
#  Tick: 51655 -8.72, v: 1600.0,
#  Tick: 51656 -9.3, v: 6200.0,
#  Tick: 51656 -6.4, v: 0.0,
#  Tick: 51657 -6.4, v: 6750.0,
#  Tick: 51657 -5.81, v: 0.0,
#  Tick: 51659 -5.81, v: 6350.0,
#  Tick: 51660 -6.4, v: 3250.0,
#  Tick: 51661 -4.65, v: 4000.0,
#  Tick: 51662 -5.23, v: 2050.0,
#  Tick: 51662 -5.23, v: 0.0,
#  Tick: 51663 -4.65, v: 2900.0,
#  Tick: 51664 -4.07, v: 3800.0,
#  Tick: 51665 -4.07, v: 950.0,
#  Tick: 51665 0.0, v: 0.0,
#  Tick: 51666 -1.16, v: 46550.0,
#  Tick: 51667 -0.58, v: 6550.0,
#  Tick: 51668 -1.74, v: 5500.0,
#  Tick: 51668 0.0, v: 0.0,
#  Tick: 51669 -0.58, v: 2550.0,
#  Tick: 51670 -0.58, v: 100.0,
#  Tick: 51671 0.0, v: 4500.0,
#  Tick: 51671 0.0, v: 0.0,
#  Tick: 51672 1.16, v: 10400.0,
#  Tick: 51672 0.0, v: 0.0,
#  Tick: 51673 0.0, v: 17750.0,
#  Tick: 51673 0.0, v: 0.0,
#  Tick: 51675 1.16, v: 1300.0,
#  Tick: 51675 -1.16, v: 3650.0,
#  Tick: 51677 -0.58, v: 7500.0,
#  Tick: 51678 -1.74, v: 3100.0,
#  Tick: 51679 -1.16, v: 5800.0,
#  Tick: 51680 -1.16, v: 2100.0,
#  Tick: 51680 0.0, v: 0.0,
#  Tick: 51681 -1.16, v: 1400.0,
#  Tick: 51682 -2.91, v: 3550.0,
#  Tick: 51683 -2.33, v: 1100.0,
#  Tick: 51684 -1.74, v: 3250.0,
#  Tick: 51684 -3.49, v: 0.0,
#  Tick: 51686 -5.23, v: 11500.0,
#  Tick: 51687 -3.49, v: 3650.0,
#  Tick: 51687 -4.07, v: 3900.0,
#  Tick: 51688 -5.81, v: 350.0,
#  Tick: 51688 -5.81, v: 0.0,
#  Tick: 51688 -5.23, v: 0.0,
#  Tick: 51691 -5.81, v: 22000.0,
#  Tick: 51692 -5.81, v: 2200.0,
#  Tick: 51692 -5.81, v: 0.0,
#  Tick: 51693 -6.98, v: 7800.0,
#  Tick: 51694 -6.4, v: 4400.0,
#  Tick: 51695 -6.4, v: 2400.0,
#  Tick: 51695 -6.98, v: 0.0,
#  Tick: 51696 -7.56, v: 12650.0,
#  Tick: 51696 -5.23, v: 0.0,
#  Tick: 51697 -6.4, v: 3150.0,
#  Tick: 51698 -6.4, v: 4100.0,
#  Tick: 51698 -6.98, v: 0.0,
#  Tick: 51699 -7.56, v: 6800.0,
#  Tick: 51700 -7.56, v: 3350.0,
#  Tick: 51700 -8.72, v: 5250.0,
#  Tick: 51701 -8.72, v: 2800.0,
#  Tick: 51703 -9.3, v: 3550.0,
#  Tick: 51704 -8.72, v: 3650.0,
#  Tick: 51704 -6.98, v: 0.0,
#  Tick: 51705 -7.56, v: 5400.0,
#  Tick: 51705 -8.14, v: 100.0,
#  Tick: 51707 -6.98, v: 4000.0,
#  Tick: 51708 -4.65, v: 7200.0,
#  Tick: 51708 -5.81, v: 800.0,
#  Tick: 51710 -5.81, v: 2900.0,
#  Tick: 51710 -5.81, v: 0.0,
#  Tick: 51711 -5.81, v: 850.0,
#  Tick: 51712 -5.81, v: 900.0,
#  Tick: 51713 -8.72, v: 4600.0,
#  Tick: 51713 -7.56, v: 0.0,
#  Tick: 51714 -7.56, v: 3850.0,
#  Tick: 51715 -6.98, v: 550.0,
#  Tick: 51716 -5.23, v: 17950.0,
#  Tick: 51716 -5.23, v: 0.0,
#  Tick: 51717 -5.23, v: 2250.0,
#  Tick: 51717 -4.65, v: 0.0,
#  Tick: 51718 -6.98, v: 3350.0,
#  Tick: 51718 -6.4, v: 0.0,
#  Tick: 51720 -5.81, v: 23300.0,
#  Tick: 51721 -5.81, v: 3900.0,
#  Tick: 51722 -6.4, v: 2800.0,
#  Tick: 51723 -8.14, v: 4850.0,
#  Tick: 51724 -8.14, v: 16500.0,
#  Tick: 51725 -8.14, v: 4750.0,
#  Tick: 51725 -6.4, v: 0.0,
#  Tick: 51726 -7.56, v: 4900.0,
#  Tick: 51726 -7.56, v: 0.0,
#  Tick: 51727 -8.14, v: 300.0,
#  Tick: 51728 -8.14, v: 1100.0,
#  Tick: 51728 -9.3, v: 300.0,
#  Tick: 51730 -5.23, v: 15250.0,
#  Tick: 51731 -4.65, v: 1650.0,
#  Tick: 51731 -4.65, v: 0.0,
#  Tick: 51732 -4.65, v: 7950.0,
#  Tick: 51732 -5.81, v: 0.0,
#  Tick: 51733 -5.81, v: 1500.0,
#  Tick: 51734 -6.98, v: 3600.0,
#  Tick: 51734 -6.98, v: 0.0,
#  Tick: 51734 -6.98, v: 250.0,
#  Tick: 51734 -6.98, v: 0.0,
#  Tick: 51737 -6.98, v: 4600.0,
#  Tick: 51738 -6.4, v: 12000.0,
#  Tick: 51739 -6.98, v: 900.0,
#  Tick: 51740 -5.81, v: 2350.0,
#  Tick: 51740 -4.65, v: 0.0,
#  Tick: 51741 -4.65, v: 1750.0,
#  Tick: 51741 -4.65, v: 0.0,
#  Tick: 51742 -5.81, v: 2150.0,
#  Tick: 51743 -5.81, v: 1000.0,
#  Tick: 51743 -4.07, v: 0.0,
#  Tick: 51744 -5.23, v: 1750.0,
#  Tick: 51745 -3.49, v: 1550.0,
#  Tick: 51746 -3.49, v: 3150.0,
#  Tick: 51747 -5.81, v: 4950.0,
#  Tick: 51748 -5.23, v: 1900.0,
#  Tick: 51748 -6.4, v: 3450.0,
#  Tick: 51748 -6.98, v: 0.0,
#  Tick: 51750 -6.98, v: 6800.0,
#  Tick: 51750 -5.81, v: 700.0,
#  Tick: 51750 -7.56, v: 0.0,
#  Tick: 51752 -6.4, v: 10600.0,
#  Tick: 51754 -7.56, v: 1800.0,
#  Tick: 51755 -8.14, v: 5600.0,
#  Tick: 51755 -6.98, v: 3800.0,
#  Tick: 51757 -10.47, v: 26200.0,
#  Tick: 51758 -10.47, v: 12250.0,
#  Tick: 51758 -12.21, v: 0.0,
#  Tick: 51759 -12.21, v: 16200.0,
#  Tick: 51760 -12.79, v: 4350.0,
#  Tick: 51761 -11.63, v: 4850.0,
#  Tick: 51761 -12.21, v: 0.0,
#  Tick: 51762 -13.37, v: 20600.0,
#  Tick: 51762 -12.21, v: 0.0,
#  Tick: 51763 -12.79, v: 14400.0,
#  Tick: 51764 -10.47, v: 1250.0,
#  Tick: 51765 -10.47, v: 3250.0,
#  Tick: 51765 -9.3, v: 0.0,
#  Tick: 51766 -11.05, v: 10300.0,
#  Tick: 51767 -10.47, v: 5700.0,
#  Tick: 51767 -12.21, v: 0.0,
#  Tick: 51768 -12.21, v: 13200.0,
#  Tick: 51769 -11.05, v: 50.0,
#  Tick: 51770 -11.63, v: 2250.0,
#  Tick: 51770 -10.47, v: 0.0,
#  Tick: 51771 -9.88, v: 2550.0,
#  Tick: 51772 -9.3, v: 9900.0,
#  Tick: 51773 -10.47, v: 4400.0,
#  Tick: 51773 -11.05, v: 0.0,
#  Tick: 51774 -10.47, v: 1000.0,
#  Tick: 51775 -8.72, v: 400.0,
#  Tick: 51776 -8.72, v: 3700.0,
#  Tick: 51776 -9.88, v: 0.0,
#  Tick: 51777 -8.14, v: 1250.0,
#  Tick: 51777 -8.72, v: 2400.0,
#  Tick: 51779 -9.3, v: 3400.0,
#  Tick: 51779 -8.14, v: 0.0,
#  Tick: 51780 -8.14, v: 1950.0,
#  Tick: 51780 -9.3, v: 0.0,
#  Tick: 51780 -9.3, v: 8350.0,
#  Tick: 51782 -9.3, v: 50.0,
#  Tick: 51782 -11.05, v: 0.0,
#  Tick: 51783 -11.63, v: 6700.0,
#  Tick: 51783 -12.79, v: 0.0,
#  Tick: 51784 -11.63, v: 8300.0,
#  Tick: 51784 -11.63, v: 200.0,
#  Tick: 51784 -12.21, v: 0.0,
#  Tick: 51786 -12.21, v: 300.0,
#  Tick: 51787 -11.63, v: 4000.0,
#  Tick: 51787 -12.79, v: 0.0,
#  Tick: 51789 -12.79, v: 22550.0,
#  Tick: 51790 -13.95, v: 2800.0,
#  Tick: 51791 -12.79, v: 1400.0,
#  Tick: 51791 -11.63, v: 0.0,
#  Tick: 51792 -12.21, v: 3450.0,
#  Tick: 51792 -12.79, v: 0.0,
#  Tick: 51793 -13.95, v: 4550.0,
#  Tick: 51794 -12.21, v: 1200.0,
#  Tick: 51794 -13.37, v: 0.0,
#  Tick: 51795 -13.37, v: 19200.0,
#  Tick: 51795 -11.63, v: 0.0,
#  Tick: 51796 -11.63, v: 7600.0,
#  Tick: 51797 -12.21, v: 4250.0,
#  Tick: 51798 -11.05, v: 1850.0,
#  Tick: 51799 -9.3, v: 3150.0,
#  Tick: 51799 -8.72, v: 1050.0,
#  Tick: 51799 -8.14, v: 0.0,
#  Tick: 51801 -8.14, v: 1250.0,
#  Tick: 51801 -8.72, v: 0.0,
#  Tick: 51802 -8.72, v: 1100.0,
#  Tick: 51803 -9.3, v: 2000.0,
#  Tick: 51804 -8.14, v: 6250.0,
#  Tick: 51805 -8.14, v: 650.0,
#  Tick: 51806 -4.65, v: 30800.0,
#  Tick: 51806 -3.49, v: 0.0,
#  Tick: 51807 -3.49, v: 6800.0,
#  Tick: 51808 -2.91, v: 6400.0,
#  Tick: 51809 -3.49, v: 7050.0,
#  Tick: 51809 -4.07, v: 0.0,
#  Tick: 51810 -4.07, v: 9050.0,
#  Tick: 51811 -4.65, v: 2500.0,
#  Tick: 51812 -4.07, v: 4600.0,
#  Tick: 51812 -4.07, v: 0.0,
#  Tick: 51813 -3.49, v: 2600.0,
#  Tick: 51813 -2.33, v: 0.0,
#  Tick: 51814 -2.91, v: 7500.0,
#  Tick: 51815 -2.91, v: 6800.0,
#  Tick: 51816 -2.91, v: 12500.0,
#  Tick: 51816 -2.91, v: 0.0,
#  Tick: 51818 -2.33, v: 11250.0,
#  Tick: 51819 -3.49, v: 2650.0,
#  Tick: 51820 -4.07, v: 8150.0,
#  Tick: 51820 -5.23, v: 2700.0,
#  Tick: 51820 -5.81, v: 0.0,
#  Tick: 51822 -4.65, v: 2450.0,
#  Tick: 51823 -5.81, v: 1100.0,
#  Tick: 51824 -4.65, v: 1950.0,
#  Tick: 51824 -4.65, v: 100.0,
#  Tick: 51826 -2.91, v: 2700.0,
#  Tick: 51827 -1.74, v: 14050.0,
#  Tick: 51828 -1.74, v: 4350.0,
#  Tick: 51829 0.0, v: 57600.0,
#  Tick: 51830 -0.58, v: 6300.0,
#  Tick: 51830 -0.58, v: 0.0,
#  Tick: 51831 0.58, v: 22600.0,
#  Tick: 51832 1.74, v: 11200.0,
#  Tick: 51833 1.74, v: 10250.0,
#  Tick: 51833 1.74, v: 0.0,
#  Tick: 51834 1.74, v: 9500.0,
#  Tick: 51835 1.74, v: 9500.0,
#  Tick: 51836 1.16, v: 17850.0,
#  Tick: 51836 1.74, v: 0.0,
#  Tick: 51837 2.33, v: 7000.0,
#  Tick: 51838 2.33, v: 7900.0,
#  Tick: 51838 5.81, v: 0.0,
#  Tick: 51839 4.07, v: 80500.0,
#  Tick: 51840 4.65, v: 7650.0,
#  Tick: 51840 6.4, v: 0.0,
#  Tick: 51841 5.81, v: 18850.0,
#  Tick: 51841 4.07, v: 0.0,
#  Tick: 51842 4.65, v: 19150.0,
#  Tick: 51843 2.91, v: 10650.0,
#  Tick: 51844 4.07, v: 16600.0,
#  Tick: 51845 5.23, v: 30000.0,
#  Tick: 51845 5.23, v: 0.0,
#  Tick: 51846 5.81, v: 13350.0,
#  Tick: 51846 4.65, v: 0.0,
#  Tick: 51847 6.4, v: 7850.0,
#  Tick: 51848 5.23, v: 5850.0,
#  Tick: 51848 4.65, v: 0.0,
#  Tick: 51849 6.98, v: 12300.0,
#  Tick: 51849 6.4, v: 0.0,
#  Tick: 51850 5.81, v: 38900.0,
#  Tick: 51851 6.4, v: 1350.0,
#  Tick: 51851 5.81, v: 0.0,
#  Tick: 51852 6.98, v: 5750.0,
#  Tick: 51853 4.65, v: 5600.0,
#  Tick: 51853 5.23, v: 0.0,
#  Tick: 51854 1.74, v: 21450.0,
#  Tick: 51855 0.58, v: 25550.0,
#  Tick: 51855 0.58, v: 0.0,
#  Tick: 51856 4.07, v: 16600.0,
#  Tick: 51857 2.91, v: 1300.0,
#  Tick: 51858 5.23, v: 10350.0,
#  Tick: 51859 4.65, v: 5350.0,
#  Tick: 51859 5.23, v: 0.0,
#  Tick: 51860 6.98, v: 15500.0,
#  Tick: 51861 5.23, v: 25600.0,
#  Tick: 51861 5.23, v: 0.0,
#  Tick: 51862 4.07, v: 19350.0,
#  Tick: 51863 5.23, v: 9800.0,
#  Tick: 51863 5.81, v: 0.0,
#  Tick: 51864 5.23, v: 9400.0,
#  Tick: 51865 3.49, v: 12350.0,
#  Tick: 51866 3.49, v: 6650.0,
#  Tick: 51866 2.33, v: 0.0,
#  Tick: 51867 2.91, v: 4100.0,
#  Tick: 51867 2.33, v: 0.0,
#  Tick: 51868 1.74, v: 8050.0,
#  Tick: 51869 0.0, v: 13500.0,
#  Tick: 51869 -1.16, v: 0.0,
#  Tick: 51870 -1.16, v: 24700.0,
#  Tick: 51870 1.74, v: 0.0,
#  Tick: 51871 1.74, v: 12300.0,
#  Tick: 51871 1.74, v: 0.0,
#  Tick: 51872 4.65, v: 7900.0,
#  Tick: 51873 3.49, v: 3500.0,
#  Tick: 51874 2.91, v: 2050.0,
#  Tick: 51874 3.49, v: 0.0,
#  Tick: 51874 2.91, v: 0.0,
#  Tick: 51876 2.91, v: 16600.0,
#  Tick: 51876 1.74, v: 0.0,
#  Tick: 51877 1.74, v: 11950.0,
#  Tick: 51878 0.0, v: 11850.0,
#  Tick: 51878 0.58, v: 0.0,
#  Tick: 51879 0.58, v: 3750.0,
#  Tick: 51879 1.74, v: 0.0,
#  Tick: 51880 0.58, v: 10600.0,
#  Tick: 51881 1.74, v: 6300.0,
#  Tick: 51881 0.0, v: 0.0,
#  Tick: 51882 -0.58, v: 11800.0,
#  Tick: 51882 0.0, v: 0.0,
#  Tick: 51883 -1.16, v: 10850.0,
#  Tick: 51884 -0.58, v: 3250.0,
#  Tick: 51884 0.0, v: 0.0,
#  Tick: 51885 -0.58, v: 7800.0,
#  Tick: 51885 1.16, v: 0.0,
#  Tick: 51886 1.74, v: 4800.0,
#  Tick: 51887 0.58, v: 3500.0,
#  Tick: 51887 0.0, v: 0.0,
#  Tick: 51888 0.0, v: 2350.0,
#  Tick: 51888 -2.33, v: 0.0,
#  Tick: 51889 -2.33, v: 6550.0,
#  Tick: 51890 -1.74, v: 6550.0,
#  Tick: 51890 -1.16, v: 0.0,
#  Tick: 51891 -1.16, v: 4500.0,
#  Tick: 51891 -2.33, v: 0.0,
#  Tick: 51892 -2.33, v: 5700.0,
#  Tick: 51892 -3.49, v: 0.0,
#  Tick: 51893 -4.65, v: 15350.0,
#  Tick: 51894 -4.07, v: 12000.0,
#  Tick: 51894 -4.07, v: 0.0,
#  Tick: 51895 -4.65, v: 9700.0,
#  Tick: 51895 -5.23, v: 0.0,
#  Tick: 51896 -5.23, v: 14450.0,
#  Tick: 51897 -7.56, v: 53550.0,
#  Tick: 51897 -8.14, v: 0.0,
#  Tick: 51899 -8.72, v: 20600.0,
#  Tick: 51899 -8.14, v: 13650.0,
#  Tick: 51899 -7.56, v: 0.0,
#  Tick: 51900 -8.72, v: 11750.0,
#  Tick: 51901 -5.23, v: 8800.0,
#  Tick: 51902 -4.65, v: 2350.0,
#  Tick: 51902 -4.07, v: 0.0,
#  Tick: 51903 -4.65, v: 5850.0,
#  Tick: 51903 -4.65, v: 0.0,
#  Tick: 51904 -4.07, v: 2900.0,
#  Tick: 51904 -5.23, v: 0.0,
#  Tick: 51905 -4.07, v: 1000.0,
#  Tick: 51906 -4.07, v: 2550.0,
#  Tick: 51906 -2.33, v: 0.0,
#  Tick: 51907 -2.33, v: 12200.0,
#  Tick: 51907 -1.74, v: 0.0,
#  Tick: 51908 -1.16, v: 7600.0,
#  Tick: 51909 -2.91, v: 2500.0,
#  Tick: 51910 -4.07, v: 30900.0,
#  Tick: 51911 -5.81, v: 13550.0,
#  Tick: 51912 -6.4, v: 4600.0,
#  Tick: 51913 -6.98, v: 3300.0,
#  Tick: 51914 -6.98, v: 4500.0,
#  Tick: 51915 -4.65, v: 6250.0,
#  Tick: 51915 -4.65, v: 0.0,
#  Tick: 51916 -4.65, v: 2400.0,
#  Tick: 51917 -4.65, v: 600.0,
#  Tick: 51918 -5.81, v: 3100.0,
#  Tick: 51918 -4.65, v: 0.0,
#  Tick: 51919 -4.65, v: 2650.0,
#  Tick: 51919 -4.65, v: 0.0,
#  Tick: 51920 -3.49, v: 3450.0,
#  Tick: 51921 -4.07, v: 2700.0,
#  Tick: 51921 -3.49, v: 0.0,
#  Tick: 51922 -2.33, v: 11150.0,
#  Tick: 51923 -3.49, v: 4100.0,
#  Tick: 51924 -3.49, v: 3100.0,
#  Tick: 51925 -4.65, v: 1300.0,
#  Tick: 51926 -4.65, v: 3600.0,
#  Tick: 51927 -6.98, v: 22600.0,
#  Tick: 51928 -8.72, v: 16950.0,
#  Tick: 51929 -8.14, v: 8200.0,
#  Tick: 51929 -8.72, v: 0.0,
#  Tick: 51930 -8.14, v: 15150.0,
#  Tick: 51931 -6.98, v: 2550.0,
#  Tick: 51932 -9.3, v: 2300.0,
#  Tick: 51933 -9.88, v: 13100.0,
#  Tick: 51933 -9.88, v: 0.0,
#  Tick: 51934 -9.88, v: 3150.0,
#  Tick: 51934 -11.05, v: 0.0,
#  Tick: 51935 -9.3, v: 14650.0,
#  Tick: 51935 -9.3, v: 0.0,
#  Tick: 51937 -7.56, v: 8750.0,
#  Tick: 51938 -8.14, v: 6400.0,
#  Tick: 51939 -5.23, v: 3200.0,
#  Tick: 51940 -5.23, v: 8500.0,
#  Tick: 51941 -6.4, v: 3050.0,
#  Tick: 51942 -5.23, v: 650.0,
#  Tick: 51943 -6.98, v: 2200.0,
#  Tick: 51944 -4.65, v: 4250.0,
#  Tick: 51945 -5.81, v: 2250.0,
#  Tick: 51946 -5.81, v: 750.0,
#  Tick: 51947 -6.98, v: 950.0,
#  Tick: 51948 -8.14, v: 2050.0,
#  Tick: 51948 -9.3, v: 0.0,
#  Tick: 51949 -9.88, v: 10550.0,
#  Tick: 51949 -8.72, v: 0.0,
#  Tick: 51950 -9.88, v: 4750.0,
#  Tick: 51951 -9.3, v: 2700.0,
#  Tick: 51951 -9.3, v: 0.0,
#  Tick: 51952 -8.14, v: 3100.0,
#  Tick: 51952 -8.72, v: 0.0,
#  Tick: 51953 -8.72, v: 2950.0,
#  Tick: 51954 -8.14, v: 1300.0,
#  Tick: 51954 -8.72, v: 0.0,
#  Tick: 51955 -8.72, v: 3900.0,
#  Tick: 51956 -6.98, v: 2000.0,
#  Tick: 51957 -6.4, v: 4950.0,
#  Tick: 51958 -7.56, v: 3500.0,
#  Tick: 51959 -7.56, v: 1050.0,
#  Tick: 51959 -8.14, v: 0.0,
#  Tick: 51960 -7.56, v: 2400.0,
#  Tick: 51961 -7.56, v: 2050.0,
#  Tick: 51961 -5.23, v: 0.0,
#  Tick: 51962 -6.98, v: 19600.0,
#  Tick: 51963 -7.56, v: 8250.0,
#  Tick: 51963 -6.4, v: 0.0,
#  Tick: 51964 -5.81, v: 5600.0,
#  Tick: 51964 -7.56, v: 0.0,
#  Tick: 51965 -7.56, v: 400.0,
#  Tick: 51966 -8.14, v: 1400.0,
#  Tick: 51966 -8.72, v: 0.0,
#  Tick: 51967 -9.3, v: 7350.0,
#  Tick: 51967 -9.3, v: 0.0,
#  Tick: 51968 -8.14, v: 6100.0,
#  Tick: 51969 -4.07, v: 9300.0,
#  Tick: 51969 -4.07, v: 0.0,
#  Tick: 51970 -4.65, v: 4650.0,
#  Tick: 51971 -2.91, v: 3450.0,
#  Tick: 51972 -3.49, v: 13150.0,
#  Tick: 51972 -3.49, v: 0.0,
#  Tick: 51973 -4.07, v: 1150.0,
#  Tick: 51974 -3.49, v: 1450.0,
#  Tick: 51974 -2.91, v: 0.0,
#  Tick: 51975 -2.33, v: 7100.0,
#  Tick: 51976 -2.91, v: 4850.0,
#  Tick: 51976 -2.91, v: 0.0,
#  Tick: 51977 -1.74, v: 450.0,
#  Tick: 51977 -3.49, v: 0.0,
#  Tick: 51979 -3.49, v: 8950.0,
#  Tick: 51979 -4.65, v: 0.0,
#  Tick: 51980 -4.65, v: 2400.0,
#  Tick: 51980 -4.65, v: 0.0,
#  Tick: 51981 -4.07, v: 2750.0,
#  Tick: 51983 -5.81, v: 5100.0,
#  Tick: 51984 -5.81, v: 3550.0,
#  Tick: 51984 -5.23, v: 0.0,
#  Tick: 51985 -4.07, v: 2950.0,
#  Tick: 51985 -3.49, v: 0.0,
#  Tick: 51986 -1.16, v: 14350.0,
#  Tick: 51987 -2.33, v: 5100.0,
#  Tick: 51988 -2.91, v: 3800.0,
#  Tick: 51989 -4.07, v: 1150.0,
#  Tick: 51989 -3.49, v: 0.0,
#  Tick: 51990 -4.07, v: 2800.0,
#  Tick: 51990 -2.33, v: 0.0,
#  Tick: 51991 -2.33, v: 1600.0,
#  Tick: 51992 -1.74, v: 5800.0,
#  Tick: 51993 -2.33, v: 12800.0,
#  Tick: 51993 -1.74, v: 0.0,
#  Tick: 51994 -1.74, v: 12500.0,
#  Tick: 51994 -2.33, v: 0.0,
#  Tick: 51995 -3.49, v: 2550.0,
#  Tick: 51995 -3.49, v: 0.0,
#  Tick: 51997 -3.49, v: 850.0,
#  Tick: 51998 -2.91, v: 2550.0,
#  Tick: 51999 -1.74, v: 2050.0,
#  Tick: 51999 -2.33, v: 0.0,
#  Tick: 52000 -2.33, v: 2700.0,
#  Tick: 52001 -1.74, v: 2550.0,
#  Tick: 52002 -2.33, v: 9600.0,
#  Tick: 52002 -2.33, v: 0.0,
#  Tick: 52003 -2.91, v: 2900.0,
#  Tick: 52003 -2.33, v: 0.0,
#  Tick: 52004 -2.91, v: 5200.0,
#  Tick: 52005 -4.07, v: 1000.0,
#  Tick: 52005 -4.07, v: 0.0,
#  Tick: 52006 -2.91, v: 1550.0,
#  Tick: 52007 -1.16, v: 2100.0,
#  Tick: 52008 -2.91, v: 1200.0,
#  Tick: 52008 -1.16, v: 0.0,
#  Tick: 52009 -2.91, v: 4900.0,
#  Tick: 52010 -4.07, v: 300.0,
#  Tick: 52011 -5.23, v: 3500.0,
#  Tick: 52011 -4.07, v: 0.0,
#  Tick: 52012 -4.07, v: 500.0,
#  Tick: 52012 -4.07, v: 0.0,
#  Tick: 52013 -5.81, v: 12250.0,
#  Tick: 52013 -5.23, v: 0.0,
#  Tick: 52014 -3.49, v: 1250.0,
#  Tick: 52015 -2.91, v: 1350.0,
#  Tick: 52016 -2.91, v: 1450.0,
#  Tick: 52017 -5.23, v: 4750.0,
#  Tick: 52017 -6.4, v: 0.0,
#  Tick: 52018 -4.65, v: 900.0,
#  Tick: 52019 -5.23, v: 4000.0,
#  Tick: 52019 -6.4, v: 0.0,
#  Tick: 52020 -5.23, v: 3300.0,
#  Tick: 52020 -6.98, v: 0.0,
#  Tick: 52021 -8.14, v: 25000.0,
#  Tick: 52022 -8.14, v: 14700.0,
#  Tick: 52023 -8.72, v: 13200.0,
#  Tick: 52023 -8.72, v: 0.0,
#  Tick: 52024 -8.72, v: 14350.0,
#  Tick: 52024 -9.3, v: 0.0,
#  Tick: 52025 -8.14, v: 4500.0,
#  Tick: 52026 -8.14, v: 1150.0,
#  Tick: 52026 -8.14, v: 0.0,
#  Tick: 52027 -8.14, v: 500.0,
#  Tick: 52027 -8.72, v: 0.0,
#  Tick: 52028 -8.14, v: 13850.0,
#  Tick: 52028 -8.72, v: 0.0,
#  Tick: 52030 -9.3, v: 5350.0,
#  Tick: 52030 -6.98, v: 700.0,
#  Tick: 52030 -8.14, v: 0.0,
#  Tick: 52031 -6.98, v: 2800.0,
#  Tick: 52031 -8.72, v: 0.0,
#  Tick: 52032 -8.14, v: 3100.0,
#  Tick: 52033 -8.14, v: 3950.0,
#  Tick: 52034 -6.4, v: 9750.0,
#  Tick: 52035 -5.81, v: 2350.0,
#  Tick: 52035 -6.4, v: 0.0,
#  Tick: 52036 -6.4, v: 2350.0,
#  Tick: 52037 -6.4, v: 450.0,
#  Tick: 52038 -6.4, v: 5900.0,
#  Tick: 52038 -6.98, v: 0.0,
#  Tick: 52039 -6.98, v: 5800.0,
#  Tick: 52039 -6.4, v: 0.0,
#  Tick: 52040 -3.49, v: 6500.0,
#  Tick: 52041 -4.65, v: 3000.0,
#  Tick: 52041 -4.07, v: 0.0,
#  Tick: 52042 -4.07, v: 8400.0,
#  Tick: 52042 -4.65, v: 0.0,
#  Tick: 52043 -5.23, v: 7500.0,
#  Tick: 52043 -5.23, v: 0.0,
#  Tick: 52044 -5.81, v: 1300.0,
#  Tick: 52046 -4.07, v: 3650.0,
#  Tick: 52047 -3.49, v: 7050.0,
#  Tick: 52047 -4.07, v: 0.0,
#  Tick: 52048 -4.07, v: 100.0,
#  Tick: 52049 -2.91, v: 1700.0,
#  Tick: 52049 -2.91, v: 0.0,
#  Tick: 52050 -3.49, v: 500.0,
#  Tick: 52050 -2.91, v: 0.0,
#  Tick: 52051 -2.33, v: 4250.0,
#  Tick: 52051 -2.91, v: 0.0,
#  Tick: 52052 -2.91, v: 14600.0,
#  Tick: 52053 -3.49, v: 100.0,
#  Tick: 52053 -2.33, v: 0.0,
#  Tick: 52054 -2.91, v: 550.0,
#  Tick: 52054 -1.74, v: 0.0,
#  Tick: 52055 -2.33, v: 4600.0,
#  Tick: 52056 -2.33, v: 6750.0,
#  Tick: 52056 -2.91, v: 0.0,
#  Tick: 52058 -4.07, v: 1750.0,
#  Tick: 52058 -4.07, v: 1850.0,
#  Tick: 52059 -2.33, v: 4000.0,
#  Tick: 52059 -2.91, v: 0.0,
#  Tick: 52060 -3.49, v: 1250.0,
#  Tick: 52060 -4.65, v: 0.0,
#  Tick: 52061 -4.07, v: 5850.0,
#  Tick: 52061 -3.49, v: 0.0,
#  Tick: 52063 -6.4, v: 1000.0,
#  Tick: 52063 -5.23, v: 500.0,
#  Tick: 52063 -6.98, v: 0.0,
#  Tick: 52064 -6.98, v: 3300.0,
#  Tick: 52064 -5.81, v: 0.0,
#  Tick: 52066 -5.23, v: 1050.0,
#  Tick: 52066 -5.23, v: 500.0,
#  Tick: 52067 -5.81, v: 850.0,
#  Tick: 52068 -7.56, v: 6450.0,
#  Tick: 52068 -6.98, v: 0.0,
#  Tick: 52069 -6.98, v: 2800.0,
#  Tick: 52069 -6.98, v: 0.0,
#  Tick: 52070 -7.56, v: 4150.0,
#  Tick: 52071 -6.98, v: 1850.0,
#  Tick: 52071 -7.56, v: 0.0,
#  Tick: 52072 -7.56, v: 1700.0,
#  Tick: 52072 -7.56, v: 0.0,
#  Tick: 52073 -6.98, v: 2100.0,
#  Tick: 52073 -6.4, v: 0.0,
#  Tick: 52074 -5.81, v: 3800.0,
#  Tick: 52075 -5.81, v: 100.0,
#  Tick: 52075 -6.4, v: 0.0,
#  Tick: 52076 -5.81, v: 3650.0,
#  Tick: 52077 -6.4, v: 100.0,
#  Tick: 52077 -6.4, v: 0.0,
#  Tick: 52078 -6.98, v: 5850.0,
#  Tick: 52078 -6.98, v: 0.0,
#  Tick: 52079 -5.81, v: 1650.0,
#  Tick: 52080 -6.98, v: 1850.0,
#  Tick: 52080 -5.81, v: 0.0,
#  Tick: 52081 -5.81, v: 15600.0,
#  Tick: 52081 -6.98, v: 0.0,
#  Tick: 52082 -6.98, v: 8800.0,
#  Tick: 52082 -8.14, v: 0.0,
#  Tick: 52084 -8.14, v: 11400.0,
#  Tick: 52084 -8.14, v: 8900.0,
#  Tick: 52085 -8.14, v: 900.0,
#  Tick: 52086 -8.72, v: 7300.0,
#  Tick: 52086 -8.72, v: 0.0,
#  Tick: 52087 -8.14, v: 8650.0,
#  Tick: 52087 -9.3, v: 0.0,
#  Tick: 52089 -9.3, v: 5850.0,
#  Tick: 52089 -8.14, v: 5250.0,
#  Tick: 52089 -8.14, v: 0.0,
#  Tick: 52090 -7.56, v: 8950.0,
#  Tick: 52090 -7.56, v: 0.0,
#  Tick: 52092 -8.14, v: 8250.0,
#  Tick: 52092 -8.72, v: 3900.0,
#  Tick: 52092 -8.72, v: 0.0,
#  Tick: 52093 -8.14, v: 1100.0,
#  Tick: 52093 -7.56, v: 0.0,
#  Tick: 52094 -7.56, v: 1350.0,
#  Tick: 52094 -7.56, v: 0.0,
#  Tick: 52095 -8.14, v: 100.0,
#  Tick: 52096 -8.14, v: 100.0,
#  Tick: 52097 -7.56, v: 100.0,
#  Tick: 52097 -8.72, v: 0.0,
#  Tick: 52098 -8.14, v: 1150.0,
#  Tick: 52099 -9.3, v: 12450.0,
#  Tick: 52099 -9.3, v: 0.0,
#  Tick: 52100 -8.72, v: 20350.0,
#  Tick: 52101 -8.14, v: 2850.0,
#  Tick: 52101 -8.14, v: 0.0,
#  Tick: 52102 -8.14, v: 2500.0,
#  Tick: 52102 -9.3, v: 0.0,
#  Tick: 52103 -8.72, v: 1800.0,
#  Tick: 52103 -8.72, v: 0.0,
#  Tick: 52104 -8.72, v: 1050.0,
#  Tick: 52105 -6.4, v: 29800.0,
#  Tick: 52105 -6.4, v: 0.0,
#  Tick: 52107 -7.56, v: 4750.0,
#  Tick: 52108 -7.56, v: 1400.0,
#  Tick: 52110 -9.88, v: 36150.0,
#  Tick: 52110 -9.88, v: 500.0,
#  Tick: 52110 -11.05, v: 0.0,
#  Tick: 52111 -10.47, v: 1600.0,
#  Tick: 52112 -10.47, v: 2800.0,
#  Tick: 52112 -12.79, v: 0.0,
#  Tick: 52113 -12.79, v: 26150.0,
#  Tick: 52115 -13.37, v: 12350.0,
#  Tick: 52115 -12.79, v: 0.0,
#  Tick: 52116 -13.95, v: 13900.0,
#  Tick: 52117 -15.12, v: 22800.0,
#  Tick: 52117 -15.12, v: 0.0,
#  Tick: 52118 -13.37, v: 6500.0,
#  Tick: 52118 -12.79, v: 0.0,
#  Tick: 52119 -12.21, v: 11850.0,
#  Tick: 52120 -11.05, v: 6950.0,
#  Tick: 52120 -11.63, v: 0.0,
#  Tick: 52121 -11.63, v: 3300.0,
#  Tick: 52121 -11.63, v: 0.0,
#  Tick: 52122 -11.05, v: 700.0,
#  Tick: 52123 -9.88, v: 1000.0,
#  Tick: 52123 -10.47, v: 0.0,
#  Tick: 52124 -9.3, v: 2200.0,
#  Tick: 52124 -10.47, v: 0.0,
#  Tick: 52125 -8.14, v: 10500.0,
#  Tick: 52127 -6.98, v: 6000.0,
#  Tick: 52127 -6.4, v: 8950.0,
#  Tick: 52127 -7.56, v: 0.0,
#  Tick: 52128 -6.4, v: 1850.0,
#  Tick: 52130 -6.4, v: 5800.0,
#  Tick: 52131 -6.4, v: 2950.0,
#  Tick: 52131 -6.98, v: 0.0,
#  Tick: 52132 -6.98, v: 4600.0,
#  Tick: 52132 -8.14, v: 0.0,
#  Tick: 52133 -8.14, v: 8350.0,
#  Tick: 52133 -8.14, v: 0.0,
#  Tick: 52134 -8.72, v: 600.0,
#  Tick: 52135 -8.14, v: 500.0,
#  Tick: 52135 -8.72, v: 0.0,
#  Tick: 52136 -8.14, v: 2750.0,
#  Tick: 52136 -8.14, v: 0.0,
#  Tick: 52137 -8.72, v: 2150.0,
#  Tick: 52139 -8.72, v: 3250.0,
#  Tick: 52139 -8.72, v: 0.0,
#  Tick: 52140 -9.88, v: 14050.0,
#  Tick: 52140 -9.88, v: 0.0,
#  Tick: 52141 -8.14, v: 1150.0,
#  Tick: 52141 -9.88, v: 0.0,
#  Tick: 52142 -9.3, v: 8500.0,
#  Tick: 52142 -9.88, v: 0.0,
#  Tick: 52143 -9.88, v: 2050.0,
#  Tick: 52144 -9.88, v: 4300.0,
#  Tick: 52144 -7.56, v: 0.0,
#  Tick: 52146 -8.14, v: 10450.0,
#  Tick: 52146 -8.72, v: 0.0,
#  ...]

# %%
# Losses
# multi_y = [[po.order.limit_price, po.order.square_off_price] for po in pm.closed_orders if po.order.pnl <= 0]
# multi_x = [[po.phase.started_at.id, po.phase.hard_retraced_at.id] for po in pm.closed_orders if po.order.pnl <= 0]
# texts = [str(po.order.pnl) for po in pm.closed_orders if po.order.pnl <= 0]
# subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

# All
from bokeh.models import ColumnDataSource

multi_y = [[po.order.limit_price, po.order.square_off_price] for po in pm.closed_orders]
multi_x = [[po.phase.started_at.id, po.phase.hard_retraced_at.id] for po in pm.closed_orders]
texts = [f"{po.order.pnl}, {round(po.phase.confidence_at_confirmation)}, s:{round(po.phase.svac)}, l:{round(po.phase.lvac)}" for po in pm.closed_orders]
subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

subplot = ColumnDataSource(subplot)

# phase_in_id = [phase.t_start.id for phase in pm.ps]
# phase_in_price = [phase.t_start.last_price for phase in pm.ps]
# phase_start_plot = ColumnDataSource({'x': phase_in_id, 'y': phase_in_price})

# p_end_id = [phase.t_end.id for phase in pm.ps]
# p_end_price = [phase.t_end.last_price for phase in pm.ps]
# phase_end_plot = ColumnDataSource({'x': p_end_id, 'y': p_end_price})

up_start_id = [phase.t_start.id for phase in pm.ps if phase.direction == ph.Direction.UP]
up_start_price = [phase.t_start.last_price for phase in pm.ps if phase.direction == ph.Direction.UP]
up_start_plot = ColumnDataSource({'x': up_start_id, 'y': up_start_price})

up_end_id = [phase.t_end.id for phase in pm.ps if phase.direction == ph.Direction.UP]
up_end_price = [phase.t_end.last_price for phase in pm.ps if phase.direction == ph.Direction.UP]
up_end_plot = ColumnDataSource({'x': up_end_id, 'y': up_end_price})

up_confirm_id = [phase.started_at.id for phase in pm.ps if phase.direction == ph.Direction.UP]
up_confirm_price = [phase.started_at.last_price for phase in pm.ps if phase.direction == ph.Direction.UP]
up_confirm_plot = ColumnDataSource({'x': up_confirm_id, 'y': up_confirm_price})

down_confirm_id = [phase.started_at.id for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_confirm_price = [phase.started_at.last_price for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_confirm_plot = ColumnDataSource({'x': down_confirm_id, 'y': down_confirm_price})

down_start_id = [phase.t_start.id for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_start_price = [phase.t_start.last_price for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_start_plot = ColumnDataSource({'x': down_start_id, 'y': down_start_price})

down_end_id = [phase.t_end.id for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_end_price = [phase.t_end.last_price for phase in pm.ps if phase.direction == ph.Direction.DOWN]
down_end_plot = ColumnDataSource({'x': down_end_id, 'y': down_end_price})

# phase_plot.data
import utils as ut
# ut.bokeh_plot(x=list(range(tdf.shape[0])), y=tdf.last_price, x_label="timestamp", y_label="price", plot='line')
ut.bokeh_plot(x=[m.id for m in pm.ticks], y=[tick.last_price for tick in pm.ticks], x_label="timestamp", y_label="price", plot='line', multi_plots=subplot, subplots=[up_start_plot, up_end_plot, down_start_plot, down_end_plot, up_confirm_plot, down_confirm_plot], subplot_labels=['Up start', 'Up end', 'Down start', 'Down end', 'Up confirm', 'Down confirm'])
# tdf
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e33b3451-f1c8-4ca8-9ee7-7d8c1a123b79">Loading BokehJS ...</span>
#     </div>
#   <div id="e4c3ec58-c619-43a8-b072-ebeb19e2a50c" data-root-id="p1022" style="display: contents;"></div>

# %%
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cf6c36eb-4139-41a7-a8e4-35c6157df90f">Loading BokehJS ...</span>
#     </div>
#   <div id="afa68cff-9c59-466a-9a7d-a43309d66271" data-root-id="p1010" style="display: contents;"></div>

# %%
multi_y = [[ph.started_at.last_price, ph.hard_retraced_at.last_price] for ph in pm.aps if ph.direction == ph.Direction.UP]
multi_x = [[ph.started_at.id, ph.hard_retraced_at.id] for ph in pm.aps if ph.direction == ph.Direction.UP]
texts = [str(round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2)) for ph in pm.aps if ph.direction == ph.Direction.UP]
subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

from bokeh.models import ColumnDataSource
subplot = ColumnDataSource(subplot)
