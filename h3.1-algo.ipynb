# %%
import pandas as pd
import datetime as dt
from logger_settings import logger
import phase as ph

pd.options.display.max_colwidth = 10
pd.options.display.max_rows = None

# %%
ticks_columns = {
    'last_price': float,
    'last_traded_quantity': int,
    'total_buy_quantity': int,
    'total_sell_quantity': int,
    'last_trade_time': 'datetime64[ns]',
    'oi': int,
}
tdf = pd.read_json('ticks-formatted.json', dtype=ticks_columns, convert_dates={'last_trade_time': '%Y-%m-%d %H:%M:%S'})
columns_to_drop = set(tdf.columns).difference(ticks_columns.keys())
tdf.drop(columns=columns_to_drop, inplace=True)
tdf.set_index('last_trade_time', inplace=True, drop=False)


class Settings:
    MIN_UP_PC_CHG = 0.5 / 100 # .5%
    MIN_DOWN_PC_CHG = -0.5 / 100 # -.5%
    BREACH_PC = 5 / 100 # 5% Percentage of continuation phase gains required to breach the trend
    LAST_TICKS_BREACH = {ph.Direction.UP: 5, ph.Direction.DOWN: 5}
    QUANTITY = 50
    CONFIRM_TICKS = 5 # 5 Seconds

# %%
class ContinuationPhase(ph.Phase):
    def __init__(self, ticks, pm):
        self.phase_type = ph.Phase.TYPE_CONT
        self.t_start = ticks[0]
        self.t_end = ticks[-1]
        self.status = self.STATUS_INITIATED
        self.min_pc = None
        self.direction = None
        self.pm = pm
        self.last_processed_tid = ticks[-1].id
        self.started_at = None
        self.terminated_at = None
        self.hard_retraced_at = None
        self.soft_retraced_at = None
        self.last_5sec = ph.Candle(ticks, confirm_ticks=self.pm.settings.CONFIRM_TICKS)
        self.second_last_5sec = ph.Candle([], confirm_ticks=self.pm.settings.CONFIRM_TICKS)

    def start_phase(self):
        if self.t_start.id == 12068:
            print(f"{self.second_last_5sec}, l: {self.last_5sec}")
        if self.second_last_5sec.period < Settings.CONFIRM_TICKS or len(self.last_5sec) == 0:
            if self.t_start.id == 12068:
                print(f"f1: {self.second_last_5sec}, l: {self.last_5sec}")
            return False
        if self.second_last_5sec.IS_RED != self.last_5sec.IS_RED:
            raise ph.PhaseStartFailed(f'failed to start phase at: {self.last_5sec.end_id}')
        is_red_breach = self.second_last_5sec.IS_RED and self.last_5sec.CLOSE >= self.second_last_5sec.CLOSE
        is_green_breach = (not self.second_last_5sec.IS_RED) and self.last_5sec.CLOSE <= self.second_last_5sec.CLOSE
        if is_red_breach or is_green_breach:
            raise ph.PhaseStartFailed(f'failed to start phase at: {self.last_5sec.end_id}')
        if self.t_start.id == 12068:
            print(f"s1: {self.second_last_5sec}, l: {self.last_5sec}")
        price_change = self.last_5sec.CLOSE - self.second_last_5sec.OPEN
        self.min_pc = Settings.MIN_UP_PC_CHG if price_change >= 0 else Settings.MIN_DOWN_PC_CHG
        self.direction = ph.Direction.UP if price_change >= 0 else ph.Direction.DOWN
        self.status = self.STATUS_STARTED
        self.started_at = self.last_5sec[-1]
        return True

    def process(self, tick):
        """
        if it breaks previous open or previous nth tick
        """
        if tick.id <= self.last_processed_tid:
            return
        self.last_processed_tid = tick.id
        self.update_last_nsec(tick)
        self.t_end = tick
        if self.status == self.STATUS_INITIATED:
            has_started = self.start_phase()
            if not has_started:
                return
            self.pm.on_phase_start(self, tick)
            return
        elif self.status == self.STATUS_TERM or self.status == self.STATUS_HARD_RETR:
            return
        change = self.last_5sec.CLOSE - self.second_last_5sec.OPEN
        open_change = self.last_5sec.CLOSE - self.t_start.last_price
        last_5sec_breach = (self.direction == ph.Direction.UP and change < 0) or (self.direction == ph.Direction.DOWN and change > 0)
        open_breach = (self.direction == ph.Direction.UP and open_change < 0) or (self.direction == ph.Direction.DOWN and open_change > 0)
        if last_5sec_breach or open_breach:
            self.status = self.STATUS_HARD_RETR
            self.hard_retraced_at = tick
            raise ph.PhaseHardRetraceException(f"Continuation Phase {self} hard retracing at: {tick}")
        self.status = self.STATUS_ONG

# %%
class MyPhaseManager(ph.PhaseManager):
    def __init__(self, instrument, settings):
        super().__init__(instrument, settings)

    def process(self, tick):
        if self.current_phase is None:
            # First call
            self.current_phase = ContinuationPhase(ticks=[tick], pm=self)
            return
        # Has existing phase
        try:
            self.current_phase.process(tick)
            self.on_ongoing(self.current_phase, tick)
        except ph.PhaseSoftRetraceException:
            self.on_soft_retracel(self.current_phase, tick)
        except ph.PhaseHardRetraceException:
            self.on_hard_retracel(self.current_phase, tick)
            self.ps.append(self.current_phase)
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        except ph.PhaseTerminatedException:
            self.on_hard_retracel(self.current_phase, tick)
            self.on_termination(self.current_phase, tick)
            self.aps.append(self.current_phase)
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        except ph.PhaseStartFailed:
            logger.info(f"phase start failed at: {tick}, phase: {self.current_phase}")
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        # self.process_ps(tick)

    def process_ps(self, tick):
        # Process for process stack
        mark_for_removal = []
        for i in range(len(self.ps)):
            phase = self.ps[i]
            try:
                phase.process(tick)
            except ph.PhaseSoftRetraceException:
                # logger.info(f"soft retracel of {phase}")
                pass
            except ph.PhaseHardRetraceException:
                pass
            except ph.PhaseTerminatedException:
                mark_for_removal.append(i)
                self.aps.append(phase)
        mark_for_removal.reverse()
        for mark in mark_for_removal:
            del self.ps[mark]

    def on_phase_start(self, phase, tick):
        self.current_order = ph.Order(type=ph.Order.TYPE_BUY, limit_price=tick.last_price, quantity=Settings.QUANTITY)

    def on_hard_retracel(self, phase, tick):
        if phase.direction == ph.Direction.UP:
            if self.current_order is not None:
                self.current_order.square_off(tick.last_price)
                self.closed_orders.append(ph.PhaseOrder(phase, self.current_order))
                self.current_order = None
            logger.info(f"hard retracel {phase}, Up change %: {phase.started_at.last_price - phase.hard_retraced_at.last_price}")
        else:
            logger.info(f"hard retracel {phase}, Down change %: {phase.started_at.last_price - phase.hard_retraced_at.last_price}")

instrument = ph.Instrument(name="NIFTY 22650 CALL 7 Mar 2024")
pm = MyPhaseManager(instrument=instrument, settings=Settings)
# for i in range(70):
for i in range(tdf.shape[0]):
    pm.next(tdf.iloc[i].to_dict())

print(pm.current_phase)
# print(pm.ps)
# print(pm.aps)
# Out:
# 2024-03-12 07:04:39,751 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick:
- INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26751 7.56, phase: Continuation: None, INITIATED from Tick: 26741 1.74 to Tick: 26751 7.56, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,216 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 26746 4.07 to Tick: 26761 5.81, confirmation:Tick: 26714 -0.58 terminated at: None, hard retracel: Tick: 26761 5.81, soft: None, Down change %: -6.395348837209291
# 2024-03-12 07:04:40,218 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26767 5.81, phase: Continuation: None, INITIATED from Tick: 26756 2.33 to Tick: 26767 5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,221 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26772 5.81, phase: Continuation: None, INITIATED from Tick: 26762 5.23 to Tick: 26772 5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,224 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26777 11.63, phase: Continuation: None, INITIATED from Tick: 26767 5.81 to Tick: 26777 11.63, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,227 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26783 15.7, phase: Continuation: None, INITIATED from Tick: 26772 6.4 to Tick: 26783 15.7, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,231 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 26778 13.95 to Tick: 26794 15.12, confirmation:Tick: 26761 5.81 terminated at: None, hard retracel: Tick: 26794 15.12, soft: None, Down change %: -9.302325581395355
# 2024-03-12 07:04:40,233 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26800 15.12, phase: Continuation: None, INITIATED from Tick: 26789 12.79 to Tick: 26800 15.12, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,236 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26805 10.47, phase: Continuation: None, INITIATED from Tick: 26795 15.12 to Tick: 26805 10.47, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,239 - INFO - 235263041.py:61 - [140514618705152] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 26800 13.95 to Tick: 26812 12.79, confirmation:Tick: 26794 15.12 terminated at: None, hard retracel: Tick: 26812 12.79, soft: None, Up change %: 2.3255813953488467
# 2024-03-12 07:04:40,241 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26818 9.3, phase: Continuation: None, INITIATED from Tick: 26807 11.05 to Tick: 26818 9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,244 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26824 13.37, phase: Continuation: None, INITIATED from Tick: 26813 13.37 to Tick: 26824 13.37, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,246 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26830 19.19, phase: Continuation: None, INITIATED from Tick: 26818 8.14 to Tick: 26830 19.19, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,248 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26836 19.19, phase: Continuation: None, INITIATED from Tick: 26825 14.53 to Tick: 26836 19.19, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,251 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26842 25.0, phase: Continuation: None, INITIATED from Tick: 26831 19.19 to Tick: 26842 25.0, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,254 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26849 27.91, phase: Continuation: None, INITIATED from Tick: 26837 19.19 to Tick: 26849 27.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,256 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26855 27.91, phase: Continuation: None, INITIATED from Tick: 26843 27.33 to Tick: 26855 27.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,258 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26861 26.74, phase: Continuation: None, INITIATED from Tick: 26850 26.16 to Tick: 26861 26.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,260 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26866 26.74, phase: Continuation: None, INITIATED from Tick: 26855 26.74 to Tick: 26866 26.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,263 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 26861 25.58 to Tick: 26874 31.98, confirmation:Tick: 26812 12.79 terminated at: None, hard retracel: Tick: 26874 31.98, soft: None, Down change %: -19.18604651162791
# 2024-03-12 07:04:40,266 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26880 40.12, phase: Continuation: None, INITIATED from Tick: 26869 22.67 to Tick: 26880 40.12, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,269 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26885 43.6, phase: Continuation: None, INITIATED from Tick: 26875 29.07 to Tick: 26885 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,273 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 26880 41.28 to Tick: 26903 38.95, confirmation:Tick: 26874 31.98 terminated at: None, hard retracel: Tick: 26903 38.95, soft: None, Down change %: -6.976744186046506
# 2024-03-12 07:04:40,275 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 26909 51.16, phase: Continuation: None, INITIATED from Tick: 26899 30.23 to Tick: 26909 51.16, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:40,277 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 
confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,671 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 29944 45.35 to Tick: 29970 43.02, confirmation:Tick: 29882 37.21 terminated at: None, hard retracel: Tick: 29970 43.02, soft: None, Down change %: -5.813953488372093
# 2024-03-12 07:04:41,673 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 29977 42.44, phase: Continuation: None, INITIATED from Tick: 29968 43.02 to Tick: 29977 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,676 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 29983 42.44, phase: Continuation: None, INITIATED from Tick: 29971 44.19 to Tick: 29983 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,680 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 29988 42.44, phase: Continuation: None, INITIATED from Tick: 29977 43.02 to Tick: 29988 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,683 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 29994 43.6, phase: Continuation: None, INITIATED from Tick: 29983 43.02 to Tick: 29994 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,686 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 29999 43.02, phase: Continuation: None, INITIATED from Tick: 29988 43.02 to Tick: 29999 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,689 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30005 44.77, phase: Continuation: None, INITIATED from Tick: 29994 43.6 to Tick: 30005 44.77, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,702 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 30000 44.19 to Tick: 30036 41.86, confirmation:Tick: 29970 43.02 terminated at: None, hard retracel: Tick: 30036 41.86, soft: None, Down change %: 1.1627906976744384
# 2024-03-12 07:04:41,706 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30043 43.02, phase: Continuation: None, INITIATED from Tick: 30033 40.12 to Tick: 30043 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,711 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30048 42.44, phase: Continuation: None, INITIATED from Tick: 30037 41.86 to Tick: 30048 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,720 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 30043 42.44 to Tick: 30072 40.12, confirmation:Tick: 30036 41.86 terminated at: None, hard retracel: Tick: 30072 40.12, soft: None, Down change %: 1.744186046511608
# 2024-03-12 07:04:41,724 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30078 42.44, phase: Continuation: None, INITIATED from Tick: 30067 37.79 to Tick: 30078 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,728 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30084 43.02, phase: Continuation: None, INITIATED from Tick: 30073 40.7 to Tick: 30084 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,732 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30089 43.02, phase: Continuation: None, INITIATED from Tick: 30079 41.86 to Tick: 30089 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,735 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30095 42.44, phase: Continuation: None, INITIATED from Tick: 30084 43.02 to Tick: 30095 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,740 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30101 42.44, phase: Continuation: None, INITIATED from Tick: 30089 42.44 to Tick: 30101 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,743 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 30096 42.44 to Tick: 30108 43.6, confirmation:Tick: 30072 40.12 terminated at: None, hard retracel: Tick: 30108 43.6, soft: None, Down change %: -3.4883720930232442
# 2024-03-12 07:04:41,747 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30114 43.6, phase: Continuation: None, INITIATED from Tick: 30103 43.02 to Tick: 30114 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,750 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30120 43.6, phase: Continuation: None, INITIATED from Tick: 30109 43.6 to Tick: 30120 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,752 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30126 43.02, phase: Continuation: None, INITIATED from Tick: 30115 43.6 to Tick: 30126 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,754 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30131 43.6, phase: Continuation: None, INITIATED from Tick: 30121 44.19 to Tick: 30131 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,757 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30137 43.02, phase: Continuation: None, INITIATED from Tick: 30126 43.02 to Tick: 30137 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,760 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30144 42.44, phase: Continuation: None, INITIATED from Tick: 30132 43.6 to Tick: 30144 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,764 - INFO - 235263041.py:61 - [140514618705152] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 30138 43.02 to Tick: 30151 41.86, confirmation:Tick: 30108 43.6 terminated at: None, hard retracel: Tick: 30151 41.86, soft: None, Up change %: 1.7441860465116363
# 2024-03-12 07:04:41,768 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30157 41.28, phase: Continuation: None, INITIATED from Tick: 30146 43.02 to Tick: 30157 41.28, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,770 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30162 41.86, phase: Continuation: None, INITIATED from Tick: 30152 41.28 to Tick: 30162 41.86, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,773 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30167 40.7, phase: Continuation: None, INITIATED from Tick: 30157 40.7 to Tick: 30167 40.7, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,778 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30173 40.12, phase: Continuation: None, INITIATED from Tick: 30162 42.44 to Tick: 30173 40.12, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,781 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30179 42.44, phase: Continuation: None, INITIATED from Tick: 30168 40.12 to Tick: 30179 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,784 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30185 43.02, phase: Continuation: None, INITIATED from Tick: 30174 41.28 to Tick: 30185 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,787 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30191 42.44, phase: Continuation: None, INITIATED from Tick: 30180 41.86 to Tick: 30191 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,790 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30197 43.6, phase: Continuation: None, INITIATED from Tick: 30186 42.44 to Tick: 30197 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,794 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30203 42.44, phase: Continuation: None, INITIATED from Tick: 30192 42.44 to Tick: 30203 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,797 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 30198 42.44 to Tick: 30210 43.6, confirmation:Tick: 30151 41.86 terminated at: None, hard retracel: Tick: 30210 43.6, soft: None, Down change %: -1.7441860465116363
# 2024-03-12 07:04:41,800 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30216 41.86, phase: Continuation: None, INITIATED from Tick: 30205 43.6 to Tick: 30216 41.86, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,802 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30222 41.86, phase: Continuation: None, INITIATED from Tick: 30211 43.6 to Tick: 30222 41.86, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,812 - INFO - 235263041.py:61 - [140514618705152] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 30217 42.44 to Tick: 30268 49.42, confirmation:Tick: 30210 43.6 terminated at: None, hard retracel: Tick: 30268 49.42, soft: None, Up change %: -5.813953488372093
# 2024-03-12 07:04:41,817 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30274 50.0, phase: Continuation: None, INITIATED from Tick: 30263 50.58 to Tick: 30274 50.0, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,819 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30279 51.16, phase: Continuation: None, INITIATED from Tick: 30269 50.0 to Tick: 30279 51.16, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,821 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30285 52.91, phase: Continuation: None, INITIATED from Tick: 30274 50.0 to Tick: 30285 52.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,824 - INFO - 235263041.py:63 - [140514618705152] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 30280 50.0 to Tick: 30292 51.16, confirmation:Tick: 30268 49.42 terminated at: None, hard retracel: Tick: 30292 51.16, soft: None, Down change %: -1.7441860465116292
# 2024-03-12 07:04:41,827 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30298 52.91, phase: Continuation: None, INITIATED from Tick: 30287 53.49 to Tick: 30298 52.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,830 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30304 54.65, phase: Continuation: None, INITIATED from Tick: 30293 51.74 to Tick: 30304 54.65, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,833 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30309 55.23, phase: Continuation: None, INITIATED from Tick: 30299 52.91 to Tick: 30309 55.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,835 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30315 55.23, phase: Continuation: None, INITIATED from Tick: 30304 54.07 to Tick: 30315 55.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 07:04:41,838 - INFO - 235263041.py:28 - [140514618705152] -
# phase start failed at: Tick: 30321 56.4, phase: Continuation: None, INITIATED from Tick: 30310 55.23 to Tick: 30321 56.4, confirmation:None terminated at: None, hard retracel: None, soft: None
# Continuation: None, INITIATED from Tick: 30316 54.65 to Tick: 30326 55.23, confirmation:None terminated at: None, hard retracel: None, soft: None

# %%
pm.ps[8]
# Out:
# Continuation: up, HARD RETRACING from Tick: 12143 -8.14 to Tick: 12156 -9.88, confirmation:Tick: 12155 -8.72 terminated at: None, hard retracel: Tick: 12156 -9.88, soft: None

# %%
profits = [po.order.pnl for po in pm.closed_orders]
# profits = [round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2) for ph in pm.aps if ph.direction == ph.Direction.UP]
# profits = [round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2) for ph in pm.ps if ph.direction == ph.Direction.UP]
print(sum(profits))
print(len(profits))
# Out:
# -7.519999999999999
# 143

# %%
# Losses
# multi_y = [[po.order.limit_price, po.order.square_off_price] for po in pm.closed_orders if po.order.pnl <= 0]
# multi_x = [[po.phase.started_at.id, po.phase.hard_retraced_at.id] for po in pm.closed_orders if po.order.pnl <= 0]
# texts = [str(po.order.pnl) for po in pm.closed_orders if po.order.pnl <= 0]
# subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

# All
from bokeh.models import ColumnDataSource

multi_y = [[po.order.limit_price, po.order.square_off_price] for po in pm.closed_orders]
multi_x = [[po.phase.started_at.id, po.phase.hard_retraced_at.id] for po in pm.closed_orders]
texts = [str(po.order.pnl) for po in pm.closed_orders]
subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

subplot = ColumnDataSource(subplot)

phase_in_id = [phase.t_start.id for phase in pm.ps]
phase_in_price = [phase.t_start.last_price for phase in pm.ps]
phase_start_plot = ColumnDataSource({'x': phase_in_id, 'y': phase_in_price})

p_end_id = [phase.t_end.id for phase in pm.ps]
p_end_price = [phase.t_end.last_price for phase in pm.ps]
phase_end_plot = ColumnDataSource({'x': p_end_id, 'y': p_end_price})

# phase_plot.data

# %%
import utils as ut
# ut.bokeh_plot(x=list(range(tdf.shape[0])), y=tdf.last_price, x_label="timestamp", y_label="price", plot='line')
ut.bokeh_plot(x=[m.id for m in pm.ticks], y=[tick.last_price for tick in pm.ticks], x_label="timestamp", y_label="price", plot='line', multi_plots=subplot, subplots=[phase_start_plot, phase_end_plot])
# tdf
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="abc9d72f-3bff-49f1-b52b-932392225429">Loading BokehJS ...</span>
#     </div>
#   <div id="aef1d89f-d993-4482-9cb3-11010fc932bf" data-root-id="p1010" style="display: contents;"></div>

# %%
multi_y = [[ph.started_at.last_price, ph.hard_retraced_at.last_price] for ph in pm.aps if ph.direction == ph.Direction.UP]
multi_x = [[ph.started_at.id, ph.hard_retraced_at.id] for ph in pm.aps if ph.direction == ph.Direction.UP]
texts = [str(round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2)) for ph in pm.aps if ph.direction == ph.Direction.UP]
subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

from bokeh.models import ColumnDataSource
subplot = ColumnDataSource(subplot)
