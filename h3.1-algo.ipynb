# %%
import pandas as pd
import datetime as dt
from logger_settings import logger

pd.options.display.max_colwidth = 10
pd.options.display.max_rows = None

# %%
ticks_columns = {
    'last_price': float,
    'last_traded_quantity': int,
    'total_buy_quantity': int,
    'total_sell_quantity': int,
    'last_trade_time': 'datetime64[ns]',
    'oi': int,
}
tdf = pd.read_json('ticks-formatted.json', dtype=ticks_columns, convert_dates={'last_trade_time': '%Y-%m-%d %H:%M:%S'})
columns_to_drop = set(tdf.columns).difference(ticks_columns.keys())
tdf.drop(columns=columns_to_drop, inplace=True)
tdf.set_index('last_trade_time', inplace=True, drop=False)

# %%
START_TIME = dt.datetime.now().replace(year=2024, month=3, day=1)

class Tick:
    def __init__(self, last_price, last_traded_quantity, total_buy_quantity, total_sell_quantity, last_trade_time, oi):
        self.last_price = last_price
        self.last_traded_quantity = last_traded_quantity
        self.total_buy_quantity = total_buy_quantity
        self.total_sell_quantity = total_sell_quantity
        self.last_trade_time = last_trade_time
        self.oi = oi
        self.id = (last_trade_time - START_TIME).seconds

    def __str__(self):
        return self.__repr__()

    def __repr__(self):
        return f"Tick: {self.id} {round(self.last_price, 2)}"

class Direction:
    UP = 'up'
    DOWN = 'down'

class Instrument:
    def __init__(self, name):
        self.name = name

class Phase:
    TYPE_CONT = "continuation"
    TYPE_STAG = "stagnation"

    def __init__(self, phase_type, direction, start):
        self.phase_type = phase_type
        self.direction = direction
        self.start = start
        self.end = None
        self.strength = None

class PhaseStartedException(Exception):
    pass

class PhaseSoftRetraceException(Exception):
    pass

class PhaseHardRetraceException(Exception):
    pass

class PhaseTerminatedException(Exception):
    pass

class Settings:
    MIN_UP_PC_CHG = 0.5 / 100 # .5%
    MIN_DOWN_PC_CHG = -0.5 / 100 # -.5%
    BREACH_PC = 5 / 100 # 5% Percentage of continuation phase gains required to breach the trend
    LAST_TICKS_BREACH = {Direction.UP: 5, Direction.DOWN: 5}
    QUANTITY = 50
    CONFIRM_TICKS = 5 # 5 Seconds


class Order:
    ORDER_ID = 0

    TYPE_BUY = 'buy'
    TYPE_SELL = 'sell'
    STATUS_CREATED = 'CREATED'
    STATUS_EXECUTED = 'EXECUTED'
    STATUS_DECLINE = 'DECLINED'
    STATUS_INTRADE = 'INTRADE'
    STATUS_CLOSED = 'CLOSED'

    def __init__(self, type, limit_price, quantity):
        self.type = type
        self.limit_price = limit_price
        self.quantity = quantity
        self.STATUS = 'CREATED'
        self.square_off_price = None
        self.id = Order.ORDER_ID
        Order.ORDER_ID += 1

    def square_off(self, price):
        self.square_off_price = price
        self.STATUS = Order.STATUS_CLOSED

    @property
    def pnl(self):
        profit = round(self.square_off_price - self.limit_price,  2)
        if self.type == Order.TYPE_BUY:
            return profit
        return - profit

    def __str__(self):
        return self.__repr__()

    def __repr__(self):
        return f"{self.type}, b:{self.limit_price}, s:{self.square_off_price}, pnl:{self.pnl}"

class PhaseOrder:
    def __init__(self, phase, order):
        self.phase = phase
        self.order = order

    def __str__(self):
        return self.__repr__()

    def __repr__(self):
        return f"{self.order}, Phase: {self.phase}"

# %%
from collections import deque


class Candle(deque):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.HIGH = self.OPEN
        self.LOW = self.OPEN

    def append(self, x):
        super().append(x)
        if len(self) == 1:
            self.HIGH = x.last_price
            self.LOW = x.last_price
        else:
            self.HIGH = max(x.last_price, self.HIGH)
            self.LOW = min(x.last_price, self.LOW)

    def popleft(self):
        if self.period < Settings.CONFIRM_TICKS:
            raise Exception("not full yet")
        x = super().popleft()
        if self.HIGH == x.last_price:
            self.HIGH = max(self, key=lambda k: k.last_price).last_price
        if self.LOW == x.last_price:
            self.LOW = min(self, key=lambda k: k.last_price).last_price
        return x

    @property
    def OPEN(self):
        if len(self) == 0:
            return
        return self[0].last_price

    @property
    def CLOSE(self):
        if len(self) == 0:
            return
        return self[-1].last_price

    @property
    def IS_RED(self):
        return self.OPEN > self.CLOSE

    @property
    def period(self):
        if len(self) == 0:
            return 0
        return self[-1].id - self[0].id

    @property
    def start_id(self):
        if len(self) == 0:
            return
        return self[0].id

    @property
    def end_id(self):
        if len(self) == 0:
            return
        return self[-1].id


class PhaseStartFailed(Exception):
    pass

class ContinuationPhase(Phase):
    STATUS_INITIATED = 'INITIATED'
    STATUS_STARTED = 'STARTED'
    STATUS_TERM = 'TERMINATED'
    STATUS_ONG = 'ONGOING'
    STATUS_SOFT_RETR = 'SOFT RETRACING'
    STATUS_HARD_RETR = 'HARD RETRACING'

    def __init__(self, ticks, pm):
        self.phase_type = Phase.TYPE_CONT
        self.t_start = ticks[0]
        self.t_end = ticks[-1]
        self.status = self.STATUS_INITIATED
        self.min_pc = None
        self.direction = None
        self.pm = pm
        self.last_processed_tid = ticks[-1].id
        self.started_at = None
        self.terminated_at = None
        self.hard_retraced_at = None
        self.soft_retraced_at = None
        self.last_5sec = Candle(ticks)
        self.second_last_5sec = Candle([])

    def start_phase(self):
        if self.t_start.id == 12068:
            print(f"{self.second_last_5sec}, l: {self.last_5sec}")
        if self.second_last_5sec.period < Settings.CONFIRM_TICKS or len(self.last_5sec) == 0:
            if self.t_start.id == 12068:
                print(f"f1: {self.second_last_5sec}, l: {self.last_5sec}")
            return False
        if self.second_last_5sec.IS_RED != self.last_5sec.IS_RED:
            raise PhaseStartFailed(f'failed to start phase at: {self.last_5sec.end_id}')
        is_red_breach = self.second_last_5sec.IS_RED and self.last_5sec.CLOSE >= self.second_last_5sec.CLOSE
        is_green_breach = (not self.second_last_5sec.IS_RED) and self.last_5sec.CLOSE <= self.second_last_5sec.CLOSE
        if is_red_breach or is_green_breach:
            raise PhaseStartFailed(f'failed to start phase at: {self.last_5sec.end_id}')
        if self.t_start.id == 12068:
            print(f"s1: {self.second_last_5sec}, l: {self.last_5sec}")
        price_change = self.last_5sec.CLOSE - self.second_last_5sec.OPEN
        self.min_pc = Settings.MIN_UP_PC_CHG if price_change >= 0 else Settings.MIN_DOWN_PC_CHG
        self.direction = Direction.UP if price_change >= 0 else Direction.DOWN
        self.status = self.STATUS_STARTED
        self.started_at = self.last_5sec[-1]
        return True

    def __repr__(self):
        return f"Continuation: {self.direction}, {self.status} from {self.t_start} to {self.t_end}, confirmation:{self.started_at} terminated at: {self.terminated_at}, hard retracel: {self.hard_retraced_at}, soft: {self.soft_retraced_at}"

    def __str__(self):
        return self.__repr__()

    def get_last_n_high(self):
        """
        """
        if len(self.pm.ticks) < 2:
            raise Exception(f"insufficient length to calculate last n high len: {len(self.pm.ticks)}")
        if self.direction == Direction.UP:
            return min(self.pm.ticks[-2-Settings.LAST_TICKS_BREACH[self.direction]: -2], key=lambda x: x.last_price).last_price
        elif self.direction == Direction.DOWN:
            return max(self.pm.ticks[-2-Settings.LAST_TICKS_BREACH[self.direction]: -2], key=lambda x: x.last_price).last_price
        else:
            raise NotImplementedError

    def get_last_nsec_ticks(self, n):
        ticks = []
        close_id = self.last_5sec[-1].id
        idx_sl = 0 # index in second last
        start_id = self.second_last_5sec[idx_sl].id
        for idx_sl in range(len(self.second_last_5sec)):
            if close_id - self.second_last_5sec[idx_sl].id <= n:
                ticks.append(self.second_last_5sec[idx_sl])
        for idx_l in range(len(self.last_5sec)):
            ticks.append(self.last_5sec[idx_l])
        if close_id == 22475:
            print(f"n: {n}, t: {ticks}, {self.last_5sec}, {self.second_last_5sec}")
        return ticks

    def update_last_nsec(self, tick):
        """
        Updates the state for last_5sec and second_last_5sec when new ticks arrive
        """
        if self.second_last_5sec.period < Settings.CONFIRM_TICKS:
            self.second_last_5sec.append(tick)
            return
        self.last_5sec.append(tick)
        while self.last_5sec.period > Settings.CONFIRM_TICKS:
            x = self.last_5sec.popleft()
            self.second_last_5sec.append(x)
        while self.second_last_5sec.period > Settings.CONFIRM_TICKS:
            self.second_last_5sec.popleft()

    def process(self, tick):
        """
        if it breaks previous open or previous nth tick
        """
        if tick.id <= self.last_processed_tid:
            return
        self.last_processed_tid = tick.id
        self.update_last_nsec(tick)
        self.t_end = tick
        if self.status == self.STATUS_INITIATED:
            has_started = self.start_phase()
            if not has_started:
                return
            self.pm.on_phase_start(self, tick)
            return
        elif self.status == self.STATUS_TERM or self.status == self.STATUS_HARD_RETR:
            return
        change = self.last_5sec.CLOSE - self.second_last_5sec.OPEN
        open_change = self.last_5sec.CLOSE - self.t_start.last_price
        last_5sec_breach = (self.direction == Direction.UP and change < 0) or (self.direction == Direction.DOWN and change > 0)
        open_breach = (self.direction == Direction.UP and open_change < 0) or (self.direction == Direction.DOWN and open_change > 0)
        if last_5sec_breach or open_breach:
            self.status = self.STATUS_HARD_RETR
            self.hard_retraced_at = tick
            raise PhaseHardRetraceException(f"Continuation Phase {self} hard retracing at: {tick}")
        self.status = self.STATUS_ONG

        # if self.status in [self.STATUS_STARTED, self.STATUS_ONG, self.STATUS_SOFT_RETR]:
        #     if (self.direction == Direction.UP and change < 0) or (self.direction == Direction.DOWN and change > 0):
        #         if (self.direction == Direction.UP and tick.last_price < self.t_start.last_price) or (self.direction == Direction.DOWN and tick.last_price > self.t_start.last_price):
        #             self.status = self.STATUS_TERM
        #             self.terminated_at = tick
        #             if self.hard_retraced_at is None:
        #                 self.hard_retraced_at = tick
        #             if self.soft_retraced_at is None:
        #                 self.soft_retraced_at = tick
        #             raise PhaseTerminatedException(f"Continuation Phase {self} terminated at: {tick}")
        #         else:
        #             last = self.get_last_n_high()
        #             if (tick.last_price < last and self.direction == Direction.UP) or (tick.last_price > last and self.direction == Direction.DOWN):
        #                 self.status = self.STATUS_HARD_RETR
        #                 self.hard_retraced_at = tick
        #                 if self.soft_retraced_at is None:
        #                     self.soft_retraced_at = tick
        #                 raise PhaseHardRetraceException(f"Continuation Phase {self} hard retracing at: {tick}")
        #             else:
        #                 self.status = self.STATUS_SOFT_RETR
        #                 self.soft_retraced_at = tick
        #                 raise PhaseSoftRetraceException(f"Continuation Phase {self} soft retracing at: {tick}")
        #     elif self.status == self.STATUS_SOFT_RETR:
        #         self.soft_retraced_at = None
        #     self.status = self.STATUS_ONG
        #     self.t_end = tick
        # elif self.status == self.STATUS_SOFT_RETR:
        #     pass
        # else:
        #     raise NotImplementedError

# %%
class PhaseManager:
    def __init__(self, instrument):
        self.instrument = instrument
        self.current_phase = None
        self.ps = [] # phase stack
        self.aps = [] # archived phase stack
        self.ticks = []
        self.first_pc = None
        self.current_id = 0
        self.current_order = None
        self.closed_orders = []

    def get_pc_tick(self, tick):
        if len(self.ticks) == 0:
            self.first_pc = tick
        pc_tick = {
            'last_price': (tick['last_price'] - self.first_pc['last_price']) * 100 / self.first_pc['last_price'],
            'last_traded_quantity': (tick['last_traded_quantity'] - self.first_pc['last_traded_quantity']) * 100 / self.first_pc['last_traded_quantity'],
            'total_buy_quantity': (tick['total_buy_quantity'] - self.first_pc['total_buy_quantity']) * 100 / self.first_pc['total_buy_quantity'],
            'total_sell_quantity': (tick['total_sell_quantity'] - self.first_pc['total_sell_quantity']) * 100 / self.first_pc['total_sell_quantity'],
            'last_trade_time': tick['last_trade_time'],
            'oi': (tick['oi'] - self.first_pc['oi']) * 100 / self.first_pc['oi'],
        }
        tick_obj = Tick(**pc_tick)
        self.current_id += 1
        return tick_obj

    def next(self, tick):
        pc_tick = self.get_pc_tick(tick)
        self.ticks.append(pc_tick)
        return self.process(pc_tick)

    def process(self, tick):
        if self.current_phase is None:
            # First call
            self.current_phase = ContinuationPhase(ticks=[tick], pm=self)
            return
        # Has existing phase
        try:
            self.current_phase.process(tick)
            self.on_ongoing(self.current_phase, tick)
        except PhaseSoftRetraceException:
            self.on_soft_retracel(self.current_phase, tick)
        except PhaseHardRetraceException:
            self.on_hard_retracel(self.current_phase, tick)
            self.ps.append(self.current_phase)
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        except PhaseTerminatedException:
            self.on_hard_retracel(self.current_phase, tick)
            self.on_termination(self.current_phase, tick)
            self.aps.append(self.current_phase)
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        except PhaseStartFailed:
            logger.info(f"phase start failed at: {tick}, phase: {self.current_phase}")
            ticks = self.current_phase.get_last_nsec_ticks(Settings.CONFIRM_TICKS)
            self.current_phase = ContinuationPhase(ticks=ticks, pm=self)
        # self.process_ps(tick)

    def process_ps(self, tick):
        # Process for process stack
        mark_for_removal = []
        for i in range(len(self.ps)):
            phase = self.ps[i]
            try:
                phase.process(tick)
            except PhaseSoftRetraceException:
                # logger.info(f"soft retracel of {phase}")
                pass
            except PhaseHardRetraceException:
                pass
            except PhaseTerminatedException:
                mark_for_removal.append(i)
                self.aps.append(phase)
        mark_for_removal.reverse()
        for mark in mark_for_removal:
            del self.ps[mark]

    def on_soft_retracel(self, phase, tick):
        # logger.info(f"soft retracel {phase}")
        pass

    def on_phase_start(self, phase, tick):
        self.current_order = Order(type=Order.TYPE_BUY, limit_price=tick.last_price, quantity=Settings.QUANTITY)

    def on_hard_retracel(self, phase, tick):
        if phase.direction == Direction.UP:
            if self.current_order is not None:
                self.current_order.square_off(tick.last_price)
                self.closed_orders.append(PhaseOrder(phase, self.current_order))
                self.current_order = None
            logger.info(f"hard retracel {phase}, Up change %: {phase.started_at.last_price - phase.hard_retraced_at.last_price}")
        else:
            logger.info(f"hard retracel {phase}, Down change %: {phase.started_at.last_price - phase.hard_retraced_at.last_price}")

    def on_termination(self, phase, tick):
        # logger.info(f"termination {phase}")
        pass

    def on_initiation(self, phase, tick):
        # logger.info(f"initiation {phase}")
        pass

    def on_ongoing(self, phase, tick):
        pass
        # logger.info(f"ongoing {phase}")

instrument = Instrument(name="NIFTY 22650 CALL 7 Mar 2024")
pm = PhaseManager(instrument=instrument)
# for i in range(70):
for i in range(tdf.shape[0]):
    pm.next(tdf.iloc[i].to_dict())


print(pm.current_phase)
# print(pm.ps)
# print(pm.aps)
# Out:
# 2024-03-12 06:32:04,355 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 11990 -2.91, phase: Continuation: None, INITIATED from Tick: 11983 0.0 to Tick: 11990 -2.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,369 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 11996 -1.74, phase: Continuation: None, INITIATED from Tick: 11985 0.58 to Tick: 11996 -1.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,381 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 11991 -3.49 to Tick: 12020 0.58, confirmation:Tick: 11983 0.0 terminated at: None, hard retracel: Tick: 12020 0.58, soft: None, Up change %: -0.5813953488372176
# 2024-03-12 06:32:04,385 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12027 -2.33, phase: Continuation: None, INITIATED from Tick: 12015 2.91 to Tick: 12027 -2.33, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,396 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12032 -2.33, phase: Continuation: None, INITIATED from Tick: 12021 0.58 to Tick: 12032 -2.33, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,400 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12038 -4.07, phase: Continuation: None, INITIATED from Tick: 12027 -1.16 to Tick: 12038 -4.07, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,404 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12044 -9.3, phase: Continuation: None, INITIATED from Tick: 12033 -2.91 to Tick: 12044 -9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,407 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12050 -10.47, phase: Continuation: None, INITIATED from Tick: 12039 -5.81 to Tick: 12050 -10.47, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,410 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12056 -11.63, phase: Continuation: None, INITIATED from Tick: 12045 -9.3 to Tick: 12056 -11.63, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,415 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12051 -10.47 to Tick: 12064 -11.63, confirmation:Tick: 12020 0.58 terminated at: None, hard retracel: Tick: 12064 -11.63, soft: None, Up change %: 12.209302325581405
# 2024-03-12 06:32:04,418 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12070 -14.53, phase: Continuation: None, INITIATED from Tick: 12059 -8.14 to Tick: 12070 -14.53, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,421 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12065 -11.63 to Tick: 12076 -15.12, confirmation:Tick: 12064 -11.63 terminated at: None, hard retracel: Tick: 12076 -15.12, soft: None, Up change %: 3.4883720930232514
# 2024-03-12 06:32:04,426 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12083 -8.72, phase: Continuation: None, INITIATED from Tick: 12071 -15.12 to Tick: 12083 -8.72, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,431 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12089 -4.07, phase: Continuation: None, INITIATED from Tick: 12078 -8.14 to Tick: 12089 -4.07, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,435 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12096 -6.4, phase: Continuation: None, INITIATED from Tick: 12084 -6.98 to Tick: 12096 -6.4, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,443 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12090 -6.4 to Tick: 12120 -9.88, confirmation:Tick: 12076 -15.12 terminated at: None, hard retracel: Tick: 12120 -9.88, soft: None, Down change %: -5.232558139534884
# 2024-03-12 06:32:04,447 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12127 -13.37, phase: Continuation: None, INITIATED from Tick: 12118 -8.72 to Tick: 12127 -13.37, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,453 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12122 -12.79 to Tick: 12147 -9.88, confirmation:Tick: 12120 -9.88 terminated at: None, hard retracel: Tick: 12147 -9.88, soft: None, Up change %: 0.0
# 2024-03-12 06:32:04,456 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12154 -11.05, phase: Continuation: None, INITIATED from Tick: 12143 -8.14 to Tick: 12154 -11.05, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,459 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12159 -6.98, phase: Continuation: None, INITIATED from Tick: 12149 -9.88 to Tick: 12159 -6.98, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,462 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12164 -4.65, phase: Continuation: None, INITIATED from Tick: 12154 -9.88 to Tick: 12164 -4.65, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,465 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12170 -4.07, phase: Continuation: None, INITIATED from Tick: 12159 -5.81 to Tick: 12170 -4.07, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,471 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12165 -4.07 to Tick: 12182 -3.49, confirmation:Tick: 12147 -9.88 terminated at: None, hard retracel: Tick: 12182 -3.49, soft: None, Down change %: -6.395348837209311
# 2024-03-12 06:32:04,476 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12189 -5.23, phase: Continuation: None, INITIATED from Tick: 12179 -5.23 to Tick: 12189 -5.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,492 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12195 -6.4, phase: Continuation: None, INITIATED from Tick: 12183 -3.49 to Tick: 12195 -6.4, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,500 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12201 -7.56, phase: Continuation: None, INITIATED from Tick: 12190 -4.07 to Tick: 12201 -7.56, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,507 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12196 -6.4 to Tick: 12223 -6.4, confirmation:Tick: 12182 -3.49 terminated at: None, hard retracel: Tick: 12223 -6.4, soft: None, Up change %: 2.9069767441860472
# 2024-03-12 06:32:04,511 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12229 -5.81, phase: Continuation: None, INITIATED from Tick: 12219 -5.81 to Tick: 12229 -5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,514 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12236 -9.88, phase: Continuation: None, INITIATED from Tick: 12224 -6.98 to Tick: 12236 -9.88, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,517 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12230 -7.56 to Tick: 12242 -9.88, confirmation:Tick: 12223 -6.4 terminated at: None, hard retracel: Tick: 12242 -9.88, soft: None, Up change %: 3.488372093023264
# 2024-03-12 06:32:04,521 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12248 -9.3, phase: Continuation: None, INITIATED from Tick: 12238 -10.47 to Tick: 12248 -9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,523 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12253 -4.65, phase: Continuation: None, INITIATED from Tick: 12243 -10.47 to Tick: 12253 -4.65, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,528 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12259 -0.58, phase: Continuation: None, INITIATED from Tick: 12248 -6.4 to Tick: 12259 -0.58, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,531 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12265 0.0, phase: Continuation: None, INITIATED from Tick: 12254 -5.23 to Tick: 12265 0.0, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,534 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12260 -1.74 to Tick: 12271 -1.16, confirmation:Tick: 12242 -9.88 terminated at: None, hard retracel: Tick: 12271 -1.16, soft: None, Down change %: -8.720930232558139
# 2024-03-12 06:32:04,537 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12278 -5.23, phase: Continuation: None, INITIATED from Tick: 12267 1.16 to Tick: 12278 -5.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,540 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12284 -5.81, phase: Continuation: None, INITIATED from Tick: 12272 -1.16 to Tick: 12284 -5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,543 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12289 -6.4, phase: Continuation: None, INITIATED from Tick: 12279 -3.49 to Tick: 12289 -6.4, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,546 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12295 -9.3, phase: Continuation: None, INITIATED from Tick: 12284 -5.81 to Tick: 12295 -9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,550 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12290 -6.4 to Tick: 12305 -8.72, confirmation:Tick: 12271 -1.16 terminated at: None, hard retracel: Tick: 12305 -8.72, soft: None, Up change %: 7.558139534883725
# 2024-03-12 06:32:04,553 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12312 -5.81, phase: Continuation: None, INITIATED from Tick: 12300 -4.65 to Tick: 12312 -5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,557 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12306 -7.56 to Tick: 12322 -5.23, confirmation:Tick: 12305 -8.72 terminated at: None, hard retracel: Tick: 12322 -5.23, soft: None, Down change %: -3.488372093023264
# 2024-03-12 06:32:04,561 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12329 -6.98, phase: Continuation: None, INITIATED from Tick: 12317 -8.14 to Tick: 12329 -6.98, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,564 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12335 -5.81, phase: Continuation: None, INITIATED from Tick: 12323 -4.65 to Tick: 12335 -5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,566 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12340 -5.23, phase: Continuation: None, INITIATED from Tick: 12330 -6.4 to Tick: 12340 -5.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,569 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12346 -7.56, phase: Continuation: None, INITIATED from Tick: 12335 -4.07 to Tick: 12346 -7.56, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,572 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12352 -12.79, phase: Continuation: None, INITIATED from Tick: 12340 -6.4 to Tick: 12352 -12.79, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,575 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12347 -8.14 to Tick: 12359 -10.47, confirmation:Tick: 12322 -5.23 terminated at: None, hard retracel: Tick: 12359 -10.47, soft: None, Up change %: 5.232558139534886
# 2024-03-12 06:32:04,579 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12365 -10.47, phase: Continuation: None, INITIATED from Tick: 12354 -13.37 to Tick: 12365 -10.47, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,582 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12371 -9.3, phase: Continuation: None, INITIATED from Tick: 12360 -12.21 to Tick: 12371 -9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,585 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12376 -11.63, phase: Continuation: None, INITIATED from Tick: 12365 -11.05 to Tick: 12376 -11.63, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,588 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12381 -12.79, phase: Continuation: None, INITIATED from Tick: 12371 -8.14 to Tick: 12381 -12.79, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,598 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12376 -11.63 to Tick: 12411 -3.49, confirmation:Tick: 12359 -10.47 terminated at: None, hard retracel: Tick: 12411 -3.49, soft: None, Up change %: -6.976744186046518
# 2024-03-12 06:32:04,601 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12418 -2.91, phase: Continuation: None, INITIATED from Tick: 12407 -2.91 to Tick: 12418 -2.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,604 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12424 1.74, phase: Continuation: None, INITIATED from Tick: 12412 -4.07 to Tick: 12424 1.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,607 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12430 2.33, phase: Continuation: None, INITIATED from Tick: 12419 -1.74 to Tick: 12430 2.33, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,611 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12425 1.74 to Tick: 12436 4.07, confirmation:Tick: 12411 -3.49 terminated at: None, hard retracel: Tick: 12436 4.07, soft: None, Down change %: -7.558139534883704
# 2024-03-12 06:32:04,614 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12442 5.81, phase: Continuation: None, INITIATED from Tick: 12431 4.07 to Tick: 12442 5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,617 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12448 4.07, phase: Continuation: None, INITIATED from Tick: 12437 5.23 to Tick: 12448 4.07, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,621 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12454 4.07, phase: Continuation: None, INITIATED from Tick: 12443 6.4 to Tick: 12454 4.07, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,628 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12460 1.74, phase: Continuation: None, INITIATED from Tick: 12449 2.91 to Tick: 12460 1.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,631 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12466 2.91, phase: Continuation: None, INITIATED from Tick: 12455 5.23 to Tick: 12466 2.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,634 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12471 0.58, phase: Continuation: None, INITIATED from Tick: 12461 0.0 to Tick: 12471 0.58, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,639 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12476 -0.58, phase: Continuation: None, INITIATED from Tick: 12466 3.49 to Tick: 12476 -0.58, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,642 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12481 -2.33, phase: Continuation: None, INITIATED from Tick: 12471 1.74 to Tick: 12481 -2.33, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,646 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12487 -4.65, phase: Continuation: None, INITIATED from Tick: 12476 0.0 to Tick: 12487 -4.65, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,649 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12492 -8.72, phase: Continuation: None, INITIATED from Tick: 12482 -1.74 to Tick: 12492 -8.72, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,654 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12487 -5.23 to Tick: 12503 -5.81, confirmation:Tick: 12436 4.07 terminated at: None, hard retracel: Tick: 12503 -5.81, soft: None, Up change %: 9.883720930232554
# 2024-03-12 06:32:04,657 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12509 -4.65, phase: Continuation: None, INITIATED from Tick: 12498 -4.07 to Tick: 12509 -4.65, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,661 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12515 -3.49, phase: Continuation: None, INITIATED from Tick: 12504 -6.4 to Tick: 12515 -3.49, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,664 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12521 -8.14, phase: Continuation: None, INITIATED from Tick: 12510 -5.81 to Tick: 12521 -8.14, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,669 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12526 -9.88, phase: Continuation: None, INITIATED from Tick: 12516 -3.49 to Tick: 12526 -9.88, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,672 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12531 -5.23, phase: Continuation: None, INITIATED from Tick: 12521 -8.72 to Tick: 12531 -5.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,674 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12537 -5.81, phase: Continuation: None, INITIATED from Tick: 12526 -11.05 to Tick: 12537 -5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,677 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12543 -9.3, phase: Continuation: None, INITIATED from Tick: 12532 -5.23 to Tick: 12543 -9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,680 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12538 -5.81 to Tick: 12549 -6.4, confirmation:Tick: 12503 -5.81 terminated at: None, hard retracel: Tick: 12549 -6.4, soft: None, Up change %: 0.581395348837197
# 2024-03-12 06:32:04,685 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12544 -8.14 to Tick: 12558 -8.14, confirmation:Tick: 12549 -6.4 terminated at: None, hard retracel: Tick: 12558 -8.14, soft: None, Up change %: 1.744186046511631
# 2024-03-12 06:32:04,688 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12564 -3.49, phase: Continuation: None, INITIATED from Tick: 12553 -7.56 to Tick: 12564 -3.49, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,691 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12569 -1.74, phase: Continuation: None, INITIATED from Tick: 12559 -9.3 to Tick: 12569 -1.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,697 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12564 -3.49 to Tick: 12578 -1.16, confirmation:Tick: 12558 -8.14 terminated at: None, hard retracel: Tick: 12578 -1.16, soft: None, Down change %: -6.976744186046507
# 2024-03-12 06:32:04,707 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12573 -4.07 to Tick: 12595 -2.91, confirmation:Tick: 12578 -1.16 terminated at: None, hard retracel: Tick: 12595 -2.91, soft: None, Up change %: 1.7441860465116323
# 2024-03-12 06:32:04,710 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12601 -2.91, phase: Continuation: None, INITIATED from Tick: 12592 -2.33 to Tick: 12601 -2.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,714 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12607 -2.91, phase: Continuation: None, INITIATED from Tick: 12596 -2.91 to Tick: 12607 -2.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,716 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12613 -8.14, phase: Continuation: None, INITIATED from Tick: 12602 -4.07 to Tick: 12613 -8.14, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,718 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12608 -2.91 to Tick: 12620 -8.14, confirmation:Tick: 12595 -2.91 terminated at: None, hard retracel: Tick: 12620 -8.14, soft: None, Up change %: 5.232558139534875
# 2024-03-12 06:32:04,721 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12627 -5.81, phase: Continuation: None, INITIATED from Tick: 12615 -8.72 to Tick: 12627 -5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,725 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12632 -3.49, phase: Continuation: None, INITIATED from Tick: 12622 -9.3 to Tick: 12632 -3.49, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,727 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12638 -4.07, phase: Continuation: None, INITIATED from Tick: 12627 -6.4 to Tick: 12638 -4.07, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,730 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12644 -2.91, phase: Continuation: None, INITIATED from Tick: 12633 -4.65 to Tick: 12644 -2.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,733 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12639 -3.49 to Tick: 12651 -2.33, confirmation:Tick: 12620 -8.14 terminated at: None, hard retracel: Tick: 12651 -2.33, soft: None, Down change %: -5.813953488372093
# 2024-03-12 06:32:04,736 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12658 -5.23, phase: Continuation: None, INITIATED from Tick: 12646 -2.91 to Tick: 12658 -5.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,738 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12663 -6.98, phase: Continuation: None, INITIATED from Tick: 12652 -3.49 to Tick: 12663 -6.98, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,741 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12658 -5.23 to Tick: 12669 -6.4, confirmation:Tick: 12651 -2.33 terminated at: None, hard retracel: Tick: 12669 -6.4, soft: None, Up change %: 4.069767441860462
# 2024-03-12 06:32:04,745 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12676 -8.14, phase: Continuation: None, INITIATED from Tick: 12664 -7.56 to Tick: 12676 -8.14, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,748 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12681 -9.3, phase: Continuation: None, INITIATED from Tick: 12670 -6.98 to Tick: 12681 -9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,752 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12676 -8.14 to Tick: 12691 -9.3, confirmation:Tick: 12669 -6.4 terminated at: None, hard retracel: Tick: 12691 -9.3, soft: None, Up change %: 2.906976744186057
# 2024-03-12 06:32:04,754 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12697 -6.4, phase: Continuation: None, INITIATED from Tick: 12686 -7.56 to Tick: 12697 -6.4, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,755 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12702 -9.88, phase: Continuation: None, INITIATED from Tick: 12692 -8.72 to Tick: 12702 -9.88, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,758 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12707 -13.37, phase: Continuation: None, INITIATED from Tick: 12697 -6.4 to Tick: 12707 -13.37, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,761 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12702 -9.88 to Tick: 12713 -11.63, confirmation:Tick: 12691 -9.3 terminated at: None, hard retracel: Tick: 12713 -11.63, soft: None, Up change %: 2.3255813953488396
# 2024-03-12 06:32:04,763 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12719 -6.98, phase: Continuation: None, INITIATED from Tick: 12708 -13.95 to Tick: 12719 -6.98, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,766 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12714 -11.05 to Tick: 12725 -8.14, confirmation:Tick: 12713 -11.63 terminated at: None, hard retracel: Tick: 12725 -8.14, soft: None, Down change %: -3.4883720930232656
# 2024-03-12 06:32:04,769 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12731 -8.72, phase: Continuation: None, INITIATED from Tick: 12720 -6.4 to Tick: 12731 -8.72, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,771 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12736 -9.88, phase: Continuation: None, INITIATED from Tick: 12726 -8.72 to Tick: 12736 -9.88, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,774 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12741 -9.3, phase: Continuation: None, INITIATED from Tick: 12731 -8.72 to Tick: 12741 -9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,777 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12748 -9.3, phase: Continuation: None, INITIATED from Tick: 12736 -7.56 to Tick: 12748 -9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,788 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12742 -8.72 to Tick: 12779 -0.58, confirmation:Tick: 12725 -8.14 terminated at: None, hard retracel: Tick: 12779 -0.58, soft: None, Up change %: -7.558139534883725
# 2024-03-12 06:32:04,791 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12786 -2.33, phase: Continuation: None, INITIATED from Tick: 12778 -2.33 to Tick: 12786 -2.33, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,794 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12791 -2.91, phase: Continuation: None, INITIATED from Tick: 12781 -0.58 to Tick: 12791 -2.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,797 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12796 -5.23, phase: Continuation: None, INITIATED from Tick: 12786 -2.33 to Tick: 12796 -5.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,799 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12801 0.0, phase: Continuation: None, INITIATED from Tick: 12791 -2.33 to Tick: 12801 0.0, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,802 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12806 2.91, phase: Continuation: None, INITIATED from Tick: 12796 -4.65 to Tick: 12806 2.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,804 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12811 4.07, phase: Continuation: None, INITIATED from Tick: 12801 0.0 to Tick: 12811 4.07, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,807 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12816 7.56, phase: Continuation: None, INITIATED from Tick: 12806 1.74 to Tick: 12816 7.56, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,811 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12811 4.07 to Tick: 12826 5.81, confirmation:Tick: 12779 -0.58 terminated at: None, hard retracel: Tick: 12826 5.81, soft: None, Down change %: -6.395348837209291
# 2024-03-12 06:32:04,815 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12832 5.81, phase: Continuation: None, INITIATED from Tick: 12821 2.33 to Tick: 12832 5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,817 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12837 5.81, phase: Continuation: None, INITIATED from Tick: 12827 5.23 to Tick: 12837 5.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,819 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12842 11.63, phase: Continuation: None, INITIATED from Tick: 12832 5.81 to Tick: 12842 11.63, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,822 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12848 15.7, phase: Continuation: None, INITIATED from Tick: 12837 6.4 to Tick: 12848 15.7, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,826 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12843 13.95 to Tick: 12859 15.12, confirmation:Tick: 12826 5.81 terminated at: None, hard retracel: Tick: 12859 15.12, soft: None, Down change %: -9.302325581395355
# 2024-03-12 06:32:04,828 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12865 15.12, phase: Continuation: None, INITIATED from Tick: 12854 12.79 to Tick: 12865 15.12, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,830 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12870 10.47, phase: Continuation: None, INITIATED from Tick: 12860 15.12 to Tick: 12870 10.47, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,832 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 12865 13.95 to Tick: 12877 12.79, confirmation:Tick: 12859 15.12 terminated at: None, hard retracel: Tick: 12877 12.79, soft: None, Up change %: 2.3255813953488467
# 2024-03-12 06:32:04,835 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12883 9.3, phase: Continuation: None, INITIATED from Tick: 12872 11.05 to Tick: 12883 9.3, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,838 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12889 13.37, phase: Continuation: None, INITIATED from Tick: 12878 13.37 to Tick: 12889 13.37, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,841 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12895 19.19, phase: Continuation: None, INITIATED from Tick: 12883 8.14 to Tick: 12895 19.19, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,846 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12901 19.19, phase: Continuation: None, INITIATED from Tick: 12890 14.53 to Tick: 12901 19.19, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,848 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12907 25.0, phase: Continuation: None, INITIATED from Tick: 12896 19.19 to Tick: 12907 25.0, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,851 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12914 27.91, phase: Continuation: None, INITIATED from Tick: 12902 19.19 to Tick: 12914 27.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,853 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12920 27.91, phase: Continuation: None, INITIATED from Tick: 12908 27.33 to Tick: 12920 27.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,856 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12926 26.74, phase: Continuation: None, INITIATED from Tick: 12915 26.16 to Tick: 12926 26.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,860 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12931 26.74, phase: Continuation: None, INITIATED from Tick: 12920 26.74 to Tick: 12931 26.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,864 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12926 25.58 to Tick: 12939 31.98, confirmation:Tick: 12877 12.79 terminated at: None, hard retracel: Tick: 12939 31.98, soft: None, Down change %: -19.18604651162791
# 2024-03-12 06:32:04,867 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12945 40.12, phase: Continuation: None, INITIATED from Tick: 12934 22.67 to Tick: 12945 40.12, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,870 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12950 43.6, phase: Continuation: None, INITIATED from Tick: 12940 29.07 to Tick: 12950 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,874 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12945 41.28 to Tick: 12968 38.95, confirmation:Tick: 12939 31.98 terminated at: None, hard retracel: Tick: 12968 38.95, soft: None, Down change %: -6.976744186046506
# 2024-03-12 06:32:04,877 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12974 51.16, phase: Continuation: None, INITIATED from Tick: 12964 30.23 to Tick: 12974 51.16, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,880 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12969 39.53 to Tick: 12980 42.44, confirmation:Tick: 12968 38.95 terminated at: None, hard retracel: Tick: 12980 42.44, soft: None, Down change %: -3.4883720930232656
# 2024-03-12 06:32:04,883 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12986 50.58, phase: Continuation: None, INITIATED from Tick: 12975 47.67 to Tick: 12986 50.58, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,886 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12992 51.74, phase: Continuation: None, INITIATED from Tick: 12981 42.44 to Tick: 12992 51.74, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,888 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 12997 50.58, phase: Continuation: None, INITIATED from Tick: 12987 48.26 to Tick: 12997 50.58, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,891 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13003 52.91, phase: Continuation: None, INITIATED from Tick: 12992 50.58 to Tick: 13003 52.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,893 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 12998 50.0 to Tick: 13009 51.16, confirmation:Tick: 12980 42.44 terminated at: None, hard retracel: Tick: 13009 51.16, soft: None, Down change %: -8.720930232558139
# 2024-03-12 06:32:04,895 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13015 50.0, phase: Continuation: None, INITIATED from Tick: 13004 51.74 to Tick: 13015 50.0, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,898 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13021 39.53, phase: Continuation: None, INITIATED from Tick: 13010 50.0 to Tick: 13021 39.53, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,900 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13026 38.95, phase: Continuation: None, INITIATED from Tick: 13016 48.84 to Tick: 13026 38.95, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,905 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 13021 41.28 to Tick: 13046 50.0, confirmation:Tick: 13009 51.16 terminated at: None, hard retracel: Tick: 13046 50.0, soft: None, Up change %: 1.1627906976744171
# 2024-03-12 06:32:04,907 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13052 53.49, phase: Continuation: None, INITIATED from Tick: 13044 52.33 to Tick: 13052 53.49, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,910 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13058 59.88, phase: Continuation: None, INITIATED from Tick: 13047 51.74 to Tick: 13058 59.88, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,913 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 13053 57.56 to Tick: 13065 74.42, confirmation:Tick: 13046 50.0 terminated at: None, hard retracel: Tick: 13065 74.42, soft: None, Down change %: -24.418604651162788
# 2024-03-12 06:32:04,916 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13071 71.51, phase: Continuation: None, INITIATED from Tick: 13060 64.53 to Tick: 13071 71.51, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,918 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13076 67.44, phase: Continuation: None, INITIATED from Tick: 13066 72.67 to Tick: 13076 67.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,921 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 13071 69.19 to Tick: 13083 68.02, confirmation:Tick: 13065 74.42 terminated at: None, hard retracel: Tick: 13083 68.02, soft: None, Up change %: 6.395348837209298
# 2024-03-12 06:32:04,923 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13089 65.12, phase: Continuation: None, INITIATED from Tick: 13078 62.79 to Tick: 13089 65.12, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,925 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13095 65.7, phase: Continuation: None, INITIATED from Tick: 13084 69.19 to Tick: 13095 65.7, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,928 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13101 62.79, phase: Continuation: None, INITIATED from Tick: 13090 63.95 to Tick: 13101 62.79, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,930 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 13096 66.28 to Tick: 13108 62.79, confirmation:Tick: 13083 68.02 terminated at: None, hard retracel: Tick: 13108 62.79, soft: None, Up change %: 5.232558139534888
# 2024-03-12 06:32:04,932 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13114 61.63, phase: Continuation: None, INITIATED from Tick: 13103 56.98 to Tick: 13114 61.63, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,935 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13120 60.47, phase: Continuation: None, INITIATED from Tick: 13109 63.37 to Tick: 13120 60.47, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,937 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13125 56.98, phase: Continuation: None, INITIATED from Tick: 13114 61.63 to Tick: 13125 56.98, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,940 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13131 63.37, phase: Continuation: None, INITIATED from Tick: 13120 59.88 to Tick: 13131 63.37, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,942 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13137 61.63, phase: Continuation: None, INITIATED from Tick: 13126 56.98 to Tick: 13137 61.63, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,945 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13144 55.23, phase: Continuation: None, INITIATED from Tick: 13132 70.35 to Tick: 13144 55.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,947 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13151 45.35, phase: Continuation: None, INITIATED from Tick: 13139 62.21 to Tick: 13151 45.35, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,950 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 13145 54.07 to Tick: 13159 48.26, confirmation:Tick: 13108 62.79 terminated at: None, hard retracel: Tick: 13159 48.26, soft: None, Up change %: 14.534883720930232
# 2024-03-12 06:32:04,953 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13165 56.98, phase: Continuation: None, INITIATED from Tick: 13154 47.09 to Tick: 13165 56.98, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,955 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13171 58.72, phase: Continuation: None, INITIATED from Tick: 13160 48.26 to Tick: 13171 58.72, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,958 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 13166 55.81 to Tick: 13181 58.72, confirmation:Tick: 13159 48.26 terminated at: None, hard retracel: Tick: 13181 58.72, soft: None, Down change %: -10.465116279069768
# 2024-03-12 06:32:04,961 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13187 54.65, phase: Continuation: None, INITIATED from Tick: 13176 56.98 to Tick: 13187 54.65, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,963 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13193 56.98, phase: Continuation: None, INITIATED from Tick: 13182 59.3 to Tick: 13193 56.98, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,967 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 13188 55.81 to Tick: 13201 54.65, confirmation:Tick: 13181 58.72 terminated at: None, hard retracel: Tick: 13201 54.65, soft: None, Up change %: 4.069767441860456
# 2024-03-12 06:32:04,969 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13207 51.16, phase: Continuation: None, INITIATED from Tick: 13196 52.33 to Tick: 13207 51.16, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,972 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13214 55.81, phase: Continuation: None, INITIATED from Tick: 13202 54.07 to Tick: 13214 55.81, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,973 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13220 58.14, phase: Continuation: None, INITIATED from Tick: 13208 51.16 to Tick: 13220 58.14, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,976 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 13226 57.56, phase: Continuation: None, INITIATED from Tick: 13215 52.91 to Tick: 13226 57.56, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:04,978 - INFO - 2600393101.py:56 - [140023195088128] -
# ...
# 2024-03-12 06:32:06,155 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15953 39.53, phase: Continuation: None, INITIATED from Tick: 15942 36.05 to Tick: 15953 39.53, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,158 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15958 39.53, phase: Continuation: None, INITIATED from Tick: 15948 39.53 to Tick: 15958 39.53, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,161 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15965 37.21, phase: Continuation: None, INITIATED from Tick: 15953 38.95 to Tick: 15965 37.21, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,164 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15970 39.53, phase: Continuation: None, INITIATED from Tick: 15959 40.12 to Tick: 15970 39.53, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,168 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15976 41.86, phase: Continuation: None, INITIATED from Tick: 15965 38.37 to Tick: 15976 41.86, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,172 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15982 40.7, phase: Continuation: None, INITIATED from Tick: 15971 40.12 to Tick: 15982 40.7, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,175 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15987 41.86, phase: Continuation: None, INITIATED from Tick: 15976 40.12 to Tick: 15987 41.86, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,179 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15992 43.6, phase: Continuation: None, INITIATED from Tick: 15982 41.86 to Tick: 15992 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,186 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 15997 43.02, phase: Continuation: None, INITIATED from Tick: 15987 40.7 to Tick: 15997 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,191 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16002 44.19, phase: Continuation: None, INITIATED from Tick: 15992 43.02 to Tick: 16002 44.19, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,194 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16009 45.35, phase: Continuation: None, INITIATED from Tick: 15997 43.6 to Tick: 16009 45.35, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,197 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16014 45.93, phase: Continuation: None, INITIATED from Tick: 16003 44.77 to Tick: 16014 45.93, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,204 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 16009 45.35 to Tick: 16035 43.02, confirmation:Tick: 15947 37.21 terminated at: None, hard retracel: Tick: 16035 43.02, soft: None, Down change %: -5.813953488372093
# 2024-03-12 06:32:06,207 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16042 42.44, phase: Continuation: None, INITIATED from Tick: 16033 43.02 to Tick: 16042 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,210 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16048 42.44, phase: Continuation: None, INITIATED from Tick: 16036 44.19 to Tick: 16048 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,213 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16053 42.44, phase: Continuation: None, INITIATED from Tick: 16042 43.02 to Tick: 16053 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,217 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16059 43.6, phase: Continuation: None, INITIATED from Tick: 16048 43.02 to Tick: 16059 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,219 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16064 43.02, phase: Continuation: None, INITIATED from Tick: 16053 43.02 to Tick: 16064 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,221 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16070 44.77, phase: Continuation: None, INITIATED from Tick: 16059 43.6 to Tick: 16070 44.77, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,229 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 16065 44.19 to Tick: 16101 41.86, confirmation:Tick: 16035 43.02 terminated at: None, hard retracel: Tick: 16101 41.86, soft: None, Down change %: 1.1627906976744384
# 2024-03-12 06:32:06,231 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16108 43.02, phase: Continuation: None, INITIATED from Tick: 16098 40.12 to Tick: 16108 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,234 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16113 42.44, phase: Continuation: None, INITIATED from Tick: 16102 41.86 to Tick: 16113 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,241 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 16108 42.44 to Tick: 16137 40.12, confirmation:Tick: 16101 41.86 terminated at: None, hard retracel: Tick: 16137 40.12, soft: None, Down change %: 1.744186046511608
# 2024-03-12 06:32:06,243 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16143 42.44, phase: Continuation: None, INITIATED from Tick: 16132 37.79 to Tick: 16143 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,245 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16149 43.02, phase: Continuation: None, INITIATED from Tick: 16138 40.7 to Tick: 16149 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,248 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16154 43.02, phase: Continuation: None, INITIATED from Tick: 16144 41.86 to Tick: 16154 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,250 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16160 42.44, phase: Continuation: None, INITIATED from Tick: 16149 43.02 to Tick: 16160 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,253 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16166 42.44, phase: Continuation: None, INITIATED from Tick: 16154 42.44 to Tick: 16166 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,256 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 16161 42.44 to Tick: 16173 43.6, confirmation:Tick: 16137 40.12 terminated at: None, hard retracel: Tick: 16173 43.6, soft: None, Down change %: -3.4883720930232442
# 2024-03-12 06:32:06,259 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16179 43.6, phase: Continuation: None, INITIATED from Tick: 16168 43.02 to Tick: 16179 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,261 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16185 43.6, phase: Continuation: None, INITIATED from Tick: 16174 43.6 to Tick: 16185 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,264 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16191 43.02, phase: Continuation: None, INITIATED from Tick: 16180 43.6 to Tick: 16191 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,266 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16196 43.6, phase: Continuation: None, INITIATED from Tick: 16186 44.19 to Tick: 16196 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,269 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16202 43.02, phase: Continuation: None, INITIATED from Tick: 16191 43.02 to Tick: 16202 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,273 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16209 42.44, phase: Continuation: None, INITIATED from Tick: 16197 43.6 to Tick: 16209 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,276 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 16203 43.02 to Tick: 16216 41.86, confirmation:Tick: 16173 43.6 terminated at: None, hard retracel: Tick: 16216 41.86, soft: None, Up change %: 1.7441860465116363
# 2024-03-12 06:32:06,279 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16222 41.28, phase: Continuation: None, INITIATED from Tick: 16211 43.02 to Tick: 16222 41.28, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,281 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16227 41.86, phase: Continuation: None, INITIATED from Tick: 16217 41.28 to Tick: 16227 41.86, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,283 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16232 40.7, phase: Continuation: None, INITIATED from Tick: 16222 40.7 to Tick: 16232 40.7, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,286 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16238 40.12, phase: Continuation: None, INITIATED from Tick: 16227 42.44 to Tick: 16238 40.12, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,288 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16244 42.44, phase: Continuation: None, INITIATED from Tick: 16233 40.12 to Tick: 16244 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,290 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16250 43.02, phase: Continuation: None, INITIATED from Tick: 16239 41.28 to Tick: 16250 43.02, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,292 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16256 42.44, phase: Continuation: None, INITIATED from Tick: 16245 41.86 to Tick: 16256 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,294 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16262 43.6, phase: Continuation: None, INITIATED from Tick: 16251 42.44 to Tick: 16262 43.6, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,297 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16268 42.44, phase: Continuation: None, INITIATED from Tick: 16257 42.44 to Tick: 16268 42.44, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,300 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 16263 42.44 to Tick: 16275 43.6, confirmation:Tick: 16216 41.86 terminated at: None, hard retracel: Tick: 16275 43.6, soft: None, Down change %: -1.7441860465116363
# 2024-03-12 06:32:06,302 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16281 41.86, phase: Continuation: None, INITIATED from Tick: 16270 43.6 to Tick: 16281 41.86, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,304 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16287 41.86, phase: Continuation: None, INITIATED from Tick: 16276 43.6 to Tick: 16287 41.86, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,314 - INFO - 2600393101.py:93 - [140023195088128] -
# hard retracel Continuation: up, HARD RETRACING from Tick: 16282 42.44 to Tick: 16333 49.42, confirmation:Tick: 16275 43.6 terminated at: None, hard retracel: Tick: 16333 49.42, soft: None, Up change %: -5.813953488372093
# 2024-03-12 06:32:06,316 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16339 50.0, phase: Continuation: None, INITIATED from Tick: 16328 50.58 to Tick: 16339 50.0, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,318 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16344 51.16, phase: Continuation: None, INITIATED from Tick: 16334 50.0 to Tick: 16344 51.16, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,320 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16350 52.91, phase: Continuation: None, INITIATED from Tick: 16339 50.0 to Tick: 16350 52.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,323 - INFO - 2600393101.py:95 - [140023195088128] -
# hard retracel Continuation: down, HARD RETRACING from Tick: 16345 50.0 to Tick: 16357 51.16, confirmation:Tick: 16333 49.42 terminated at: None, hard retracel: Tick: 16357 51.16, soft: None, Down change %: -1.7441860465116292
# 2024-03-12 06:32:06,326 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16363 52.91, phase: Continuation: None, INITIATED from Tick: 16352 53.49 to Tick: 16363 52.91, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,328 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16369 54.65, phase: Continuation: None, INITIATED from Tick: 16358 51.74 to Tick: 16369 54.65, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,330 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16374 55.23, phase: Continuation: None, INITIATED from Tick: 16364 52.91 to Tick: 16374 55.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,332 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16380 55.23, phase: Continuation: None, INITIATED from Tick: 16369 54.07 to Tick: 16380 55.23, confirmation:None terminated at: None, hard retracel: None, soft: None
# 2024-03-12 06:32:06,335 - INFO - 2600393101.py:56 - [140023195088128] -
# phase start failed at: Tick: 16386 56.4, phase: Continuation: None, INITIATED from Tick: 16375 55.23 to Tick: 16386 56.4, confirmation:None terminated at: None, hard retracel: None, soft: None
# Continuation: None, INITIATED from Tick: 16381 54.65 to Tick: 16391 55.23, confirmation:None terminated at: None, hard retracel: None, soft: None

# %%
pm.ps[8]
# Out:
# Continuation: up, HARD RETRACING from Tick: 12143 -8.14 to Tick: 12156 -9.88, confirmation:Tick: 12155 -8.72 terminated at: None, hard retracel: Tick: 12156 -9.88, soft: None

# %%
profits = [po.order.pnl for po in pm.closed_orders]
# profits = [round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2) for ph in pm.aps if ph.direction == Direction.UP]
# profits = [round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2) for ph in pm.ps if ph.direction == Direction.UP]
print(sum(profits))
print(len(profits))
# Out:
# -7.519999999999999
# 143

# %%
# Losses
# multi_y = [[po.order.limit_price, po.order.square_off_price] for po in pm.closed_orders if po.order.pnl <= 0]
# multi_x = [[po.phase.started_at.id, po.phase.hard_retraced_at.id] for po in pm.closed_orders if po.order.pnl <= 0]
# texts = [str(po.order.pnl) for po in pm.closed_orders if po.order.pnl <= 0]
# subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

# All
from bokeh.models import ColumnDataSource

multi_y = [[po.order.limit_price, po.order.square_off_price] for po in pm.closed_orders]
multi_x = [[po.phase.started_at.id, po.phase.hard_retraced_at.id] for po in pm.closed_orders]
texts = [str(po.order.pnl) for po in pm.closed_orders]
subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

subplot = ColumnDataSource(subplot)

phase_in_id = [phase.t_start.id for phase in pm.ps]
phase_in_price = [phase.t_start.last_price for phase in pm.ps]
phase_start_plot = ColumnDataSource({'x': phase_in_id, 'y': phase_in_price})

p_end_id = [phase.t_end.id for phase in pm.ps]
p_end_price = [phase.t_end.last_price for phase in pm.ps]
phase_end_plot = ColumnDataSource({'x': p_end_id, 'y': p_end_price})

# phase_plot.data

# %%
import utils as ut
# ut.bokeh_plot(x=list(range(tdf.shape[0])), y=tdf.last_price, x_label="timestamp", y_label="price", plot='line')
ut.bokeh_plot(x=[m.id for m in pm.ticks], y=[tick.last_price for tick in pm.ticks], x_label="timestamp", y_label="price", plot='line', multi_plots=subplot, subplots=[phase_start_plot, phase_end_plot])
# tdf
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e52b59aa-19af-4461-ac3c-03953e4cb528">Loading BokehJS ...</span>
#     </div>
#   <div id="fd1d407e-e743-4b97-84ef-2dcd4dbb5e9f" data-root-id="p1425" style="display: contents;"></div>

# %%
multi_y = [[ph.started_at.last_price, ph.hard_retraced_at.last_price] for ph in pm.aps if ph.direction == Direction.UP]
multi_x = [[ph.started_at.id, ph.hard_retraced_at.id] for ph in pm.aps if ph.direction == Direction.UP]
texts = [str(round(ph.hard_retraced_at.last_price - ph.started_at.last_price, 2)) for ph in pm.aps if ph.direction == Direction.UP]
subplot = {'xs': multi_x, 'ys': multi_y, 'texts': texts, 'x': [m[1] for m in multi_x], 'y': [m[1] for m in multi_y]}

from bokeh.models import ColumnDataSource
subplot = ColumnDataSource(subplot)
